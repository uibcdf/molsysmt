# %% [markdown]
# # Path B - Module 31: Principal Components (PCA) & Axes
#
# To understand the high-temperature stability of PETase, we need to know how the enzyme vibrates. Does it expand globally or does the active site cleft flap around?
#
# In this module, you will learn to use **Principal Components** to identify the most significant conformational changes in your engineered industrial enzyme.

# %%
import molsysmt as msm
from molsysmt import systems

# Load a sample trajectory of PETase
villin_traj = systems['chicken villin HP35']['traj_chicken_villin_HP35_solvated.dcd']
villin_topo = systems['chicken villin HP35']['chicken_villin_HP35_solvated.h5msm']
molsys = [villin_topo, villin_traj]

# %% [markdown]
# ### 1. Principal Axes and Orientation
# Identifying the orientation of your enzyme is the first step for docking or surface analysis. MolSysMT can find the long, medium, and short axes of your model.

# %%
# Get the principal axes of the protein
axes = msm.structure.get_principal_axes(molsys, selection='molecule_type=="protein"', structure_indices=0)
print("Principal Axes (Eigenvectors):")
print(axes)

# %% [markdown]
# ### 2. PCA: Dimensionality Reduction
# PCA projects the movement of thousands of atoms into a few "modes" of motion. This allows you to visualize the essential dynamics of your enzyme.

# %%
# Calculate the first two principal components
projection, eigenvalues = msm.structure.principal_component_analysis(molsys, selection='atom_name=="CA"')

print(f"Projection of the first frame on PC1 and PC2: {projection[0]}")
print(f"Variance capture by PC1: {eigenvalues[0]:.2f}")

# %% [markdown]
# ### 3. Essential Dynamics Visualization
# By projecting your trajectory into the PC1-PC2 space, you can identify if your engineered mutations have constrained the enzyme's motion compared to the wild-type.

# %% [markdown]
# ---
#
# ### 🏆 Path B Challenge: The Motion Analyst
#
# 1. Calculate the **Principal Axes** for the **BHET substrate** we built in Module 24.
# 2. Perform a **PCA** on only the active site residues of the PETase.
# 3. Does the first PC explain more than **50% of the variance**?
# 4. Align the system so its long axis (PC1) points towards the Z-direction using `msm.structure.align_principal_axes()`.
#
# Dynamics define efficiency. In **Module 32**, we will check the **Secondary Structure** to ensure our mutations didn't break the enzyme's fold.
