# %% [markdown]
# # Path C - Module 45: Performance Optimization
#
# Pre-compile your analysis tools to speed up virtual screening. In this module, you will learn to use `warmup_numba()`.

# %%
import molsysmt as msm
msm.warmup_numba()
