# %% [markdown]
# # Path C - Module 43: Trajectory Management (Slicing)
#
# Filter the production frames of your drug sim. In this module, you will learn to slice trajectories to focus on the binding event.

# %%
import molsysmt as msm
from molsysmt import systems
villin = [systems['chicken villin HP35']['chicken_villin_HP35_solvated.h5msm'], systems['chicken villin HP35']['traj_chicken_villin_HP35_solvated.dcd']]
short_traj = msm.extract(villin, structure_indices=range(0, 10))
