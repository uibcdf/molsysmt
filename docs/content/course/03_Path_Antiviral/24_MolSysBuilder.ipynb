# %% [markdown]
# # Path C - Module 24: The MolSysBuilder API
#
# In the SARS-CoV-2 Mpro site, some water molecules are so important that they are considered part of the "active site architecture". In this module, you will learn to build a custom "Bridging Water" molecule at a specific coordinate to stabilize the inhibitor.

# %%
import molsysmt as msm
from molsysmt import systems

# Create an empty builder
molsys = msm.convert(None, to_form='molsysmt.MolSys')
builder = msm.build.editable(molsys)

# Add a bridging Oxygen at a specific pose
builder.add_atom(atom_name='OW', coordinates=[[0.5, 0.5, 0.5]], entity_name='Bridging Water')
print("Manual structural component added.")
