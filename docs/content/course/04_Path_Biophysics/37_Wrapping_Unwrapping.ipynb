# %% [markdown]
# # Path D - Module 37: Wrapping & Unwrapping
#
# Fix the membrane continuity. In this module, you will learn to unwrap the bilayer and the channel to perform accurate diffusion measurements.

# %%
import molsysmt as msm
from molsysmt import systems
system = [systems['POPC membrane']['popc_membrane.h5msm'], systems['POPC membrane']['popc_membrane.dcd']]
unwrapped = msm.pbc.unwrap(system, selection='molecule_type=="protein"')
