# %% [markdown]
# (course-biophysics-capability-matrix)=
#
# # Path D - Module 53: Capability Matrix & Config
#
# Verify which trajectory formats support unit cells for membrane wrapping. In this module, you will master the interoperability of biophysics files.

# %%
import molsysmt as msm
msm.supported.conversions()
