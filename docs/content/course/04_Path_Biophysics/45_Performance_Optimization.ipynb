# %% [markdown]
# # Path D - Module 45: Performance Optimization
#
# Speed up your ion flux counters. In this module, you will learn to use Numba warmup for high-performance membrane analysis.

# %%
import molsysmt as msm
msm.warmup_numba()
