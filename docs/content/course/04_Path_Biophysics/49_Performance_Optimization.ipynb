# %% [markdown]
# (course-biophysics-performance-optimization)=
#
# # Path D - Module 49: Performance Optimization
#
# Speed up your ion flux counters. In this module, you will learn to use `warmup()` for high-performance membrane analysis.

# %%
import molsysmt as msm
msm.warmup()
