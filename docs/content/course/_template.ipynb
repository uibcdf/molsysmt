# %% [markdown]
# # [Module Number]. [Module Title]
#
# *Brief 1-2 sentence overview of what this module covers and its role in the learning path.*

# %% [markdown]
# ## 🎯 Learning Outcomes
#
# By the end of this module, you will be able to:
# - outcome_1: Ex. Load molecular systems from different input formats using `msm.convert`.
# - outcome_2: Ex. Inspect topology attributes using `msm.get`.
# - outcome_3: Ex. Apply form-agnostic selection queries.

# %% [markdown]
# ## 🧪 Working System & Prerequisites
#
# This module uses the following standard system from `molsysmt.systems`:
# - **System:** Ex. T4 Lysozyme (PDB ID `181L`).

# %% [markdown]
# :::{admonition} API Documentation Reference
# :class: tip
# For complete details on the functions used in this notebook, see:
# - {func}`molsysmt.basic.get`
# - {func}`molsysmt.basic.convert`
# :::

# %% [markdown]
# ## 💡 Conceptual Background & Hands-on Examples
#
# ### Step 1: Loading the System
#
# Explain the concept first before showing the code.

# %%
import molsysmt as msm

# Load system using msm.systems
# mol = msm.convert(msm.systems['T4 lysozyme L99A']['181l.mmtf'])

# %% [markdown]
# ## ✏️ Check Your Understanding
#
# **Challenge:** Try executing `msm.get` on your loaded system to count the number of water molecules.
#
# ```python
# # Write your solution here
# ```

# %% [markdown]
# ## 🔗 See Also
#
# - Next Module: [Next Module Title](../path/next_module.ipynb)
# - Related Guide: {ref}`user-foundations`
