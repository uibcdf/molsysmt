# %% [markdown]
# # Module 5: Quick Reports & Summaries
#
# Once you have loaded a system, the first thing you usually want is an inventory. What is inside? How many chains? Are there ligands?
#
# MolSysMT provides two main ways to answer these questions: `info()` (for human-readable tables) and `get()` (for raw data extraction).

# %%
import molsysmt as msm
from molsysmt import systems

lysozyme = systems['T4 lysozyme L99A']['181l.h5msm']

# %% [markdown]
# ### 1. The System Inventory with `info()`
# By default, `info()` gives you a summary of the whole system. It returns a styled Pandas table that is very easy to read.

# %%
msm.info(lysozyme)
# Out:
# <style type="text/css">
# </style>
# <table id="T_58a61">
#   <thead>
#     <tr>
#       <th id="T_58a61_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_58a61_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_58a61_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_58a61_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_58a61_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_58a61_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_58a61_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_58a61_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_58a61_level0_col8" class="col_heading level0 col8" >n_ions</th>
#       <th id="T_58a61_level0_col9" class="col_heading level0 col9" >n_small_molecules</th>
# ...

# %% [markdown]
# ### 2. Inspecting Specific Levels
# You can change the `element` argument to get details about different hierarchical levels: `atom`, `group`, `molecule`, `chain`, or `entity`.

# %%
# Let's see which biological entities are in the system
msm.info(lysozyme, element='entity')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3915e">
#   <thead>
#     <tr>
#       <th id="T_3915e_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_3915e_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_3915e_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_3915e_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_3915e_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_3915e_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_3915e_level0_col6" class="col_heading level0 col6" >n chains</th>
#       <th id="T_3915e_level0_col7" class="col_heading level0 col7" >n molecules</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3915e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3915e_row0_col1" class="data row0 col1" >T4 LYSOZYME</td>
# ...

# %%
# Let's see the chains
msm.info(lysozyme, element='chain')
# Out:
# <style type="text/css">
# </style>
# <table id="T_abbc6">
#   <thead>
#     <tr>
#       <th id="T_abbc6_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_abbc6_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_abbc6_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_abbc6_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_abbc6_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_abbc6_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_abbc6_level0_col6" class="col_heading level0 col6" >molecule index</th>
#       <th id="T_abbc6_level0_col7" class="col_heading level0 col7" >molecule type</th>
#       <th id="T_abbc6_level0_col8" class="col_heading level0 col8" >entity index</th>
#       <th id="T_abbc6_level0_col9" class="col_heading level0 col9" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ### 3. Combining Info with Selections
# You can generate a report for only a part of the system. For example, let's see a table of all non-standard residues (ligands, ions, etc.).

# %%
msm.info(lysozyme, element='group', selection='not molecule_type=="protein" and not molecule_type=="water"')
# Out:
# <style type="text/css">
# </style>
# <table id="T_24dd8">
#   <thead>
#     <tr>
#       <th id="T_24dd8_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_24dd8_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_24dd8_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_24dd8_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_24dd8_level0_col4" class="col_heading level0 col4" >n atoms</th>
#       <th id="T_24dd8_level0_col5" class="col_heading level0 col5" >component index</th>
#       <th id="T_24dd8_level0_col6" class="col_heading level0 col6" >chain index</th>
#       <th id="T_24dd8_level0_col7" class="col_heading level0 col7" >molecule index</th>
#       <th id="T_24dd8_level0_col8" class="col_heading level0 col8" >molecule type</th>
#       <th id="T_24dd8_level0_col9" class="col_heading level0 col9" >entity index</th>
# ...

# %% [markdown]
# ### 4. Extracting Raw Data with `get()`
# While `info()` is for looking, `get()` is for computing. It returns lists or NumPy arrays that you can use in your code.

# %%
# Get the names and IDs of all residues in chain 0
names, ids = msm.get(lysozyme, element='group', selection='chain_index==0', group_name=True, group_id=True)

print(f"First 5 residues: {list(zip(names, ids))[:5]}")
# Out:
# First 5 residues: [('MET', '1'), ('ASN', '2'), ('ILE', '3'), ('PHE', '4'), ('GLU', '5')]

# %% [markdown]
# ---
#
# ### 🏆 Challenge 5: The System Auditor
#
# 1. Load the **Antiviral Complex** (Barnase-Barstar) from the systems database.
# 2. Use `msm.info()` to see how many chains it has.
# 3. Use `msm.get()` to find the total number of atoms in the system.
# 4. Generate an `info()` table of only the **Entities** of the system.
#
# Great! You now know what is inside any molecular system. In **Module 6**, we will learn how to handle units safely so our numbers always make physical sense.
