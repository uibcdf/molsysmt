# %% [markdown]
# (course-biophysics-final-project)=
#
# # Path D - Module 54: Final Project: Computational Biophysics of Ion Permeation
#
# Your final mission: Build a membrane-embedded potassium channel, solvate it in KCl, relax the system, and perform a high-performance analysis of the ion crossing events.
#
# **The nano-mechanics of life are now yours to command.**

# %%
import molsysmt as msm
print("Path D Graduation Project Template Ready.")
# Out:
# Path D Graduation Project Template Ready.
