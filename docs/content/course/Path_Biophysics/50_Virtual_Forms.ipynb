# %% [markdown]
# (course-biophysics-virtual-forms)=
#
# # Path D - Module 50: Virtual Forms & Memory I/O
#
# Work with in-memory membrane patches. In this module, you will learn to process cloud-hosted biophysical models without disk access.

# %%
import molsysmt as msm
molsys = msm.convert('pdb:1K4C', to_form='molsysmt.MolSys')
