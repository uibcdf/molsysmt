# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Contains)=
# # Contains
#
# *Checking whether a molecular system contains specific elements or attributes.*
#
# The function {func}`molsysmt.basic.contains` allows to check whether or not a molecular system contains certain elements or attributes without needing to call {func}`molsysmt.basic.get` directly.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.basic.contains`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's show how this function works using the T4 lysozyme dataset (`181l.bcif.gz`):

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['T4 lysozyme L99A']['181l.bcif.gz'], to_form='molsysmt.MolSys')

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba66e" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_ba66e_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_ba66e_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_ba66e_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_ba66e_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_ba66e_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_ba66e_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_ba66e_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_ba66e_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_ba66e_level0_col8" class="col_heading level0 col8" >n_ions</th>
#       <th id="T_ba66e_level0_col9" class="col_heading level0 col9" >n_small_molecules</th>
#       <th id="T_ba66e_level0_col10" class="col_heading level0 col10" >n_proteins</th>
#       <th id="T_ba66e_level0_col11" class="col_heading level0 col11" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ba66e_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_ba66e_row0_col1" class="data row0 col1" >1441</td>
#       <td id="T_ba66e_row0_col2" class="data row0 col2" >302</td>
#       <td id="T_ba66e_row0_col3" class="data row0 col3" >141</td>
#       <td id="T_ba66e_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_ba66e_row0_col5" class="data row0 col5" >141</td>
#       <td id="T_ba66e_row0_col6" class="data row0 col6" >5</td>
#       <td id="T_ba66e_row0_col7" class="data row0 col7" >136</td>
#       <td id="T_ba66e_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_ba66e_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_ba66e_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_ba66e_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's check if the system contains water molecules:

# %%
msm.contains(molsys, waters=True)
# Out:
# True

# %% [markdown]
# We can also check whether the system includes periodic boundary conditions (`box`):

# %%
msm.contains(molsys, box=True)
# Out:
# True

# %% [markdown]
# :::{tip}
# :class: dropdown
#
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can also be invoked from the main level of the library. Hence, {func}`molsysmt.contains` is the same function as {func}`molsysmt.basic.contains`.
# :::

# %% [markdown]
# Now let's verify if the system contains ions, small molecules, and proteins:

# %%
msm.contains(molsys, ions=True, small_molecules=True, proteins=True)
# Out:
# True

# %% [markdown]
# You can also check for the absence of specific elements or attributes by setting their value to `False`:

# %%
msm.contains(molsys, proteins=True, lipids=False)
# Out:
# True

# %% [markdown]
# Or check whether the system contains a specific minimum count of molecules by passing an integer threshold:

# %%
msm.contains(molsys, small_molecules=2, ions=2)
# Out:
# True

# %%
msm.contains(molsys, small_molecules=2, proteins=2)
# Out:
# False

# %% [markdown]
# The input argument `selection` can be used to test whether specific atom selections exist in the system:

# %%
msm.contains(molsys, selection='hydrogens')
# Out:
# False

# %%
msm.contains(molsys, selection='molecule_type!="water" and atom_name==["CA", "CB"]')
# Out:
# True

# %% [markdown]
# Finally, you can combine a selection with additional attribute conditions:

# %%
msm.contains(molsys, selection='molecule_type!="water"', small_molecules=2)
# Out:
# True

# %%
msm.contains(molsys, selection='molecule_type!="water"', waters=True)
# Out:
# False

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Tutorial_Get`: Retrieve attribute values from a molecular system with {func}`molsysmt.basic.get`.
# - {ref}`Tutorial_Convert`: Convert a molecular system into another form or forms with {func}`molsysmt.basic.convert`.
# - {ref}`Tutorial_Info`: Print a summary of the contents, topology, and structural data of a molecular system with {func}`molsysmt.basic.info`.
# - {ref}`Tutorial_Select`: Select elements from a molecular system with {func}`molsysmt.basic.select`.
# :::
