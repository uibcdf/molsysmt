# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Remove)=
# # Remove
#
# *Removing atoms or structures from a molecular system.*
#
# The function {func}`molsysmt.basic.remove` allows removing atoms or structures from a molecular system.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.basic.remove`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's show how this function works with a PDB structure (`181L`). The input argument `selection` allows us to define the elements to be removed:

# %%
import molsysmt as msm

# %%
molsys = msm.convert('181L')

# %%
msm.info(molsys, element='chain')
# Out:
# <style type="text/css">
# </style>
# <table id="T_31b14" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_31b14_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_31b14_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_31b14_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_31b14_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_31b14_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_31b14_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_31b14_level0_col6" class="col_heading level0 col6" >molecule index</th>
#       <th id="T_31b14_level0_col7" class="col_heading level0 col7" >molecule type</th>
#       <th id="T_31b14_level0_col8" class="col_heading level0 col8" >entity index</th>
#       <th id="T_31b14_level0_col9" class="col_heading level0 col9" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
molsys_trimmed = msm.remove(molsys, selection='chain_index==[1,2,3,4,5]')

# %% [markdown]
# :::{tip}
# :class: dropdown
#
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can also be invoked from the main level of the library. Hence, {func}`molsysmt.remove` is the same function as {func}`molsysmt.basic.remove`.
# :::

# %%
msm.info(molsys_trimmed, element='chain')
# Out:
# <style type="text/css">
# </style>
# <table id="T_83669" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_83669_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_83669_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_83669_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_83669_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_83669_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_83669_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_83669_level0_col6" class="col_heading level0 col6" >molecule index</th>
#       <th id="T_83669_level0_col7" class="col_heading level0 col7" >molecule type</th>
#       <th id="T_83669_level0_col8" class="col_heading level0 col8" >entity index</th>
#       <th id="T_83669_level0_col9" class="col_heading level0 col9" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Removing structures
#
# The function {func}`molsysmt.basic.remove` can also remove structures from a molecular system. The input argument `structure_indices` specifies the structures to be removed:

# %%
pdbfile = msm.systems['Trp-Cage']['1l2y.pdb']
molsys = msm.convert(pdbfile, to_form='molsysmt.Structures')

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89fa3" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_89fa3_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_89fa3_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_89fa3_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_89fa3_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_89fa3_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_89fa3_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_89fa3_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_89fa3_level0_col7" class="col_heading level0 col7" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_89fa3_row0_col0" class="data row0 col0" >molsysmt.Structures</td>
#       <td id="T_89fa3_row0_col1" class="data row0 col1" >304</td>
# ...

# %%
molsys_trimmed = msm.remove(molsys, structure_indices=range(1,38))

# %%
msm.info(molsys_trimmed)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eefc3" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_eefc3_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_eefc3_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_eefc3_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_eefc3_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_eefc3_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_eefc3_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_eefc3_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_eefc3_level0_col7" class="col_heading level0 col7" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eefc3_row0_col0" class="data row0 col0" >molsysmt.Structures</td>
#       <td id="T_eefc3_row0_col1" class="data row0 col1" >304</td>
# ...

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`user-foundations-entrance-demo-systems`: Explore demonstration datasets used for testing and tutorials.
# - {ref}`Tutorial_Convert`: Convert a molecular system into another form with {func}`molsysmt.basic.convert`.
# - {ref}`Tutorial_Info`: Display a summary of the contents of a molecular system with {func}`molsysmt.basic.info`.
# - {ref}`Tutorial_Remove`: Remove atoms or structures from a molecular system with {func}`molsysmt.basic.remove`.
# - {ref}`Tutorial_Select`: Select atoms or structural elements using flexible selection syntax with {func}`molsysmt.basic.select`.
# :::
