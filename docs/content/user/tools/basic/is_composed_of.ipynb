# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Is_composed_of)=
# # Is composed of
#
# *Checking whether a molecular system is composed of specific elements.*
#
# The function {func}`molsysmt.basic.is_composed_of` checks whether a molecular system is made up exclusively of certain types or number of elements.
#
# :::{hint}
# :class: dropdown
#
# Visit the section {ref}`Introduction_Elements` for a detailed overview of element hierarchy in MolSysMT.
# :::
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.basic.is_composed_of`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's show how this function works using a PDB structure (`181L`):

# %%
import molsysmt as msm

# %%
molsys = msm.convert('181L')

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a276d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_a276d_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_a276d_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_a276d_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_a276d_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_a276d_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_a276d_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_a276d_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_a276d_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_a276d_level0_col8" class="col_heading level0 col8" >n_ions</th>
#       <th id="T_a276d_level0_col9" class="col_heading level0 col9" >n_small_molecules</th>
#       <th id="T_a276d_level0_col10" class="col_heading level0 col10" >n_proteins</th>
#       <th id="T_a276d_level0_col11" class="col_heading level0 col11" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a276d_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_a276d_row0_col1" class="data row0 col1" >1441</td>
#       <td id="T_a276d_row0_col2" class="data row0 col2" >302</td>
#       <td id="T_a276d_row0_col3" class="data row0 col3" >141</td>
#       <td id="T_a276d_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_a276d_row0_col5" class="data row0 col5" >141</td>
#       <td id="T_a276d_row0_col6" class="data row0 col6" >5</td>
#       <td id="T_a276d_row0_col7" class="data row0 col7" >136</td>
#       <td id="T_a276d_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_a276d_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_a276d_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_a276d_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We know in advance that the system includes multiple molecule types: proteins, ions, waters, and small molecules.
# Therefore, although it contains proteins, it is not composed solely of proteins:

# %%
msm.is_composed_of(molsys, proteins=True)
# Out:
# False

# %% [markdown]
# :::{tip}
# :class: dropdown
#
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can also be invoked from the main level of the library. Hence, {func}`molsysmt.is_composed_of` is the same function as {func}`molsysmt.basic.is_composed_of`.
# :::

# %% [markdown]
# Let's see now if the molecular system is indeed composed of proteins, waters, small molecules and ions:

# %%
msm.is_composed_of(molsys, proteins=True, waters=True, small_molecules=True, ions=True)
# Out:
# True

# %% [markdown]
# You can also specify the exact number of each element type using keyword arguments. For example:

# %%
msm.is_composed_of(molsys, proteins=1, waters=True, small_molecules=2, ions=True)
# Out:
# True

# %%
msm.is_composed_of(molsys, proteins=1, small_molecules=1)
# Out:
# False

# %% [markdown]
# Other element types, such as atoms, groups, components or molecules, can also be checked using their respective attribute names:

# %%
msm.is_composed_of(molsys, n_atoms=1441, n_groups=302)
# Out:
# True

# %%
msm.is_composed_of(molsys, n_components=3, n_molecules=3)
# Out:
# False

# %% [markdown]
# Finally, you can apply this function to a selection of elements using the `selection` argument:

# %%
msm.is_composed_of(molsys, selection='molecule_type in ["ion", "water", "small molecule", "protein"]')
# Out:
# True

# %%
msm.is_composed_of(molsys, selection='molecule_type not in ["ion", "water", "small molecule"]', proteins=1)
# Out:
# True

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Introduction_Elements`: Describe the hierarchical structure of elements (atom, group, component, molecule, chain, entity, system) in a molecular system.
# - {ref}`Tutorial_Convert`: Convert a molecular system into another form or forms with {func}`molsysmt.basic.convert`.
# - {ref}`Tutorial_Info`: Display summary information about the contents of a molecular system with {func}`molsysmt.basic.info`.
# - {ref}`Tutorial_Is_composed_of`: Check whether a molecular system is composed of specific elements with {func}`molsysmt.basic.is_composed_of`.
# - {ref}`Tutorial_Contains`: Check whether specific elements are present in a molecular system with {func}`molsysmt.basic.contains`.
# :::
