# %% [markdown]
# # Make water box

# %%
import molsysmt as msm
from molsysmt import pyunitwizard as puw
import numpy as np

# %%
box = np.zeros((3,3))
box[0,0] = 5.0
box[1,1] = 5.0
box[2,2] = 3.0
box = msm.pyunitwizard.quantity(box, 'nm')

# %%
molsys = msm.build.make_water_box(box)

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_69570">
#   <thead>
#     <tr>
#       <th id="T_69570_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_69570_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_69570_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_69570_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_69570_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_69570_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_69570_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_69570_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_69570_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69570_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_69570_row0_col1" class="data row0 col1" >7608</td>
#       <td id="T_69570_row0_col2" class="data row0 col2" >2536</td>
#       <td id="T_69570_row0_col3" class="data row0 col3" >2536</td>
#       <td id="T_69570_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_69570_row0_col5" class="data row0 col5" >2536</td>
#       <td id="T_69570_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_69570_row0_col7" class="data row0 col7" >2536</td>
#       <td id="T_69570_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
coordinates = msm.get(molsys, coordinates=True)

# %%
coordinates[0,:,0].min()
# Out:
# <Quantity(-0.04997, 'nanometer')>

# %%
coordinates[0,:,1].min()
# Out:
# <Quantity(-0.06997, 'nanometer')>

# %%
coordinates[0,:,2].min()
# Out:
# <Quantity(-0.05297, 'nanometer')>

# %%
coordinates[0,:,0].max()
# Out:
# <Quantity(5.07115, 'nanometer')>

# %%
coordinates[0,:,1].max()
# Out:
# <Quantity(5.03215, 'nanometer')>

# %%
coordinates[0,:,2].max()
# Out:
# <Quantity(3.06909, 'nanometer')>
