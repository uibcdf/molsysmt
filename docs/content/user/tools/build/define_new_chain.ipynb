# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Define_new_chain)=
# # Define new chain
#
# *Defining a new chain by grouping a selection of atoms.*
#
# The function {func}`molsysmt.build.define_new_chain` groups any selected set of atoms into a new chain. This is useful when preparing systems for simulation, merging fragments, or reassigning chain identities after structural modifications.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.build.define_new_chain`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's show how this function works using a protein system loaded from PDB ID `1TCD`:

# %%
import molsysmt as msm

# %%
molsys = msm.convert('1TCD')

# %% [markdown]
# Let's inspect the current chain composition of the system:

# %%
msm.info(molsys, element='chain')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ea56" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_6ea56_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_6ea56_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_6ea56_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_6ea56_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_6ea56_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_6ea56_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_6ea56_level0_col6" class="col_heading level0 col6" >molecule index</th>
#       <th id="T_6ea56_level0_col7" class="col_heading level0 col7" >molecule type</th>
#       <th id="T_6ea56_level0_col8" class="col_heading level0 col8" >entity index</th>
#       <th id="T_6ea56_level0_col9" class="col_heading level0 col9" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# We now assign all water molecules to a new chain labeled `'C'`:

# %%
msm.build.define_new_chain(molsys, selection='molecule_type=="water"', chain_name='C')

# %% [markdown]
# Let's confirm that the water molecules have been grouped into a new chain:

# %%
msm.info(molsys, element='chain')
# Out:
# <style type="text/css">
# </style>
# <table id="T_95e0a" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_95e0a_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_95e0a_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_95e0a_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_95e0a_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_95e0a_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_95e0a_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_95e0a_level0_col6" class="col_heading level0 col6" >molecule index</th>
#       <th id="T_95e0a_level0_col7" class="col_heading level0 col7" >molecule type</th>
#       <th id="T_95e0a_level0_col8" class="col_heading level0 col8" >entity index</th>
#       <th id="T_95e0a_level0_col9" class="col_heading level0 col9" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Convert <Tutorial_Convert>`: Convert molecular systems between different forms with {func}`molsysmt.basic.convert`.
# - {ref}`Info <Tutorial_Info>`: Display structural and topological summaries of a molecular system with {func}`molsysmt.basic.info`.
# - {ref}`Define new chain <Tutorial_Define_new_chain>`: Group a selection of atoms into a new chain with {func}`molsysmt.build.define_new_chain`.
# :::
