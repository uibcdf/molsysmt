# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_shape_from_box)=
# # Get shape from box
#
# *Inferring the unit cell shape directly from a 3x3 box matrix.*
#
# The function {func}`molsysmt.pbc.get_shape_from_box` determines the space-filling geometry of a periodic boundary condition box matrix.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.pbc.get_shape_from_box`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's identify the box shape from a periodic box matrix:

# %%
import molsysmt as msm

# %%
box_dod = msm.pbc.get_box_with_shape(shape='rhombic dodecahedral', length='3.0 nm')
shape_dod = msm.pbc.get_shape_from_box(box_dod)
print('Inferred box shape:', shape_dod)
# Out:
# Inferred box shape: rhombic dodecahedral

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get box with shape <Tutorial_Get_box_with_shape>`: Generate standard boxes with {func}`molsysmt.pbc.get_box_with_shape`.
# - {ref}`Get shape from angles <Tutorial_Get_shape_from_angles>`: Determine shape from angles with {func}`molsysmt.pbc.get_shape_from_angles`.
# - {ref}`Get volume from box <Tutorial_Get_volume_from_box>`: Compute box volume with {func}`molsysmt.pbc.get_volume_from_box`.
# :::
