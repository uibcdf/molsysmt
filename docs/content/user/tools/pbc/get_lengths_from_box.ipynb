# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_lengths_from_box)=
# # Get lengths from box
#
# *Extracting edge lengths from periodic box matrices.*
#
# The function {func}`molsysmt.pbc.get_lengths_from_box` computes the Euclidean lengths of the three cell vectors $(a, b, c)$ defining a periodic box matrix.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.pbc.get_lengths_from_box`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's extract edge lengths from a periodic box matrix:

# %%
import molsysmt as msm
import pyunitwizard as puw

# %%
box = msm.pbc.get_box_with_shape(shape='cubic', length='3.5 nm')
lengths = msm.pbc.get_lengths_from_box(box)
print('Box lengths:', lengths)
# Out:
# Box lengths: [[3.5 3.5 3.5]] nanometer

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get box with shape <Tutorial_Get_box_with_shape>`: Generate standard boxes with {func}`molsysmt.pbc.get_box_with_shape`.
# - {ref}`Get angles from box <Tutorial_Get_angles_from_box>`: Extract box angles with {func}`molsysmt.pbc.get_angles_from_box`.
# - {ref}`Get volume from box <Tutorial_Get_volume_from_box>`: Compute box volume with {func}`molsysmt.pbc.get_volume_from_box`.
# :::
