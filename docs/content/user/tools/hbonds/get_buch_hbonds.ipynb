# %% [markdown]
# # Get Buch hbonds

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['chicken villin HP35']['chicken_villin_HP35.h5msm'])

# %%
hbonds, distance = msm.hbonds.get_buch_hbonds(molsys)

# %%
hbonds
# Out:
# array([[[ 42,  43,  91],
#         [ 51,  52,  90],
#         [ 80,  81,  90],
#         [ 92,  93,  47],
#         [112, 113,  58],
#         [130, 132,  79],
#         [130, 133,  78],
#         [134, 135,  70],
#         [144, 145,  85],
#         [160, 161,  97],
#         [180, 181, 117],
#         [187, 188, 165],
#         [218, 219,  64],
#         [233, 234,  63],
#         [236, 238,  28],
#         [239, 240,  28],
#         [239, 241,  63],
#         [253, 254, 212],
#         [263, 264, 209],
#         [283, 284, 223],
#         [293, 294, 258],
#         [307, 308, 268],
#         [383, 384, 330],
#         [401, 402, 530],
#         [401, 403, 529],
#         [405, 406, 330],
#         [419, 421, 312],
#         [422, 423, 345],
#         [439, 440, 364],
#         [453, 454, 388],
#         [472, 473, 410],
#         [490, 492,   1],
#         [490, 493, 559],
#         [494, 495, 458],
#         [512, 513, 435],
#         [512, 514, 427],
#         [512, 515, 477],
#         [516, 517, 444],
#         [531, 532, 458],
#         [549, 550, 149]]])

# %%
distance
# Out:
# <Quantity([[0.19900185 0.15920687 0.18909734 0.20613839 0.18360413 0.19072422
#   0.1716894  0.19033877 0.20429171 0.18012114 0.19193857 0.19313254
#   0.1815416  0.18365467 0.19502046 0.18780084 0.17765819 0.21942751
#   0.18543787 0.21186452 0.20569051 0.20363263 0.21097517 0.17315926
#   0.19845041 0.20057324 0.17853139 0.18927051 0.19304898 0.1862113
#   0.19133048 0.18645106 0.177747   0.19041938 0.18692091 0.18042592
#   0.1847712  0.17978268 0.2146073  0.175748  ]], 'nanometer')>

# %%
molsys = msm.convert(msm.systems['Barnase-Barstar']['barnase_barstar.h5msm'])

# %%
msm.info(molsys, element='molecule')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fa3d">
#   <thead>
#     <tr>
#       <th id="T_1fa3d_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_1fa3d_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1fa3d_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_1fa3d_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_1fa3d_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_1fa3d_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_1fa3d_level0_col6" class="col_heading level0 col6" >chain index</th>
#       <th id="T_1fa3d_level0_col7" class="col_heading level0 col7" >entity index</th>
#       <th id="T_1fa3d_level0_col8" class="col_heading level0 col8" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1fa3d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1fa3d_row0_col1" class="data row0 col1" >BARNASE</td>
#       <td id="T_1fa3d_row0_col2" class="data row0 col2" >protein</td>
#       <td id="T_1fa3d_row0_col3" class="data row0 col3" >1727</td>
#       <td id="T_1fa3d_row0_col4" class="data row0 col4" >110</td>
#       <td id="T_1fa3d_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_1fa3d_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_1fa3d_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_1fa3d_row0_col8" class="data row0 col8" >protein 0</td>
#     </tr>
#     <tr>
#       <td id="T_1fa3d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1fa3d_row1_col1" class="data row1 col1" >BARSTAR</td>
#       <td id="T_1fa3d_row1_col2" class="data row1 col2" >protein</td>
#       <td id="T_1fa3d_row1_col3" class="data row1 col3" >1432</td>
#       <td id="T_1fa3d_row1_col4" class="data row1 col4" >89</td>
#       <td id="T_1fa3d_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_1fa3d_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_1fa3d_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_1fa3d_row1_col8" class="data row1 col8" >protein 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
hbonds, distance = msm.hbonds.get_buch_hbonds(molsys, selection='molecule_name=="BARNASE"',
                                              selection_2='molecule_name=="BARSTAR"')

# %%
hbonds
# Out:
# array([[[ 431,  432, 2361],
#         [ 431,  434, 2400],
#         [ 583,  584, 2442],
#         [ 858,  859, 2296],
#         [ 876,  878, 2969],
#         [ 879,  881, 2969],
#         [ 882,  883, 2297],
#         [1253, 1254, 2361],
#         [1253, 1255, 2412],
#         [1256, 1258, 2361],
#         [1256, 1258, 2362],
#         [1311, 1312, 2362],
#         [1317, 1318, 2362],
#         [1610, 1611, 2237],
#         [2267, 2268,  896]]])
