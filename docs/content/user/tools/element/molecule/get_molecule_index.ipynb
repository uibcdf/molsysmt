# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_molecule_index)=
# # Get molecule index
#
# *Querying 0-indexed integer indices for molecules in a molecular system.*
#
# The function {func}`molsysmt.element.molecule.get_molecule_index` returns 0-based topological indices for molecules.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.element.molecule.get_molecule_index`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's retrieve the topological indices:

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['Barnase-Barstar']['barnase_barstar.h5msm'])

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %%
indices = msm.element.molecule.get_molecule_index(molsys, element='molecule', selection='all')
print('Molecule indices:', indices)
# Out:
# Molecule indices: [0, 1]

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get molecule id <Tutorial_Get_molecule_id>`: Get molecule IDs with {func}`molsysmt.element.molecule.get_molecule_id`.
# - {ref}`Get molecule name <Tutorial_Get_molecule_name>`: Get molecule names with {func}`molsysmt.element.molecule.get_molecule_name`.
# :::
