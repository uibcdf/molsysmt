# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_molecule_name)=
# # Get molecule name
#
# *Extracting descriptive names for molecules in molecular systems.*
#
# The function {func}`molsysmt.element.molecule.get_molecule_name` retrieves human-readable names assigned to molecules.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.element.molecule.get_molecule_name`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's query the names across the system:

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['Barnase-Barstar']['barnase_barstar.h5msm'])

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %%
names = msm.element.molecule.get_molecule_name(molsys, element='molecule', selection='all')
print('Molecule names:', names)
# Out:
# Molecule names: ['BARNASE', 'BARSTAR']

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get molecule id <Tutorial_Get_molecule_id>`: Get molecule IDs with {func}`molsysmt.element.molecule.get_molecule_id`.
# - {ref}`Get molecule type <Tutorial_Get_molecule_type>`: Get molecule types with {func}`molsysmt.element.molecule.get_molecule_type`.
# :::
