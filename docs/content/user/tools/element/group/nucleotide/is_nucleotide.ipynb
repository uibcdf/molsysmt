# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Is_nucleotide)=
# # Is nucleotide
#
# *Validating whether a residue is a recognized DNA or RNA nucleotide.*
#
# The function {func}`molsysmt.element.group.nucleotide.is_nucleotide` checks residue names against standard nucleic acid nucleotide definitions.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.element.group.nucleotide.is_nucleotide`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's test nucleotide names:

# %%
import molsysmt as msm

# %%
print('Is DA a nucleotide?:', msm.element.group.nucleotide.is_nucleotide('DA'))
print('Is U a nucleotide?:', msm.element.group.nucleotide.is_nucleotide('U'))
print('Is ALA a nucleotide?:', msm.element.group.nucleotide.is_nucleotide('ALA'))
# Out:
# Is DA a nucleotide?: True
# Is U a nucleotide?: True
# Is ALA a nucleotide?: False

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Is group type <Tutorial_Is_group_type>`: Check group types with {func}`molsysmt.element.group.is_group_type`.
# :::
