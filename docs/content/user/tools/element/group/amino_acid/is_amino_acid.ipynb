# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Is_amino_acid)=
# # Is amino acid
#
# *Validating whether a residue name corresponds to an amino acid.*
#
# The function {func}`molsysmt.element.group.amino_acid.is_amino_acid` checks if a residue name is a recognized standard or non-standard amino acid.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.element.group.amino_acid.is_amino_acid`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's test various residue names against the amino-acid dictionary:

# %%
import molsysmt as msm

# %%
print('Is ALA an amino acid?:', msm.element.group.amino_acid.is_amino_acid('ALA'))
print('Is MSE an amino acid?:', msm.element.group.amino_acid.is_amino_acid('MSE'))
print('Is HOH an amino acid?:', msm.element.group.amino_acid.is_amino_acid('HOH'))
# Out:
# Is ALA an amino acid?: True
# Is MSE an amino acid?: False
# Is HOH an amino acid?: False

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get 1 letter code from name <Tutorial_Get_1_letter_code_from_name>`: Get 1-letter code with {func}`molsysmt.element.group.amino_acid.get_1_letter_code_from_name`.
# - {ref}`Get standard name <Tutorial_Get_standard_name>`: Map to canonical residue name with {func}`molsysmt.element.group.amino_acid.get_standard_name`.
# :::
