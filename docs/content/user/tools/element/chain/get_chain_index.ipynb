# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_chain_index)=
# # Get chain index
#
# *Querying 0-indexed integer indices for chains in a molecular system.*
#
# The function {func}`molsysmt.element.chain.get_chain_index` returns 0-based topological indices for chains.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.element.chain.get_chain_index`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's retrieve the topological indices:

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['Barnase-Barstar']['barnase_barstar.h5msm'])

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %%
indices = msm.element.chain.get_chain_index(molsys, element='chain', selection='all')
print('Chain indices:', indices)
# Out:
# Chain indices: [0]

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get chain id <Tutorial_Get_chain_id>`: Get chain IDs with {func}`molsysmt.element.chain.get_chain_id`.
# - {ref}`Get chain name <Tutorial_Get_chain_name>`: Get chain names with {func}`molsysmt.element.chain.get_chain_name`.
# :::
