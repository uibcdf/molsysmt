# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_pdb)=
# # file:pdb
#
# *Protein Data Bank file format*
#
# - **Technical Form Name:** `file:pdb`
# - **Form Type:** `file`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.file_pdb`
# :::
#
# ## Overview
#
# `file:pdb` is a supported representation form in MolSysMT. Protein Data Bank file format

# %% [markdown]
# ## Supported attributes
#
# The `file:pdb` form container supports a total of **63 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type`, `formal_charge` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bonded_atoms`, `inner_bonded_atoms`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Crystallographic & Bioassembly | `b_factor`, `alternate_location`, `occupancy`, `bioassembly`, `n_bioassemblies` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.file_pdb` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.file_pdb.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `file:pdb` instance. |
# | {func}`~molsysmt.form.file_pdb.copy.copy` | Creates an independent deep copy of the `file:pdb` object in memory. |
# | {func}`~molsysmt.form.file_pdb.add.add` | Adds elements from another system into an existing `file:pdb` instance. |
# | {func}`~molsysmt.form.file_pdb.merge.merge` | Merges multiple systems into a single combined `file:pdb` object. |
# | {func}`~molsysmt.form.file_pdb.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.file_pdb.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.file_pdb.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.file_pdb.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.file_pdb.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.file_pdb.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `file:pdb`. |
# | {func}`~molsysmt.form.file_pdb.is_form.is_form` | Returns `True` if the provided object is an instance of `file:pdb`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.file_pdb`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `MDAnalysis.Topology` | `class` | {func}`~molsysmt.form.file_pdb.to_MDAnalysis_Topology.to_MDAnalysis_Topology` |
# | `MDAnalysis.Universe` | `class` | {func}`~molsysmt.form.file_pdb.to_MDAnalysis_Universe.to_MDAnalysis_Universe` |
# | `MDAnalysis.topology.PDBParser` | `class` | {func}`~molsysmt.form.file_pdb.to_MDAnalysis_topology_PDBParser.to_MDAnalysis_topology_PDBParser` |
# | `file:mol2` | `file` | {func}`~molsysmt.form.file_pdb.to_file_mol2.to_file_mol2` |
# | `file:pdb` | `file` | {func}`~molsysmt.form.file_pdb.to_file_pdb.to_file_pdb` |
# | `mdtraj.PDBTrajectoryFile` | `class` | {func}`~molsysmt.form.file_pdb.to_mdtraj_PDBTrajectoryFile.to_mdtraj_PDBTrajectoryFile` |
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.file_pdb.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `mdtraj.Trajectory` | `class` | {func}`~molsysmt.form.file_pdb.to_mdtraj_Trajectory.to_mdtraj_Trajectory` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.file_pdb.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.PDBFileHandler` | `class` | {func}`~molsysmt.form.file_pdb.to_molsysmt_PDBFileHandler.to_molsysmt_PDBFileHandler` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.file_pdb.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.file_pdb.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.file_pdb.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Modeller` | `class` | {func}`~molsysmt.form.file_pdb.to_openmm_Modeller.to_openmm_Modeller` |
# | `openmm.PDBFile` | `class` | {func}`~molsysmt.form.file_pdb.to_openmm_PDBFile.to_openmm_PDBFile` |
# | `openmm.Simulation` | `class` | {func}`~molsysmt.form.file_pdb.to_openmm_Simulation.to_openmm_Simulation` |
# | `openmm.System` | `class` | {func}`~molsysmt.form.file_pdb.to_openmm_System.to_openmm_System` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.file_pdb.to_openmm_Topology.to_openmm_Topology` |
# | `parmed.Structure` | `class` | {func}`~molsysmt.form.file_pdb.to_parmed_Structure.to_parmed_Structure` |
# | `pdbfixer.PDBFixer` | `class` | {func}`~molsysmt.form.file_pdb.to_pdbfixer_PDBFixer.to_pdbfixer_PDBFixer` |
# | `pytraj.Topology` | `class` | {func}`~molsysmt.form.file_pdb.to_pytraj_Topology.to_pytraj_Topology` |
# | `pytraj.Trajectory` | `class` | {func}`~molsysmt.form.file_pdb.to_pytraj_Trajectory.to_pytraj_Trajectory` |
# | `string:pdb_text` | `string` | {func}`~molsysmt.form.file_pdb.to_string_pdb_text.to_string_pdb_text` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
