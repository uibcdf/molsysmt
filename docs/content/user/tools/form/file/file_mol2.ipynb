# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_mol2)=
# # file:mol2
#
# *Form adapter and capabilities for file:mol2.*
#
# - **Technical Form Name:** `file:mol2`
# - **Form Type:** `file`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.file_mol2`
# :::
#
# ## Overview
#
# `file:mol2` is a supported representation form in MolSysMT. Form adapter and capabilities for file:mol2.

# %% [markdown]
# ## Supported attributes
#
# The `file:mol2` form container supports a total of **50 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_id`, `bond_type`, `bond_order`, `fractional_bond_order`, `bond_is_aromatic`, `bond_joins_components`, `bond_evidence`, `n_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |
# | **Mechanical** | Force Field Parameters | `partial_charge` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.file_mol2` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.file_mol2.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `file:mol2` instance. |
# | {func}`~molsysmt.form.file_mol2.copy.copy` | Creates an independent deep copy of the `file:mol2` object in memory. |
# | {func}`~molsysmt.form.file_mol2.add.add` | Adds elements from another system into an existing `file:mol2` instance. |
# | {func}`~molsysmt.form.file_mol2.merge.merge` | Merges multiple systems into a single combined `file:mol2` object. |
# | {func}`~molsysmt.form.file_mol2.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.file_mol2.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.file_mol2.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.file_mol2.get_mechanical_attributes` | Module containing getters for mechanical attributes. |
# | {mod}`~molsysmt.form.file_mol2.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.file_mol2.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.file_mol2.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `file:mol2`. |
# | {func}`~molsysmt.form.file_mol2.is_form.is_form` | Returns `True` if the provided object is an instance of `file:mol2`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.file_mol2`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:mol2` | `file` | {func}`~molsysmt.form.file_mol2.to_file_mol2.to_file_mol2` |
# | `file:pdb` | `file` | {func}`~molsysmt.form.file_mol2.to_file_pdb.to_file_pdb` |
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.file_mol2.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `mdtraj.Trajectory` | `class` | {func}`~molsysmt.form.file_mol2.to_mdtraj_Trajectory.to_mdtraj_Trajectory` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.file_mol2.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.file_mol2.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.file_mol2.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.file_mol2.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Modeller` | `class` | {func}`~molsysmt.form.file_mol2.to_openmm_Modeller.to_openmm_Modeller` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.file_mol2.to_openmm_Topology.to_openmm_Topology` |
# | `parmed.Structure` | `class` | {func}`~molsysmt.form.file_mol2.to_parmed_Structure.to_parmed_Structure` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
