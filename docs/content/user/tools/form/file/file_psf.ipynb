# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_psf)=
# # file:psf
#
# *CHARMM Protein Structure File (PSF).*
#
# - **Technical Form Name:** `file:psf`
# - **Form Type:** `file`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.file_psf`
# :::
#
# ## Overview
#
# `file:psf` is a supported representation form in MolSysMT. CHARMM Protein Structure File (PSF).

# %% [markdown]
# ## Supported attributes
#
# The `file:psf` form container supports a total of **55 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `connectivity_completeness`, `bond_index`, `bond_type`, `bond_evidence`, `bonded_atoms`, `bonded_atom_pairs`, `inner_bonded_atoms`, `inner_bonded_atom_pairs`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |
# | **Mechanical** | Force Field Parameters | `partial_charge`, `atom_ff_type` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.file_psf` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.file_psf.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `file:psf` instance. |
# | {func}`~molsysmt.form.file_psf.copy.copy` | Creates an independent deep copy of the `file:psf` object in memory. |
# | {func}`~molsysmt.form.file_psf.add.add` | Adds elements from another system into an existing `file:psf` instance. |
# | {func}`~molsysmt.form.file_psf.merge.merge` | Merges multiple systems into a single combined `file:psf` object. |
# | {func}`~molsysmt.form.file_psf.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.file_psf.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.file_psf.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.file_psf.get_mechanical_attributes` | Module containing getters for mechanical attributes. |
# | {mod}`~molsysmt.form.file_psf.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.file_psf.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.file_psf.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `file:psf`. |
# | {func}`~molsysmt.form.file_psf.is_form.is_form` | Returns `True` if the provided object is an instance of `file:psf`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.file_psf`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:psf` | `file` | {func}`~molsysmt.form.file_psf.to_file_psf.to_file_psf` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.file_psf.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.file_psf.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.CharmmPsfFile` | `class` | {func}`~molsysmt.form.file_psf.to_openmm_CharmmPsfFile.to_openmm_CharmmPsfFile` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.file_psf.to_openmm_Topology.to_openmm_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
