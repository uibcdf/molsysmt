# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_crd)=
# # file:crd
#
# *Form adapter and capabilities for file:crd.*
#
# ['CHARMM card (CRD) file format with coordinates.', 'https://www.charmmtutorial.org/index.php/CHARMM:The_Basics#CHARMM_data_structures'] (form type: `file`).
#
# :::{versionadded} 1.0.0
# :::

# %% [markdown]
# ## Basic usage
#
# Let's inspect the supported attributes and properties of this form:

# %%
import molsysmt as msm

# %%
form_name = 'file:crd'
attrs = msm.form.get_attributes(form_name, output_type='list')
print('Form:', form_name)
print('Total supported attributes:', len(attrs))
print('Attributes:', attrs[:10])
# Out:
# Form: file:crd
# Total supported attributes: 15
# Attributes: ['atom_index', 'atom_name', 'atom_id', 'atom_type', 'group_index', 'group_name', 'group_id', 'group_type', 'n_atoms', 'n_groups']

# %% [markdown]
# ## Checking attribute availability
#
# We can test specific structural and topological attributes:

# %%
print('Supports coordinates?:', msm.form.has_attribute('file:crd', 'coordinates'))
print('Supports box dimensions?:', msm.form.has_attribute('file:crd', 'box'))
print('Supports atom names?:', msm.form.has_attribute('file:crd', 'atom_name'))
# Out:
# Supports coordinates?: True
# Supports box dimensions?: True
# Supports atom names?: True

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Query full attribute dictionary with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Check specific attribute with {func}`molsysmt.form.has_attribute`.
# :::
