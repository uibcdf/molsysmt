# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_crd)=
# # file:crd
#
# *CHARMM card (CRD) file format with coordinates.*
#
# - **Technical Form Name:** `file:crd`
# - **Form Type:** `file`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.file_crd`
# :::
#
# ## Overview
#
# `file:crd` is a supported representation form in MolSysMT. CHARMM card (CRD) file format with coordinates.

# %% [markdown]
# ## Supported attributes
#
# The `file:crd` form container supports a total of **15 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups` |
# | **Structural** | Coordinates & Conformations | `structure_id`, `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.file_crd` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.file_crd.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `file:crd` instance. |
# | {func}`~molsysmt.form.file_crd.copy.copy` | Creates an independent deep copy of the `file:crd` object in memory. |
# | {func}`~molsysmt.form.file_crd.add.add` | Adds elements from another system into an existing `file:crd` instance. |
# | {func}`~molsysmt.form.file_crd.merge.merge` | Merges multiple systems into a single combined `file:crd` object. |
# | {func}`~molsysmt.form.file_crd.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.file_crd.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.file_crd.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.file_crd.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.file_crd.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.file_crd.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `file:crd`. |
# | {func}`~molsysmt.form.file_crd.is_form.is_form` | Returns `True` if the provided object is an instance of `file:crd`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.file_crd`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:crd` | `file` | {func}`~molsysmt.form.file_crd.to_file_crd.to_file_crd` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.file_crd.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.file_crd.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.file_crd.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.CharmmCrdFile` | `class` | {func}`~molsysmt.form.file_crd.to_openmm_CharmmCrdFile.to_openmm_CharmmCrdFile` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
