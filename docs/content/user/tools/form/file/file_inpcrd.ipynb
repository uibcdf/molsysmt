# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_file_inpcrd)=
# # file:inpcrd
#
# *Form adapter and capabilities for file:inpcrd.*
#
# ['AMBER ASCII restart/inpcrd file format', 'https://ambermd.org/FileFormats.php#trajectory'] (form type: `file`).
#
# :::{versionadded} 1.0.0
# :::

# %% [markdown]
# ## Basic usage
#
# Let's inspect the supported attributes and properties of this form:

# %%
import molsysmt as msm

# %%
form_name = 'file:inpcrd'
attrs = msm.form.get_attributes(form_name, output_type='list')
print('Form:', form_name)
print('Total supported attributes:', len(attrs))
print('Attributes:', attrs[:10])
# Out:
# Form: file:inpcrd
# Total supported attributes: 12
# Attributes: ['atom_index', 'n_atoms', 'structure_index', 'structure_id', 'box', 'box_shape', 'box_angles', 'box_lengths', 'box_volume', 'coordinates']

# %% [markdown]
# ## Checking attribute availability
#
# We can test specific structural and topological attributes:

# %%
print('Supports coordinates?:', msm.form.has_attribute('file:inpcrd', 'coordinates'))
print('Supports box dimensions?:', msm.form.has_attribute('file:inpcrd', 'box'))
print('Supports atom names?:', msm.form.has_attribute('file:inpcrd', 'atom_name'))
# Out:
# Supports coordinates?: True
# Supports box dimensions?: True
# Supports atom names?: False

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Query full attribute dictionary with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Check specific attribute with {func}`molsysmt.form.has_attribute`.
# :::
