# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_mdtraj_GroTrajectoryFile)=
# # GroTrajectoryFile
#
# *Form adapter and capabilities for mdtraj.GroTrajectoryFile.*
#
# - **Technical Form Name:** `mdtraj.GroTrajectoryFile`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.mdtraj_GroTrajectoryFile`
# :::
#
# ## Overview
#
# `mdtraj.GroTrajectoryFile` is a supported representation form in MolSysMT. Form adapter and capabilities for mdtraj.GroTrajectoryFile.

# %% [markdown]
# ## Supported attributes
#
# The `mdtraj.GroTrajectoryFile` form container supports a total of **11 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index` |
# | **Topological** | Element Counts | `n_atoms` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.mdtraj_GroTrajectoryFile` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `mdtraj.GroTrajectoryFile` instance. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.copy.copy` | Creates an independent deep copy of the `mdtraj.GroTrajectoryFile` object in memory. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.add.add` | Adds elements from another system into an existing `mdtraj.GroTrajectoryFile` instance. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.merge.merge` | Merges multiple systems into a single combined `mdtraj.GroTrajectoryFile` object. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.mdtraj_GroTrajectoryFile.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.mdtraj_GroTrajectoryFile.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.mdtraj_GroTrajectoryFile.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.mdtraj_GroTrajectoryFile.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `mdtraj.GroTrajectoryFile`. |
# | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.is_form.is_form` | Returns `True` if the provided object is an instance of `mdtraj.GroTrajectoryFile`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.mdtraj_GroTrajectoryFile`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `mdtraj.GroTrajectoryFile` | `class` | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.to_mdtraj_GroTrajectoryFile.to_mdtraj_GroTrajectoryFile` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.mdtraj_GroTrajectoryFile.to_molsysmt_Structures.to_molsysmt_Structures` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
