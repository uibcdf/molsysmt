# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_mdtraj_HDF5TrajectoryFile)=
# # HDF5TrajectoryFile
#
# *Form adapter and capabilities for mdtraj.HDF5TrajectoryFile.*
#
# - **Technical Form Name:** `mdtraj.HDF5TrajectoryFile`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.mdtraj_HDF5TrajectoryFile`
# :::
#
# ## Overview
#
# `mdtraj.HDF5TrajectoryFile` is a supported representation form in MolSysMT. Form adapter and capabilities for mdtraj.HDF5TrajectoryFile.

# %% [markdown]
# ## Supported attributes
#
# The `mdtraj.HDF5TrajectoryFile` form container supports a total of **60 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_type`, `bond_order`, `bonded_atoms`, `n_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_amino_acids`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time`, `potential_energy`, `kinetic_energy`, `total_energy`, `temperature` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.mdtraj_HDF5TrajectoryFile` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `mdtraj.HDF5TrajectoryFile` instance. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.copy.copy` | Creates an independent deep copy of the `mdtraj.HDF5TrajectoryFile` object in memory. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.add.add` | Adds elements from another system into an existing `mdtraj.HDF5TrajectoryFile` instance. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.merge.merge` | Merges multiple systems into a single combined `mdtraj.HDF5TrajectoryFile` object. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `mdtraj.HDF5TrajectoryFile`. |
# | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.is_form.is_form` | Returns `True` if the provided object is an instance of `mdtraj.HDF5TrajectoryFile`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.mdtraj_HDF5TrajectoryFile`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `mdtraj.HDF5TrajectoryFile` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_mdtraj_HDF5TrajectoryFile.to_mdtraj_HDF5TrajectoryFile` |
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.mdtraj_HDF5TrajectoryFile.to_openmm_Topology.to_openmm_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
