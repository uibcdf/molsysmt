# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_biopython_Seq)=
# # Seq
#
# *Form adapter and capabilities for biopython.Seq.*
#
# - **Technical Form Name:** `biopython.Seq`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.biopython_Seq`
# :::
#
# ## Overview
#
# `biopython.Seq` is a supported representation form in MolSysMT. Form adapter and capabilities for biopython.Seq.

# %% [markdown]
# ## Supported attributes
#
# The `biopython.Seq` form container supports a total of **2 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Group Level | `group_index`, `group_name` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.biopython_Seq` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.biopython_Seq.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `biopython.Seq` instance. |
# | {func}`~molsysmt.form.biopython_Seq.copy.copy` | Creates an independent deep copy of the `biopython.Seq` object in memory. |
# | {func}`~molsysmt.form.biopython_Seq.add.add` | Adds elements from another system into an existing `biopython.Seq` instance. |
# | {func}`~molsysmt.form.biopython_Seq.merge.merge` | Merges multiple systems into a single combined `biopython.Seq` object. |
# | {mod}`~molsysmt.form.biopython_Seq.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.biopython_Seq.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.biopython_Seq.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.biopython_Seq.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.biopython_Seq.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `biopython.Seq`. |
# | {func}`~molsysmt.form.biopython_Seq.is_form.is_form` | Returns `True` if the provided object is an instance of `biopython.Seq`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.biopython_Seq`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `biopython.Seq` | `class` | {func}`~molsysmt.form.biopython_Seq.to_biopython_Seq.to_biopython_Seq` |
# | `biopython.SeqRecord` | `class` | {func}`~molsysmt.form.biopython_Seq.to_biopython_SeqRecord.to_biopython_SeqRecord` |
# | `file:fasta` | `file` | {func}`~molsysmt.form.biopython_Seq.to_file_fasta.to_file_fasta` |
# | `file:pir` | `file` | {func}`~molsysmt.form.biopython_Seq.to_file_pir.to_file_pir` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
