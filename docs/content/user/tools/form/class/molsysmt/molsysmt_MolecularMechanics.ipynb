# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysmt_MolecularMechanics)=
# # MolecularMechanics
#
# *Form adapter and capabilities for molsysmt.MolecularMechanics.*
#
# - **Technical Form Name:** `molsysmt.MolecularMechanics`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.molsysmt_MolecularMechanics`
# :::
#
# ## Overview
#
# `molsysmt.MolecularMechanics` is a supported representation form in MolSysMT. Form adapter and capabilities for molsysmt.MolecularMechanics.

# %% [markdown]
# ## Supported attributes
#
# The `molsysmt.MolecularMechanics` form container supports a total of **19 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `formal_charge` |
# | **Mechanical** | Force Field Parameters | `partial_charge`, `atom_ff_type`, `forcefield`, `water_model`, `implicit_solvent` |
# | **Mechanical** | Non-Bonded & Solvation | `non_bonded_method`, `cutoff_distance`, `switch_distance`, `dispersion_correction`, `ewald_error_tolerance`, `solute_dielectric`, `solvent_dielectric`, `salt_concentration`, `kappa` |
# | **Mechanical** | Constraints & Dynamics | `hydrogen_mass`, `constraints`, `flexible_constraints`, `rigid_water` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.molsysmt_MolecularMechanics` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `molsysmt.MolecularMechanics` instance. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.copy.copy` | Creates an independent deep copy of the `molsysmt.MolecularMechanics` object in memory. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.add.add` | Adds elements from another system into an existing `molsysmt.MolecularMechanics` instance. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.merge.merge` | Merges multiple systems into a single combined `molsysmt.MolecularMechanics` object. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.molsysmt_MolecularMechanics.get_mechanical_attributes` | Module containing getters for mechanical attributes. |
# | {mod}`~molsysmt.form.molsysmt_MolecularMechanics.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `molsysmt.MolecularMechanics`. |
# | {func}`~molsysmt.form.molsysmt_MolecularMechanics.is_form.is_form` | Returns `True` if the provided object is an instance of `molsysmt.MolecularMechanics`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.molsysmt_MolecularMechanics`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.MolecularMechanics` | `class` | {func}`~molsysmt.form.molsysmt_MolecularMechanics.to_molsysmt_MolecularMechanics.to_molsysmt_MolecularMechanics` |
# | `molsysmt.MolecularMechanicsDict` | `class` | {func}`~molsysmt.form.molsysmt_MolecularMechanics.to_molsysmt_MolecularMechanicsDict.to_molsysmt_MolecularMechanicsDict` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
