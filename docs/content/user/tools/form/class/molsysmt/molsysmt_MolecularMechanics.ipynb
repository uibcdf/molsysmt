# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysmt_MolecularMechanics)=
# # MolecularMechanics
#
# *Form adapter and capabilities for molsysmt.MolecularMechanics.*
#
# ['', ''] (form type: `class`).
#
# :::{versionadded} 1.0.0
# :::

# %% [markdown]
# ## Basic usage
#
# Let's inspect the supported attributes and properties of this form:

# %%
import molsysmt as msm

# %%
form_name = 'molsysmt.MolecularMechanics'
attrs = msm.form.get_attributes(form_name, output_type='list')
print('Form:', form_name)
print('Total supported attributes:', len(attrs))
print('Attributes:', attrs[:10])
# Out:
# Form: molsysmt.MolecularMechanics
# Total supported attributes: 19
# Attributes: ['formal_charge', 'partial_charge', 'atom_ff_type', 'forcefield', 'non_bonded_method', 'cutoff_distance', 'switch_distance', 'dispersion_correction', 'ewald_error_tolerance', 'hydrogen_mass']

# %% [markdown]
# ## Checking attribute availability
#
# We can test specific structural and topological attributes:

# %%
print('Supports coordinates?:', msm.form.has_attribute('molsysmt.MolecularMechanics', 'coordinates'))
print('Supports box dimensions?:', msm.form.has_attribute('molsysmt.MolecularMechanics', 'box'))
print('Supports atom names?:', msm.form.has_attribute('molsysmt.MolecularMechanics', 'atom_name'))
# Out:
# Supports coordinates?: False
# Supports box dimensions?: False
# Supports atom names?: False

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Query full attribute dictionary with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Check specific attribute with {func}`molsysmt.form.has_attribute`.
# :::
