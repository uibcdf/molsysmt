# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysmt_ViewerJSON)=
# # ViewerJSON
#
# *Form adapter and capabilities for molsysmt.ViewerJSON.*
#
# - **Technical Form Name:** `molsysmt.ViewerJSON`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.molsysmt_ViewerJSON`
# :::
#
# ## Overview
#
# `molsysmt.ViewerJSON` is a supported representation form in MolSysMT. Form adapter and capabilities for molsysmt.ViewerJSON.

# %% [markdown]
# ## Supported attributes
#
# The `molsysmt.ViewerJSON` form container supports a total of **18 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `formal_charge` |
# | **Topological** | Group Level | `group_name`, `group_id` |
# | **Topological** | Chain Level | `chain_id` |
# | **Topological** | Entity Level | `entity_id` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_type`, `bond_order`, `bonded_atoms`, `n_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_bonds` |
# | **Structural** | Coordinates & Conformations | `coordinates`, `n_structures` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |
# | **Mechanical** | Force Field Parameters | `partial_charge` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.molsysmt_ViewerJSON` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.molsysmt_ViewerJSON.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `molsysmt.ViewerJSON` instance. |
# | {func}`~molsysmt.form.molsysmt_ViewerJSON.copy.copy` | Creates an independent deep copy of the `molsysmt.ViewerJSON` object in memory. |
# | {func}`~molsysmt.form.molsysmt_ViewerJSON.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.molsysmt_ViewerJSON.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.molsysmt_ViewerJSON.get_structural_attributes` | Module containing getters for structural attributes. |
# | {func}`~molsysmt.form.molsysmt_ViewerJSON.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `molsysmt.ViewerJSON`. |
# | {func}`~molsysmt.form.molsysmt_ViewerJSON.is_form.is_form` | Returns `True` if the provided object is an instance of `molsysmt.ViewerJSON`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.molsysmt_ViewerJSON`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.molsysmt_ViewerJSON.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.ViewerJSON` | `class` | {func}`~molsysmt.form.molsysmt_ViewerJSON.to_molsysmt_ViewerJSON.to_molsysmt_ViewerJSON` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
