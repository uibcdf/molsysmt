# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysmt_Topology)=
# # Topology
#
# *Form adapter and capabilities for molsysmt.Topology.*
#
# - **Technical Form Name:** `molsysmt.Topology`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.molsysmt_Topology`
# :::
#
# ## Overview
#
# `molsysmt.Topology` is a supported representation form in MolSysMT. Form adapter and capabilities for molsysmt.Topology.

# %% [markdown]
# ## Supported attributes
#
# The `molsysmt.Topology` form container supports a total of **76 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type`, `isotope`, `formal_charge`, `atom_is_aromatic`, `n_unpaired_electrons`, `n_implicit_hydrogens`, `allows_implicit_hydrogens`, `atom_stereochemistry` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_completeness`, `component_evidence`, `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `connectivity_completeness`, `bond_index`, `bond_id`, `bond_type`, `bond_order`, `fractional_bond_order`, `bond_is_aromatic`, `bond_is_conjugated`, `bond_stereochemistry`, `bond_stereo_atom_indices`, `bond_donor_atom_index`, `bond_acceptor_atom_index`, `bond_joins_components`, `bond_evidence`, `bonded_atoms`, `bonded_atom_pairs`, `inner_bonded_atoms`, `inner_bonded_atom_pairs`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Chemical States | `chemical_state_index`, `chemical_state_id`, `n_chemical_states`, `reference_chemical_state_index` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.molsysmt_Topology` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.molsysmt_Topology.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `molsysmt.Topology` instance. |
# | {func}`~molsysmt.form.molsysmt_Topology.copy.copy` | Creates an independent deep copy of the `molsysmt.Topology` object in memory. |
# | {func}`~molsysmt.form.molsysmt_Topology.add.add` | Adds elements from another system into an existing `molsysmt.Topology` instance. |
# | {func}`~molsysmt.form.molsysmt_Topology.merge.merge` | Merges multiple systems into a single combined `molsysmt.Topology` object. |
# | {func}`~molsysmt.form.molsysmt_Topology.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {func}`~molsysmt.form.molsysmt_Topology.add_bonds.add_bonds` | Adds covalent bonds between specified pairs of atom indices in the topology. |
# | {func}`~molsysmt.form.molsysmt_Topology.remove_bonds.remove_bonds` | Removes covalent bonds between specified pairs of atom indices in the topology. |
# | {mod}`~molsysmt.form.molsysmt_Topology.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.molsysmt_Topology.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.molsysmt_Topology.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.molsysmt_Topology.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.molsysmt_Topology.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `molsysmt.Topology`. |
# | {func}`~molsysmt.form.molsysmt_Topology.is_form.is_form` | Returns `True` if the provided object is an instance of `molsysmt.Topology`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.molsysmt_Topology`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:h5msm` | `file` | {func}`~molsysmt.form.molsysmt_Topology.to_file_h5msm.to_file_h5msm` |
# | `file:pdb` | `file` | {func}`~molsysmt.form.molsysmt_Topology.to_file_pdb.to_file_pdb` |
# | `file:psf` | `file` | {func}`~molsysmt.form.molsysmt_Topology.to_file_psf.to_file_psf` |
# | `file:topology_yaml` | `file` | {func}`~molsysmt.form.molsysmt_Topology.to_file_topology_yaml.to_file_topology_yaml` |
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `molsysmt.TopologyDict` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_molsysmt_TopologyDict.to_molsysmt_TopologyDict` |
# | `molsysmt.ViewerJSON` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_molsysmt_ViewerJSON.to_molsysmt_ViewerJSON` |
# | `networkx.Graph` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_networkx_Graph.to_networkx_Graph` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_openmm_Topology.to_openmm_Topology` |
# | `parmed.Structure` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_parmed_Structure.to_parmed_Structure` |
# | `pytraj.Topology` | `class` | {func}`~molsysmt.form.molsysmt_Topology.to_pytraj_Topology.to_pytraj_Topology` |
# | `string:amino_acids_1` | `string` | {func}`~molsysmt.form.molsysmt_Topology.to_string_amino_acids_1.to_string_amino_acids_1` |
# | `string:amino_acids_3` | `string` | {func}`~molsysmt.form.molsysmt_Topology.to_string_amino_acids_3.to_string_amino_acids_3` |
# | `string:pdb_text` | `string` | {func}`~molsysmt.form.molsysmt_Topology.to_string_pdb_text.to_string_pdb_text` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
