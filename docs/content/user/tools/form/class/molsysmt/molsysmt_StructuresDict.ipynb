# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysmt_StructuresDict)=
# # StructuresDict
#
# *Python dictionary representation of structural coordinates and trajectories.*
#
# - **Technical Form Name:** `molsysmt.StructuresDict`
# - **Form Type:** `class`
# - **Origin / Library:** MolSysMT Native Object
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Reference: `molsysmt.StructuresDict`
# - Form adapter module: {mod}`molsysmt.form.molsysmt_StructuresDict`
# :::
#
# ## Overview
#
# `molsysmt.StructuresDict` is a core native component in MolSysMT. Python dictionary representation of structural coordinates and trajectories.

# %% [markdown]
# ## Supported attributes
#
# The `molsysmt.StructuresDict` form container supports a total of **20 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index` |
# | **Topological** | Element Counts | `n_atoms` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time`, `potential_energy`, `kinetic_energy`, `total_energy`, `temperature` |
# | **Structural** | Crystallographic & Bioassembly | `b_factor`, `alternate_location`, `occupancy` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.molsysmt_StructuresDict` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.molsysmt_StructuresDict.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `molsysmt.StructuresDict` instance. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.copy.copy` | Creates an independent deep copy of the `molsysmt.StructuresDict` object in memory. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.add.add` | Adds elements from another system into an existing `molsysmt.StructuresDict` instance. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.merge.merge` | Merges multiple systems into a single combined `molsysmt.StructuresDict` object. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.molsysmt_StructuresDict.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.molsysmt_StructuresDict.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.molsysmt_StructuresDict.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.molsysmt_StructuresDict.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `molsysmt.StructuresDict`. |
# | {func}`~molsysmt.form.molsysmt_StructuresDict.is_form.is_form` | Returns `True` if the provided object is an instance of `molsysmt.StructuresDict`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.molsysmt_StructuresDict`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:structures_yaml` | `file` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_file_structures_yaml.to_file_structures_yaml` |
# | `file:trjpk` | `file` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_file_trjpk.to_file_trjpk` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.MolecularMechanics` | `class` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_molsysmt_MolecularMechanics.to_molsysmt_MolecularMechanics` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.StructuresDict` | `class` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_molsysmt_StructuresDict.to_molsysmt_StructuresDict` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.molsysmt_StructuresDict.to_molsysmt_Topology.to_molsysmt_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-molecularmechanics`: Architectural specification of the `MolecularMechanics` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsysbuilder`: Procedural assembly and modification of molecular systems.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
