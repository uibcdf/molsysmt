# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_XYZ)=
# # XYZ
#
# *Form adapter and capabilities for XYZ.*
#
# - **Technical Form Name:** `XYZ`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.XYZ`
# :::
#
# ## Overview
#
# `XYZ` is a supported representation form in MolSysMT. Form adapter and capabilities for XYZ.

# %% [markdown]
# ## Supported attributes
#
# The `XYZ` form container supports a total of **5 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index` |
# | **Topological** | Element Counts | `n_atoms` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `coordinates`, `n_structures` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.XYZ` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.XYZ.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `XYZ` instance. |
# | {func}`~molsysmt.form.XYZ.copy.copy` | Creates an independent deep copy of the `XYZ` object in memory. |
# | {func}`~molsysmt.form.XYZ.add.add` | Adds elements from another system into an existing `XYZ` instance. |
# | {func}`~molsysmt.form.XYZ.merge.merge` | Merges multiple systems into a single combined `XYZ` object. |
# | {func}`~molsysmt.form.XYZ.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.XYZ.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.XYZ.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.XYZ.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.XYZ.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.XYZ.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `XYZ`. |
# | {func}`~molsysmt.form.XYZ.is_form.is_form` | Returns `True` if the provided object is an instance of `XYZ`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.XYZ`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `XYZ` | `class` | {func}`~molsysmt.form.XYZ.to_XYZ.to_XYZ` |
# | `cupy_ndarray` | `class` | {func}`~molsysmt.form.XYZ.to_cupy_ndarray.to_cupy_ndarray` |
# | `file:xyznpy` | `file` | {func}`~molsysmt.form.XYZ.to_file_xyznpy.to_file_xyznpy` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.XYZ.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.MolecularMechanics` | `class` | {func}`~molsysmt.form.XYZ.to_molsysmt_MolecularMechanics.to_molsysmt_MolecularMechanics` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.XYZ.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.XYZ.to_molsysmt_Topology.to_molsysmt_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
