# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_openmm_PDBFile)=
# # PDBFile
#
# *Form adapter and capabilities for openmm.PDBFile.*
#
# - **Technical Form Name:** `openmm.PDBFile`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.openmm_PDBFile`
# :::
#
# ## Overview
#
# `openmm.PDBFile` is a supported representation form in MolSysMT. Form adapter and capabilities for openmm.PDBFile.

# %% [markdown]
# ## Supported attributes
#
# The `openmm.PDBFile` form container supports a total of **28 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Structural** | Coordinates & Conformations | `structure_id`, `coordinates` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Other Attributes | `atom_index` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.openmm_PDBFile` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.openmm_PDBFile.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `openmm.PDBFile` instance. |
# | {func}`~molsysmt.form.openmm_PDBFile.copy.copy` | Creates an independent deep copy of the `openmm.PDBFile` object in memory. |
# | {func}`~molsysmt.form.openmm_PDBFile.add.add` | Adds elements from another system into an existing `openmm.PDBFile` instance. |
# | {func}`~molsysmt.form.openmm_PDBFile.merge.merge` | Merges multiple systems into a single combined `openmm.PDBFile` object. |
# | {func}`~molsysmt.form.openmm_PDBFile.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.openmm_PDBFile.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.openmm_PDBFile.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.openmm_PDBFile.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.openmm_PDBFile.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.openmm_PDBFile.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `openmm.PDBFile`. |
# | {func}`~molsysmt.form.openmm_PDBFile.is_form.is_form` | Returns `True` if the provided object is an instance of `openmm.PDBFile`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.openmm_PDBFile`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `mdtraj.Trajectory` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_mdtraj_Trajectory.to_mdtraj_Trajectory` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Modeller` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_openmm_Modeller.to_openmm_Modeller` |
# | `openmm.PDBFile` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_openmm_PDBFile.to_openmm_PDBFile` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.openmm_PDBFile.to_openmm_Topology.to_openmm_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
