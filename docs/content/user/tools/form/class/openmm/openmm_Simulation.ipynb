# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_openmm_Simulation)=
# # Simulation
#
# *Form adapter and capabilities for openmm.Simulation.*
#
# - **Technical Form Name:** `openmm.Simulation`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.openmm_Simulation`
# :::
#
# ## Overview
#
# `openmm.Simulation` is a supported representation form in MolSysMT. Form adapter and capabilities for openmm.Simulation.

# %% [markdown]
# ## Supported attributes
#
# The `openmm.Simulation` form container supports a total of **56 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bonded_atoms`, `bonded_atom_pairs`, `inner_bonded_atoms`, `inner_bonded_atom_pairs`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `temperature` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.openmm_Simulation` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.openmm_Simulation.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `openmm.Simulation` instance. |
# | {func}`~molsysmt.form.openmm_Simulation.copy.copy` | Creates an independent deep copy of the `openmm.Simulation` object in memory. |
# | {func}`~molsysmt.form.openmm_Simulation.add.add` | Adds elements from another system into an existing `openmm.Simulation` instance. |
# | {func}`~molsysmt.form.openmm_Simulation.merge.merge` | Merges multiple systems into a single combined `openmm.Simulation` object. |
# | {func}`~molsysmt.form.openmm_Simulation.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.openmm_Simulation.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.openmm_Simulation.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.openmm_Simulation.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.openmm_Simulation.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.openmm_Simulation.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `openmm.Simulation`. |
# | {func}`~molsysmt.form.openmm_Simulation.is_form.is_form` | Returns `True` if the provided object is an instance of `openmm.Simulation`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.openmm_Simulation`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:pdb` | `file` | {func}`~molsysmt.form.openmm_Simulation.to_file_pdb.to_file_pdb` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.Context` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_openmm_Context.to_openmm_Context` |
# | `openmm.Modeller` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_openmm_Modeller.to_openmm_Modeller` |
# | `openmm.Simulation` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_openmm_Simulation.to_openmm_Simulation` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_openmm_Topology.to_openmm_Topology` |
# | `pdbfixer.PDBFixer` | `class` | {func}`~molsysmt.form.openmm_Simulation.to_pdbfixer_PDBFixer.to_pdbfixer_PDBFixer` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
