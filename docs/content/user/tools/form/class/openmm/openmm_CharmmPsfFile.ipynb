# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_openmm_CharmmPsfFile)=
# # CharmmPsfFile
#
# *Form adapter and capabilities for openmm.CharmmPsfFile.*
#
# - **Technical Form Name:** `openmm.CharmmPsfFile`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.openmm_CharmmPsfFile`
# :::
#
# ## Overview
#
# `openmm.CharmmPsfFile` is a supported representation form in MolSysMT. Form adapter and capabilities for openmm.CharmmPsfFile.

# %% [markdown]
# ## Supported attributes
#
# The `openmm.CharmmPsfFile` form container supports a total of **9 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Other Attributes | `atom_index` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.openmm_CharmmPsfFile` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `openmm.CharmmPsfFile` instance. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.copy.copy` | Creates an independent deep copy of the `openmm.CharmmPsfFile` object in memory. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.add.add` | Adds elements from another system into an existing `openmm.CharmmPsfFile` instance. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.merge.merge` | Merges multiple systems into a single combined `openmm.CharmmPsfFile` object. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.openmm_CharmmPsfFile.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.openmm_CharmmPsfFile.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.openmm_CharmmPsfFile.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.openmm_CharmmPsfFile.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `openmm.CharmmPsfFile`. |
# | {func}`~molsysmt.form.openmm_CharmmPsfFile.is_form.is_form` | Returns `True` if the provided object is an instance of `openmm.CharmmPsfFile`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.openmm_CharmmPsfFile`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.openmm_CharmmPsfFile.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.CharmmPsfFile` | `class` | {func}`~molsysmt.form.openmm_CharmmPsfFile.to_openmm_CharmmPsfFile.to_openmm_CharmmPsfFile` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.openmm_CharmmPsfFile.to_openmm_Topology.to_openmm_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
