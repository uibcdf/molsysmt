# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_openmm_GromacsGroFile)=
# # GromacsGroFile
#
# *Form adapter and capabilities for openmm.GromacsGroFile.*
#
# - **Technical Form Name:** `openmm.GromacsGroFile`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.openmm_GromacsGroFile`
# :::
#
# ## Overview
#
# `openmm.GromacsGroFile` is a supported representation form in MolSysMT. Form adapter and capabilities for openmm.GromacsGroFile.

# %% [markdown]
# ## Supported attributes
#
# The `openmm.GromacsGroFile` form container supports a total of **11 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups` |
# | **Structural** | Coordinates & Conformations | `coordinates`, `n_structures` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.openmm_GromacsGroFile` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.openmm_GromacsGroFile.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `openmm.GromacsGroFile` instance. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.copy.copy` | Creates an independent deep copy of the `openmm.GromacsGroFile` object in memory. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.add.add` | Adds elements from another system into an existing `openmm.GromacsGroFile` instance. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.merge.merge` | Merges multiple systems into a single combined `openmm.GromacsGroFile` object. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.openmm_GromacsGroFile.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.openmm_GromacsGroFile.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.openmm_GromacsGroFile.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.openmm_GromacsGroFile.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `openmm.GromacsGroFile`. |
# | {func}`~molsysmt.form.openmm_GromacsGroFile.is_form.is_form` | Returns `True` if the provided object is an instance of `openmm.GromacsGroFile`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.openmm_GromacsGroFile`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.openmm_GromacsGroFile.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.openmm_GromacsGroFile.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.openmm_GromacsGroFile.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `openmm.GromacsGroFile` | `class` | {func}`~molsysmt.form.openmm_GromacsGroFile.to_openmm_GromacsGroFile.to_openmm_GromacsGroFile` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
