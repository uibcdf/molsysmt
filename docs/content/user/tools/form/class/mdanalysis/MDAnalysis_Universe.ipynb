# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_MDAnalysis_Universe)=
# # Universe
#
# *Form adapter and capabilities for MDAnalysis.Universe.*
#
# - **Technical Form Name:** `MDAnalysis.Universe`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.MDAnalysis_Universe`
# :::
#
# ## Overview
#
# `MDAnalysis.Universe` is a supported representation form in MolSysMT. Form adapter and capabilities for MDAnalysis.Universe.

# %% [markdown]
# ## Supported attributes
#
# The `MDAnalysis.Universe` form container supports a total of **59 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type`, `formal_charge` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `connectivity_completeness`, `bond_index`, `bond_type`, `bond_order`, `fractional_bond_order`, `bond_is_aromatic`, `bond_evidence`, `bonded_atoms`, `n_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.MDAnalysis_Universe` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.MDAnalysis_Universe.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `MDAnalysis.Universe` instance. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.copy.copy` | Creates an independent deep copy of the `MDAnalysis.Universe` object in memory. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.add.add` | Adds elements from another system into an existing `MDAnalysis.Universe` instance. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.merge.merge` | Merges multiple systems into a single combined `MDAnalysis.Universe` object. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.MDAnalysis_Universe.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.MDAnalysis_Universe.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.MDAnalysis_Universe.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.MDAnalysis_Universe.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `MDAnalysis.Universe`. |
# | {func}`~molsysmt.form.MDAnalysis_Universe.is_form.is_form` | Returns `True` if the provided object is an instance of `MDAnalysis.Universe`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.MDAnalysis_Universe`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `MDAnalysis.Universe` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_MDAnalysis_Universe.to_MDAnalysis_Universe` |
# | `file:pdb` | `file` | {func}`~molsysmt.form.MDAnalysis_Universe.to_file_pdb.to_file_pdb` |
# | `mdtraj.Trajectory` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_mdtraj_Trajectory.to_mdtraj_Trajectory` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.MDAnalysis_Universe.to_nglview_NGLWidget.to_nglview_NGLWidget` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
