# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_MDAnalysis_topology_PDBParser)=
# # PDBParser
#
# *Form adapter and capabilities for MDAnalysis.topology.PDBParser.*
#
# - **Technical Form Name:** `MDAnalysis.topology.PDBParser`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.MDAnalysis_topology_PDBParser`
# :::
#
# ## Overview
#
# `MDAnalysis.topology.PDBParser` is a supported representation form in MolSysMT. Form adapter and capabilities for MDAnalysis.topology.PDBParser.

# %% [markdown]
# ## Supported attributes
#
# The `MDAnalysis.topology.PDBParser` form container supports a total of **0 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | — | — | No direct attributes exposed |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.MDAnalysis_topology_PDBParser` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `MDAnalysis.topology.PDBParser` instance. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.copy.copy` | Creates an independent deep copy of the `MDAnalysis.topology.PDBParser` object in memory. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.add.add` | Adds elements from another system into an existing `MDAnalysis.topology.PDBParser` instance. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.merge.merge` | Merges multiple systems into a single combined `MDAnalysis.topology.PDBParser` object. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.MDAnalysis_topology_PDBParser.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.MDAnalysis_topology_PDBParser.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.MDAnalysis_topology_PDBParser.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.MDAnalysis_topology_PDBParser.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `MDAnalysis.topology.PDBParser`. |
# | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.is_form.is_form` | Returns `True` if the provided object is an instance of `MDAnalysis.topology.PDBParser`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.MDAnalysis_topology_PDBParser`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `MDAnalysis.Topology` | `class` | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.to_MDAnalysis_Topology.to_MDAnalysis_Topology` |
# | `MDAnalysis.topology.PDBParser` | `class` | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.to_MDAnalysis_topology_PDBParser.to_MDAnalysis_topology_PDBParser` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.MDAnalysis_topology_PDBParser.to_molsysmt_Topology.to_molsysmt_Topology` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
