# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_molsysviewer_MolSysView)=
# # MolSysView
#
# *MolSysViewer visualization native object.*
#
# - **Technical Form Name:** `molsysviewer.MolSysView`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.molsysviewer_MolSysView`
# :::
#
# ## Overview
#
# `molsysviewer.MolSysView` is a supported representation form in MolSysMT. MolSysViewer visualization native object.

# %% [markdown]
# ## Supported attributes
#
# The `molsysviewer.MolSysView` form container supports a total of **73 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_type`, `bond_order`, `bonded_atoms`, `bonded_atom_pairs`, `inner_bonded_atoms`, `inner_bonded_atom_pairs`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `structure_chemical_state_index`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time`, `potential_energy`, `kinetic_energy`, `total_energy`, `temperature` |
# | **Structural** | Crystallographic & Bioassembly | `b_factor`, `alternate_location`, `occupancy`, `bioassembly`, `n_bioassemblies` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.molsysviewer_MolSysView` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.molsysviewer_MolSysView.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `molsysviewer.MolSysView` instance. |
# | {func}`~molsysmt.form.molsysviewer_MolSysView.copy.copy` | Creates an independent deep copy of the `molsysviewer.MolSysView` object in memory. |
# | {func}`~molsysmt.form.molsysviewer_MolSysView.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.molsysviewer_MolSysView.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.molsysviewer_MolSysView.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.molsysviewer_MolSysView.get_mechanical_attributes` | Module containing getters for mechanical attributes. |
# | {func}`~molsysmt.form.molsysviewer_MolSysView.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `molsysviewer.MolSysView`. |
# | {func}`~molsysmt.form.molsysviewer_MolSysView.is_form.is_form` | Returns `True` if the provided object is an instance of `molsysviewer.MolSysView`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.molsysviewer_MolSysView`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.molsysviewer_MolSysView.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysviewer.MolSysView` | `class` | {func}`~molsysmt.form.molsysviewer_MolSysView.to_molsysviewer_MolSysView.to_molsysviewer_MolSysView` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
