# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_nglview_NGLWidget)=
# # NGLWidget
#
# *Form adapter and capabilities for nglview.NGLWidget.*
#
# - **Technical Form Name:** `nglview.NGLWidget`
# - **Form Type:** `class`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.nglview_NGLWidget`
# :::
#
# ## Overview
#
# `nglview.NGLWidget` is a supported representation form in MolSysMT. Form adapter and capabilities for nglview.NGLWidget.

# %% [markdown]
# ## Supported attributes
#
# The `nglview.NGLWidget` form container supports a total of **69 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type`, `isotope` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_id`, `bond_type`, `bond_order`, `bonded_atoms`, `bonded_atom_pairs`, `inner_bonded_atoms`, `inner_bonded_atom_pairs`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Crystallographic & Bioassembly | `b_factor`, `alternate_location`, `bioassembly`, `n_bioassemblies` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.nglview_NGLWidget` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.nglview_NGLWidget.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `nglview.NGLWidget` instance. |
# | {func}`~molsysmt.form.nglview_NGLWidget.copy.copy` | Creates an independent deep copy of the `nglview.NGLWidget` object in memory. |
# | {func}`~molsysmt.form.nglview_NGLWidget.add.add` | Adds elements from another system into an existing `nglview.NGLWidget` instance. |
# | {func}`~molsysmt.form.nglview_NGLWidget.merge.merge` | Merges multiple systems into a single combined `nglview.NGLWidget` object. |
# | {func}`~molsysmt.form.nglview_NGLWidget.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.nglview_NGLWidget.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.nglview_NGLWidget.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.nglview_NGLWidget.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.nglview_NGLWidget.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.nglview_NGLWidget.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `nglview.NGLWidget`. |
# | {func}`~molsysmt.form.nglview_NGLWidget.is_form.is_form` | Returns `True` if the provided object is an instance of `nglview.NGLWidget`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.nglview_NGLWidget`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.nglview_NGLWidget.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.nglview_NGLWidget.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.nglview_NGLWidget.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.nglview_NGLWidget.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.nglview_NGLWidget.to_openmm_Topology.to_openmm_Topology` |
# | `string:amino_acids_1` | `string` | {func}`~molsysmt.form.nglview_NGLWidget.to_string_amino_acids_1.to_string_amino_acids_1` |
# | `string:amino_acids_3` | `string` | {func}`~molsysmt.form.nglview_NGLWidget.to_string_amino_acids_3.to_string_amino_acids_3` |
# | `string:pdb_text` | `string` | {func}`~molsysmt.form.nglview_NGLWidget.to_string_pdb_text.to_string_pdb_text` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
