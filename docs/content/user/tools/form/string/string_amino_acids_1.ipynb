# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_string_amino_acids_1)=
# # string:amino_acids_1
#
# *Form adapter and capabilities for string:amino_acids_1.*
#
# - **Technical Form Name:** `string:amino_acids_1`
# - **Form Type:** `string`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.string_amino_acids_1`
# :::
#
# ## Overview
#
# `string:amino_acids_1` is a supported representation form in MolSysMT. Form adapter and capabilities for string:amino_acids_1.

# %% [markdown]
# ## Supported attributes
#
# The `string:amino_acids_1` form container supports a total of **2 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Group Level | `group_index`, `group_name` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.string_amino_acids_1` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.string_amino_acids_1.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `string:amino_acids_1` instance. |
# | {func}`~molsysmt.form.string_amino_acids_1.copy.copy` | Creates an independent deep copy of the `string:amino_acids_1` object in memory. |
# | {func}`~molsysmt.form.string_amino_acids_1.add.add` | Adds elements from another system into an existing `string:amino_acids_1` instance. |
# | {func}`~molsysmt.form.string_amino_acids_1.merge.merge` | Merges multiple systems into a single combined `string:amino_acids_1` object. |
# | {func}`~molsysmt.form.string_amino_acids_1.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.string_amino_acids_1.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.string_amino_acids_1.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.string_amino_acids_1.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.string_amino_acids_1.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.string_amino_acids_1.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `string:amino_acids_1`. |
# | {func}`~molsysmt.form.string_amino_acids_1.is_form.is_form` | Returns `True` if the provided object is an instance of `string:amino_acids_1`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.string_amino_acids_1`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `biopython.Seq` | `class` | {func}`~molsysmt.form.string_amino_acids_1.to_biopython_Seq.to_biopython_Seq` |
# | `biopython.SeqRecord` | `class` | {func}`~molsysmt.form.string_amino_acids_1.to_biopython_SeqRecord.to_biopython_SeqRecord` |
# | `string:amino_acids_1` | `string` | {func}`~molsysmt.form.string_amino_acids_1.to_string_amino_acids_1.to_string_amino_acids_1` |
# | `string:amino_acids_3` | `string` | {func}`~molsysmt.form.string_amino_acids_1.to_string_amino_acids_3.to_string_amino_acids_3` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
