# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Form_string_pdb_id)=
# # string:pdb_id
#
# *Form adapter and capabilities for string:pdb_id.*
#
# - **Technical Form Name:** `string:pdb_id`
# - **Form Type:** `string`
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# - Form adapter module: {mod}`molsysmt.form.string_pdb_id`
# :::
#
# ## Overview
#
# `string:pdb_id` is a supported representation form in MolSysMT. Form adapter and capabilities for string:pdb_id.

# %% [markdown]
# ## Supported attributes
#
# The `string:pdb_id` form container supports a total of **67 attributes**:
#
# | Category | Subcategory / Level | Supported Attributes |
# |---|---|---|
# | **Topological** | Atom Level | `atom_index`, `atom_name`, `atom_id`, `atom_type`, `formal_charge` |
# | **Topological** | Group Level | `group_index`, `group_name`, `group_id`, `group_type` |
# | **Topological** | Component Level | `component_index`, `component_name`, `component_id`, `component_type` |
# | **Topological** | Chain Level | `chain_index`, `chain_name`, `chain_id`, `chain_type` |
# | **Topological** | Molecule Level | `molecule_index`, `molecule_name`, `molecule_id`, `molecule_type` |
# | **Topological** | Entity Level | `entity_index`, `entity_name`, `entity_id`, `entity_type` |
# | **Topological** | Bonds & Connectivity | `bond_index`, `bond_type`, `bond_order`, `bonded_atoms`, `inner_bonded_atoms`, `inner_bond_index`, `n_bonds`, `n_inner_bonds` |
# | **Topological** | Element Counts | `n_atoms`, `n_groups`, `n_components`, `n_chains`, `n_molecules`, `n_entities`, `n_bonds`, `n_inner_bonds`, `n_amino_acids`, `n_nucleotides`, `n_ions`, `n_waters`, `n_small_molecules`, `n_peptides`, `n_proteins`, `n_dnas`, `n_rnas`, `n_lipids`, `n_polysaccharides`, `n_saccharides` |
# | **Structural** | Coordinates & Conformations | `structure_index`, `structure_id`, `coordinates`, `velocities`, `n_structures` |
# | **Structural** | Periodic Box | `box`, `box_shape`, `box_angles`, `box_lengths`, `box_volume` |
# | **Structural** | Trajectory Metadata | `time` |
# | **Structural** | Crystallographic & Bioassembly | `b_factor`, `alternate_location`, `bioassembly`, `n_bioassemblies` |
# | **Structural** | Other Attributes | `atom_index`, `n_atoms` |
# | **Mechanical** | Force Field Parameters | `partial_charge` |

# %% [markdown]
# ## Implemented operations
#
# The form adapter module {mod}`molsysmt.form.string_pdb_id` implements the following functions and modules:
#
# | Function / Module | Description |
# |---|---|
# | {func}`~molsysmt.form.string_pdb_id.extract.extract` | Extracts a subset of atoms, groups, or structures into a new `string:pdb_id` instance. |
# | {func}`~molsysmt.form.string_pdb_id.copy.copy` | Creates an independent deep copy of the `string:pdb_id` object in memory. |
# | {func}`~molsysmt.form.string_pdb_id.add.add` | Adds elements from another system into an existing `string:pdb_id` instance. |
# | {func}`~molsysmt.form.string_pdb_id.merge.merge` | Merges multiple systems into a single combined `string:pdb_id` object. |
# | {func}`~molsysmt.form.string_pdb_id.append_structures.append_structures` | Appends new coordinate frames or trajectories to the structures container. |
# | {mod}`~molsysmt.form.string_pdb_id.get_topological_attributes` | Module containing getters for topological attributes. |
# | {mod}`~molsysmt.form.string_pdb_id.get_structural_attributes` | Module containing getters for structural attributes. |
# | {mod}`~molsysmt.form.string_pdb_id.set` | Module containing setters for updating coordinates, box dimensions, or attributes in-place. |
# | {mod}`~molsysmt.form.string_pdb_id.iterators` | Module providing iterators for streaming trajectory frames and structures. |
# | {func}`~molsysmt.form.string_pdb_id.has_attribute.has_attribute` | Checks whether a specific attribute name is supported by `string:pdb_id`. |
# | {func}`~molsysmt.form.string_pdb_id.is_form.is_form` | Returns `True` if the provided object is an instance of `string:pdb_id`. |
#
# :::{note}
# :class: dropdown
#
# Each form adapter in MolSysMT implements only the specific functions that are meaningful for its data model.
# :::

# %% [markdown]
# ## Supported conversions
#
# The following table lists all direct conversion functions implemented in {mod}`molsysmt.form.string_pdb_id`:
#
# | Target Form | Form Type | API Documentation |
# |---|---|---|
# | `file:bcif` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_bcif.to_file_bcif` |
# | `file:bcif.gz` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_bcif_gz.to_file_bcif_gz` |
# | `file:cif` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_cif.to_file_cif` |
# | `file:cif.gz` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_cif_gz.to_file_cif_gz` |
# | `file:fasta` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_fasta.to_file_fasta` |
# | `file:h5msm` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_h5msm.to_file_h5msm` |
# | `file:pdb` | `file` | {func}`~molsysmt.form.string_pdb_id.to_file_pdb.to_file_pdb` |
# | `mdtraj.Topology` | `class` | {func}`~molsysmt.form.string_pdb_id.to_mdtraj_Topology.to_mdtraj_Topology` |
# | `mdtraj.Trajectory` | `class` | {func}`~molsysmt.form.string_pdb_id.to_mdtraj_Trajectory.to_mdtraj_Trajectory` |
# | `mmcif.PdbxContainers.DataContainer` | `class` | {func}`~molsysmt.form.string_pdb_id.to_mmcif_PdbxContainers_DataContainer.to_mmcif_PdbxContainers_DataContainer` |
# | `molsysmt.MolSys` | `class` | {func}`~molsysmt.form.string_pdb_id.to_molsysmt_MolSys.to_molsysmt_MolSys` |
# | `molsysmt.Structures` | `class` | {func}`~molsysmt.form.string_pdb_id.to_molsysmt_Structures.to_molsysmt_Structures` |
# | `molsysmt.Topology` | `class` | {func}`~molsysmt.form.string_pdb_id.to_molsysmt_Topology.to_molsysmt_Topology` |
# | `nglview.NGLWidget` | `class` | {func}`~molsysmt.form.string_pdb_id.to_nglview_NGLWidget.to_nglview_NGLWidget` |
# | `openmm.Modeller` | `class` | {func}`~molsysmt.form.string_pdb_id.to_openmm_Modeller.to_openmm_Modeller` |
# | `openmm.PDBFile` | `class` | {func}`~molsysmt.form.string_pdb_id.to_openmm_PDBFile.to_openmm_PDBFile` |
# | `openmm.Topology` | `class` | {func}`~molsysmt.form.string_pdb_id.to_openmm_Topology.to_openmm_Topology` |
# | `pdbfixer.PDBFixer` | `class` | {func}`~molsysmt.form.string_pdb_id.to_pdbfixer_PDBFixer.to_pdbfixer_PDBFixer` |
# | `string:pdb_id` | `string` | {func}`~molsysmt.form.string_pdb_id.to_string_pdb_id.to_string_pdb_id` |
# | `string:pdb_text` | `string` | {func}`~molsysmt.form.string_pdb_id.to_string_pdb_text.to_string_pdb_text` |

# %% [markdown]
# :::{seealso}
# :class: dropdown
#
# **Foundations & Object Architecture:**
# - {ref}`user-foundations-molecular-system-definition`: The fundamental definition of a molecular system, forms, and attributes in MolSysMT.
# - {ref}`user-foundations-native-world-classes-molsysmt-molsys`: In-depth architectural guide on the native `molsysmt.MolSys` container.
# - {ref}`user-foundations-native-world-classes-molsysmt-topology`: Architectural specification of the native `Topology` object.
# - {ref}`user-foundations-native-world-classes-molsysmt-structures`: Architectural specification of the native `Structures` object.
#
# **Form Tools & Conversions:**
# - {ref}`Convert <Tutorial_Convert>`: Converting between any molecular system representations with {func}`molsysmt.basic.convert`.
# - {ref}`Get attributes <Tutorial_Form_Get_attributes>`: Querying all supported attributes for any form with {func}`molsysmt.form.get_attributes`.
# - {ref}`Has attribute <Tutorial_Form_Has_attribute>`: Testing attribute availability for a form with {func}`molsysmt.form.has_attribute`.
# :::
