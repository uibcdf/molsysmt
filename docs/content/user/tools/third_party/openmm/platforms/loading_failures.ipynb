# %%
import molsysmt as msm

# %% [markdown]
# # Loading failures

# %%
msm.thirds.openmm.platforms.loading_failures()
# Out:
# ('Error loading library /home/diego/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/plugins/libOpenMMHIP.so: libhiprtc.so.6: cannot open shared object file: No such file or directory', 'Error loading library /home/diego/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/plugins/libOpenMMRPMDHIP.so: libhiprtc.so.6: cannot open shared object file: No such file or directory', 'Error loading library /home/diego/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/plugins/libOpenMMDrudeHIP.so: libhiprtc.so.6: cannot open shared object file: No such file or directory', 'Error loading library /home/diego/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/plugins/libOpenMMAmoebaHIP.so: libhiprtc.so.6: cannot open shared object file: No such file or directory')
