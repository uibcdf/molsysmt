# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_covalent_paths)=
# # Get covalent paths
#
# *Finding paths of covalently bonded atoms matching specified element patterns.*
#
# The function {func}`molsysmt.topology.get_covalent_paths` identifies all linear sequences of covalently bonded atoms that match a specified pattern of atom names or element criteria.
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.topology.get_covalent_paths`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's show how to find covalent paths matching atom name patterns using TcTIM (PDB ID: 1TCD):

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['TcTIM']['1tcd.h5msm'], to_form='molsysmt.MolSys')

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %% [markdown]
# We inspect structural information with {func}`molsysmt.basic.info`:

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5e8e" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_e5e8e_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_e5e8e_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_e5e8e_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_e5e8e_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_e5e8e_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_e5e8e_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_e5e8e_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_e5e8e_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_e5e8e_level0_col8" class="col_heading level0 col8" >n_proteins</th>
#       <th id="T_e5e8e_level0_col9" class="col_heading level0 col9" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# We search for all 3-atom covalent paths matching the sequence `C -> N -> CA` using {func}`molsysmt.topology.get_covalent_paths`:

# %%
covalent_paths = msm.topology.get_covalent_paths(molsys, path=['atom_name=="C"', 'atom_name=="N"', 'atom_name=="CA"'])

# %%
covalent_paths.shape
# Out:
# (495, 3)

# %%
covalent_paths
# Out:
# array([[   2,    9,   10],
#        [  11,   16,   17],
#        [  18,   25,   26],
#        ...,
#        [3789, 3796, 3797],
#        [3798, 3801, 3802],
#        [3803, 3808, 3809]], shape=(495, 3))

# %% [markdown]
# We check the atom names along the first retrieved covalent path using {func}`molsysmt.basic.get`:

# %%
msm.get(molsys, element='atom', selection=covalent_paths[0], name=True)
# Out:
# ['C', 'N', 'CA']

# %% [markdown]
# ## Using multi-name atom selections
#
# Selection strings at each position can match multiple atom names:

# %%
covalent_paths = msm.topology.get_covalent_paths(molsys, path=['atom_name==["C", "N"]', 'atom_name=="CA"', 'atom_name=="C"'])

# %%
covalent_paths
# Out:
# array([[   0,    1,    2],
#        [   2,    1,    2],
#        [   9,   10,   11],
#        ...,
#        [3803, 3802, 3803],
#        [3808, 3809, 3810],
#        [3810, 3809, 3810]], shape=(994, 3))

# %%
msm.get(molsys, element='atom', selection=covalent_paths[0], name=True)
# Out:
# ['N', 'CA', 'C']

# %%
msm.get(molsys, element='atom', selection=covalent_paths[1], name=True)
# Out:
# ['C', 'CA', 'C']

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Convert <Tutorial_Convert>`: Convert molecular systems between different forms with {func}`molsysmt.basic.convert`.
# - {ref}`Info <Tutorial_Info>`: Inspect summary information of a molecular system with {func}`molsysmt.basic.info`.
# - {ref}`Get covalent paths <Tutorial_Get_covalent_paths>`: Find linear sequences of covalently bonded atoms matching patterns with {func}`molsysmt.topology.get_covalent_paths`.
# - {ref}`Get <Tutorial_Get>`: Retrieve attribute values from a molecular system with {func}`molsysmt.basic.get`.
# :::
