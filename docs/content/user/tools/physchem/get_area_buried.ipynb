# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Get_area_buried)=
# # Get area buried
#
# *Querying average buried surface area per residue upon protein folding.*
#
# The function {func}`molsysmt.physchem.get_area_buried` extracts tabulated values (in Å²) representing average area buried upon folding using reference experimental scales (Rose et al.).
#
# :::{versionadded} 1.0.0
# :::
#
# :::{admonition} API documentation
# :class: dropdown
#
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function: {func}`molsysmt.physchem.get_area_buried`.
# :::

# %% [markdown]
# ## Basic usage
#
# Let's retrieve the average buried area per residue for a protein structure:

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.systems['Trp-Cage']['1l2y.h5msm'])

# %% [markdown]
# :::{note} Demo Systems Catalog
# :class: dropdown
#
# This tutorial uses demonstration datasets provided by MolSysMT. To explore the full catalog of bundled systems, forms, and file paths, visit the {ref}`Demo Systems <user-foundations-entrance-demo-systems>` guide.
# :::

# %% [markdown]
# We query the tabulated buried area values using the Rose scale:

# %%
ab = msm.physchem.get_area_buried(molsys, element='group', definition='rose')
print('Average buried area (Rose, Å^2):\n', ab)
# Out:
# Average buried area (Rose, Å^2):
#  [103.3 164.1 177.7 158.  119.2 224.6 164.1 115.5  97.8  62.9  62.9  92.9
#   85.6  85.6  62.9 162.2  92.9  92.9  92.9  85.6]

# %% [markdown]
# :::{seealso} Related Tools & References
# :class: dropdown
#
# - {ref}`Convert <Tutorial_Convert>`: Convert molecular systems with {func}`molsysmt.basic.convert`.
# - {ref}`Get buried fraction <Tutorial_Get_buried_fraction>`: Query residue buried fractions with {func}`molsysmt.physchem.get_buried_fraction`.
# - {ref}`Get SASA <Tutorial_Get_sasa>`: Compute 3D solvent-accessible surface area with {func}`molsysmt.physchem.get_sasa`.
# :::
