# %% [markdown]
# (Introduction_Forms)=
# # Items and Forms

# %% [markdown]
# In MolSysMT, a fundamental distinction is made between a physical **item** and its data representation **form**:
#
# - **Item**: A concrete data container holding molecular information. An item can be a file path on disk (such as `'181l.bcif.gz'`), an in-memory Python object (such as an `mdtraj.Trajectory` instance), a web database identifier (such as `'181L'`), or a text string (such as an amino acid sequence).
# - **Form**: The standardized type tag or schema label that identifies how an item's data is structured (such as `'file:bcif'`, `'molsysmt.MolSys'`, `'mdtraj.Trajectory'`, `'string:pdb_id'`).
#
# Functions in MolSysMT inspect items dynamically to determine their form. You can query the form of any item using {func}`molsysmt.basic.get_form`:

# %%
import molsysmt as msm

item = msm.systems['T4 lysozyme L99A']['181l.bcif.gz']
msm.get_form(item)
# Out:
# 'file:bcif.gz'

# %% [markdown]
# ---
#
# ## Querying Supported Forms
#
# You can inspect all forms supported by your current environment using {func}`molsysmt.supported.forms`. Passing a specific `form_type` filters the catalog by category (`'file'`, `'class'`, or `'string'`):
#
# ```python
# # Query supported file forms
# msm.supported.forms(form_type='file')
#
# # Query supported Python class forms
# msm.supported.forms(form_type='class')
#
# # Query supported string and sequence forms
# msm.supported.forms(form_type='string')
# ```

# %% [markdown]
# ---
#
# ## Catalog of Supported Forms
#
# The tables below provide the complete reference of supported forms categorized by representation type.

# %% [markdown]
# ### Files
#
# File forms represent molecular structures, topologies, or trajectories stored in disk files.

# %%
import molsysmt as msm
msm.supported.forms(form_type='file')
# Out:
# <style type="text/css">
# #T_b1f93 th {
#   text-align: left !important;
# }
# #T_b1f93 td {
#   text-align: left !important;
# }
# #T_b1f93_row0_col0, #T_b1f93_row0_col1, #T_b1f93_row0_col2, #T_b1f93_row0_col3, #T_b1f93_row1_col0, #T_b1f93_row1_col1, #T_b1f93_row1_col2, #T_b1f93_row1_col3, #T_b1f93_row2_col0, #T_b1f93_row2_col1, #T_b1f93_row2_col2, #T_b1f93_row2_col3, #T_b1f93_row3_col0, #T_b1f93_row3_col1, #T_b1f93_row3_col2, #T_b1f93_row3_col3, #T_b1f93_row4_col0, #T_b1f93_row4_col1, #T_b1f93_row4_col2, #T_b1f93_row4_col3, #T_b1f93_row5_col0, #T_b1f93_row5_col1, #T_b1f93_row5_col2, #T_b1f93_row5_col3, #T_b1f93_row6_col0, #T_b1f93_row6_col1, #T_b1f93_row6_col2, #T_b1f93_row6_col3, #T_b1f93_row7_col0, #T_b1f93_row7_col1, #T_b1f93_row7_col2, #T_b1f93_row7_col3, #T_b1f93_row8_col0, #T_b1f93_row8_col1, #T_b1f93_row8_col2, #T_b1f93_row8_col3, #T_b1f93_row9_col0, #T_b1f93_row9_col1, #T_b1f93_row9_col2, #T_b1f93_row9_col3, #T_b1f93_row10_col0, #T_b1f93_row10_col1, #T_b1f93_row10_col2, #T_b1f93_row10_col3, #T_b1f93_row11_col0, #T_b1f93_row11_col1, #T_b1f93_row11_col2, #T_b1f93_row11_col3, #T_b1f93_row12_col0, #T_b1f93_row12_col1, #T_b1f93_row12_col2, #T_b1f93_row12_col3, #T_b1f93_row13_col0, #T_b1f93_row13_col1, #T_b1f93_row13_col2, #T_b1f93_row13_col3, #T_b1f93_row14_col0, #T_b1f93_row14_col1, #T_b1f93_row14_col2, #T_b1f93_row14_col3, #T_b1f93_row15_col0, #T_b1f93_row15_col1, #T_b1f93_row15_col2, #T_b1f93_row15_col3, #T_b1f93_row16_col0, #T_b1f93_row16_col1, #T_b1f93_row16_col2, #T_b1f93_row16_col3, #T_b1f93_row17_col0, #T_b1f93_row17_col1, #T_b1f93_row17_col2, #T_b1f93_row17_col3, #T_b1f93_row18_col0, #T_b1f93_row18_col1, #T_b1f93_row18_col2, #T_b1f93_row18_col3, #T_b1f93_row19_col0, #T_b1f93_row19_col1, #T_b1f93_row19_col2, #T_b1f93_row19_col3, #T_b1f93_row20_col0, #T_b1f93_row20_col1, #T_b1f93_row20_col2, #T_b1f93_row20_col3, #T_b1f93_row21_col0, #T_b1f93_row21_col1, #T_b1f93_row21_col2, #T_b1f93_row21_col3, #T_b1f93_row22_col0, #T_b1f93_row22_col1, #T_b1f93_row22_col2, #T_b1f93_row22_col3, #T_b1f93_row23_col0, #T_b1f93_row23_col1, #T_b1f93_row23_col2, #T_b1f93_row23_col3, #T_b1f93_row24_col0, #T_b1f93_row24_col1, #T_b1f93_row24_col2, #T_b1f93_row24_col3, #T_b1f93_row25_col0, #T_b1f93_row25_col1, #T_b1f93_row25_col2, #T_b1f93_row25_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_b1f93" class="table dataframe">
#   <thead>
#     <tr>
#       <th id="T_b1f93_level0_col0" class="col_heading level0 col0" >Form</th>
#       <th id="T_b1f93_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_b1f93_level0_col2" class="col_heading level0 col2" >Dependency</th>
#       <th id="T_b1f93_level0_col3" class="col_heading level0 col3" >Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1f93_row0_col0" class="data row0 col0" >file:bcif</td>
#       <td id="T_b1f93_row0_col1" class="data row0 col1" >file</td>
#       <td id="T_b1f93_row0_col2" class="data row0 col2" >Native</td>
#       <td id="T_b1f93_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row1_col0" class="data row1 col0" >file:bcif.gz</td>
#       <td id="T_b1f93_row1_col1" class="data row1 col1" >file</td>
#       <td id="T_b1f93_row1_col2" class="data row1 col2" >Native</td>
#       <td id="T_b1f93_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row2_col0" class="data row2 col0" >file:cif</td>
#       <td id="T_b1f93_row2_col1" class="data row2 col1" >file</td>
#       <td id="T_b1f93_row2_col2" class="data row2 col2" >Native</td>
#       <td id="T_b1f93_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row3_col0" class="data row3 col0" >file:cif.gz</td>
#       <td id="T_b1f93_row3_col1" class="data row3 col1" >file</td>
#       <td id="T_b1f93_row3_col2" class="data row3 col2" >Native</td>
#       <td id="T_b1f93_row3_col3" class="data row3 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row4_col0" class="data row4 col0" >file:crd</td>
#       <td id="T_b1f93_row4_col1" class="data row4 col1" >file</td>
#       <td id="T_b1f93_row4_col2" class="data row4 col2" >Native</td>
#       <td id="T_b1f93_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.charmmtutorial.org/index.php/CHARMM:The_Basics#CHARMM_data_structures">CHARMM card (CRD) file format with coordinates.</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row5_col0" class="data row5 col0" >file:dcd</td>
#       <td id="T_b1f93_row5_col1" class="data row5 col1" >file</td>
#       <td id="T_b1f93_row5_col2" class="data row5 col2" >mdtraj</td>
#       <td id="T_b1f93_row5_col3" class="data row5 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row6_col0" class="data row6 col0" >file:fasta</td>
#       <td id="T_b1f93_row6_col1" class="data row6 col1" >file</td>
#       <td id="T_b1f93_row6_col2" class="data row6 col2" >Native</td>
#       <td id="T_b1f93_row6_col3" class="data row6 col3" ><a target="_blank" href="https://en.wikipedia.org/wiki/FASTA_format">FASTA sequence file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row7_col0" class="data row7 col0" >file:gro</td>
#       <td id="T_b1f93_row7_col1" class="data row7 col1" >file</td>
#       <td id="T_b1f93_row7_col2" class="data row7 col2" >openmm</td>
#       <td id="T_b1f93_row7_col3" class="data row7 col3" ><a target="_blank" href="http://manual.gromacs.org/documentation/2018/user-guide/file-formats.html#gro">Gromacs gro file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row8_col0" class="data row8 col0" >file:h5</td>
#       <td id="T_b1f93_row8_col1" class="data row8 col1" >file</td>
#       <td id="T_b1f93_row8_col2" class="data row8 col2" >mdtraj</td>
#       <td id="T_b1f93_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row9_col0" class="data row9 col0" >file:h5msm</td>
#       <td id="T_b1f93_row9_col1" class="data row9 col1" >file</td>
#       <td id="T_b1f93_row9_col2" class="data row9 col2" >Native</td>
#       <td id="T_b1f93_row9_col3" class="data row9 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row10_col0" class="data row10 col0" >file:inpcrd</td>
#       <td id="T_b1f93_row10_col1" class="data row10 col1" >file</td>
#       <td id="T_b1f93_row10_col2" class="data row10 col2" >openmm</td>
#       <td id="T_b1f93_row10_col3" class="data row10 col3" ><a target="_blank" href="https://ambermd.org/FileFormats.php#trajectory">AMBER ASCII restart/inpcrd file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row11_col0" class="data row11 col0" >file:mdcrd</td>
#       <td id="T_b1f93_row11_col1" class="data row11 col1" >file</td>
#       <td id="T_b1f93_row11_col2" class="data row11 col2" >Native</td>
#       <td id="T_b1f93_row11_col3" class="data row11 col3" ><a target="_blank" href="https://ambermd.org/FileFormats.php#trajectory">AMBER MDCRD coordinate/trajectory file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row12_col0" class="data row12 col0" >file:mol2</td>
#       <td id="T_b1f93_row12_col1" class="data row12 col1" >file</td>
#       <td id="T_b1f93_row12_col2" class="data row12 col2" >parmed</td>
#       <td id="T_b1f93_row12_col3" class="data row12 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row13_col0" class="data row13 col0" >file:molsys_yaml</td>
#       <td id="T_b1f93_row13_col1" class="data row13 col1" >file</td>
#       <td id="T_b1f93_row13_col2" class="data row13 col2" >yaml</td>
#       <td id="T_b1f93_row13_col3" class="data row13 col3" >Human-authored declarative YAML molecular system file.</td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row14_col0" class="data row14 col0" >file:pdb</td>
#       <td id="T_b1f93_row14_col1" class="data row14 col1" >file</td>
#       <td id="T_b1f93_row14_col2" class="data row14 col2" >Native</td>
#       <td id="T_b1f93_row14_col3" class="data row14 col3" ><a target="_blank" href="https://www.rcsb.org/pdb/static.do?p=file_formats/pdb/index.html">Protein Data Bank file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_b1f93_row15_col0" class="data row15 col0" >file:pir</td>
#       <td

# %% [markdown]
# ### Classes
#
# Class forms represent in-memory Python objects from third-party libraries (such as MDTraj, PyTraj, MDAnalysis, OpenMM, and ParmEd) as well as native MolSysMT classes.

# %%
import molsysmt as msm
msm.supported.forms(form_type='class')
# Out:
# <style type="text/css">
# #T_5d97e th {
#   text-align: left !important;
# }
# #T_5d97e td {
#   text-align: left !important;
# }
# #T_5d97e_row0_col0, #T_5d97e_row0_col1, #T_5d97e_row0_col2, #T_5d97e_row0_col3, #T_5d97e_row1_col0, #T_5d97e_row1_col1, #T_5d97e_row1_col2, #T_5d97e_row1_col3, #T_5d97e_row2_col0, #T_5d97e_row2_col1, #T_5d97e_row2_col2, #T_5d97e_row2_col3, #T_5d97e_row3_col0, #T_5d97e_row3_col1, #T_5d97e_row3_col2, #T_5d97e_row3_col3, #T_5d97e_row4_col0, #T_5d97e_row4_col1, #T_5d97e_row4_col2, #T_5d97e_row4_col3, #T_5d97e_row5_col0, #T_5d97e_row5_col1, #T_5d97e_row5_col2, #T_5d97e_row5_col3, #T_5d97e_row6_col0, #T_5d97e_row6_col1, #T_5d97e_row6_col2, #T_5d97e_row6_col3, #T_5d97e_row7_col0, #T_5d97e_row7_col1, #T_5d97e_row7_col2, #T_5d97e_row7_col3, #T_5d97e_row8_col0, #T_5d97e_row8_col1, #T_5d97e_row8_col2, #T_5d97e_row8_col3, #T_5d97e_row9_col0, #T_5d97e_row9_col1, #T_5d97e_row9_col2, #T_5d97e_row9_col3, #T_5d97e_row10_col0, #T_5d97e_row10_col1, #T_5d97e_row10_col2, #T_5d97e_row10_col3, #T_5d97e_row11_col0, #T_5d97e_row11_col1, #T_5d97e_row11_col2, #T_5d97e_row11_col3, #T_5d97e_row12_col0, #T_5d97e_row12_col1, #T_5d97e_row12_col2, #T_5d97e_row12_col3, #T_5d97e_row13_col0, #T_5d97e_row13_col1, #T_5d97e_row13_col2, #T_5d97e_row13_col3, #T_5d97e_row14_col0, #T_5d97e_row14_col1, #T_5d97e_row14_col2, #T_5d97e_row14_col3, #T_5d97e_row15_col0, #T_5d97e_row15_col1, #T_5d97e_row15_col2, #T_5d97e_row15_col3, #T_5d97e_row16_col0, #T_5d97e_row16_col1, #T_5d97e_row16_col2, #T_5d97e_row16_col3, #T_5d97e_row17_col0, #T_5d97e_row17_col1, #T_5d97e_row17_col2, #T_5d97e_row17_col3, #T_5d97e_row18_col0, #T_5d97e_row18_col1, #T_5d97e_row18_col2, #T_5d97e_row18_col3, #T_5d97e_row19_col0, #T_5d97e_row19_col1, #T_5d97e_row19_col2, #T_5d97e_row19_col3, #T_5d97e_row20_col0, #T_5d97e_row20_col1, #T_5d97e_row20_col2, #T_5d97e_row20_col3, #T_5d97e_row21_col0, #T_5d97e_row21_col1, #T_5d97e_row21_col2, #T_5d97e_row21_col3, #T_5d97e_row22_col0, #T_5d97e_row22_col1, #T_5d97e_row22_col2, #T_5d97e_row22_col3, #T_5d97e_row23_col0, #T_5d97e_row23_col1, #T_5d97e_row23_col2, #T_5d97e_row23_col3, #T_5d97e_row24_col0, #T_5d97e_row24_col1, #T_5d97e_row24_col2, #T_5d97e_row24_col3, #T_5d97e_row25_col0, #T_5d97e_row25_col1, #T_5d97e_row25_col2, #T_5d97e_row25_col3, #T_5d97e_row26_col0, #T_5d97e_row26_col1, #T_5d97e_row26_col2, #T_5d97e_row26_col3, #T_5d97e_row27_col0, #T_5d97e_row27_col1, #T_5d97e_row27_col2, #T_5d97e_row27_col3, #T_5d97e_row28_col0, #T_5d97e_row28_col1, #T_5d97e_row28_col2, #T_5d97e_row28_col3, #T_5d97e_row29_col0, #T_5d97e_row29_col1, #T_5d97e_row29_col2, #T_5d97e_row29_col3, #T_5d97e_row30_col0, #T_5d97e_row30_col1, #T_5d97e_row30_col2, #T_5d97e_row30_col3, #T_5d97e_row31_col0, #T_5d97e_row31_col1, #T_5d97e_row31_col2, #T_5d97e_row31_col3, #T_5d97e_row32_col0, #T_5d97e_row32_col1, #T_5d97e_row32_col2, #T_5d97e_row32_col3, #T_5d97e_row33_col0, #T_5d97e_row33_col1, #T_5d97e_row33_col2, #T_5d97e_row33_col3, #T_5d97e_row34_col0, #T_5d97e_row34_col1, #T_5d97e_row34_col2, #T_5d97e_row34_col3, #T_5d97e_row35_col0, #T_5d97e_row35_col1, #T_5d97e_row35_col2, #T_5d97e_row35_col3, #T_5d97e_row36_col0, #T_5d97e_row36_col1, #T_5d97e_row36_col2, #T_5d97e_row36_col3, #T_5d97e_row37_col0, #T_5d97e_row37_col1, #T_5d97e_row37_col2, #T_5d97e_row37_col3, #T_5d97e_row38_col0, #T_5d97e_row38_col1, #T_5d97e_row38_col2, #T_5d97e_row38_col3, #T_5d97e_row39_col0, #T_5d97e_row39_col1, #T_5d97e_row39_col2, #T_5d97e_row39_col3, #T_5d97e_row40_col0, #T_5d97e_row40_col1, #T_5d97e_row40_col2, #T_5d97e_row40_col3, #T_5d97e_row41_col0, #T_5d97e_row41_col1, #T_5d97e_row41_col2, #T_5d97e_row41_col3, #T_5d97e_row42_col0, #T_5d97e_row42_col1, #T_5d97e_row42_col2, #T_5d97e_row42_col3, #T_5d97e_row43_col0, #T_5d97e_row43_col1, #T_5d97e_row43_col2, #T_5d97e_row43_col3, #T_5d97e_row44_col0, #T_5d97e_row44_col1, #T_5d97e_row44_col2, #T_5d97e_row44_col3, #T_5d97e_row45_col0, #T_5d97e_row45_col1, #T_5d97e_row45_col2, #T_5d97e_row45_col3, #T_5d97e_row46_col0, #T_5d97e_row46_col1, #T_5d97e_row46_col2, #T_5d97e_row46_col3, #T_5d97e_row47_col0, #T_5d97e_row47_col1, #T_5d97e_row47_col2, #T_5d97e_row47_col3, #T_5d97e ...
#   text-align: left;
# }
# </style>
# <table id="T_5d97e" class="table dataframe">
#   <thead>
#     <tr>
#       <th id="T_5d97e_level0_col0" class="col_heading level0 col0" >Form</th>
#       <th id="T_5d97e_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_5d97e_level0_col2" class="col_heading level0 col2" >Dependency</th>
#       <th id="T_5d97e_level0_col3" class="col_heading level0 col3" >Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d97e_row0_col0" class="data row0 col0" >biopython.PDBStructure</td>
#       <td id="T_5d97e_row0_col1" class="data row0 col1" >class</td>
#       <td id="T_5d97e_row0_col2" class="data row0 col2" >Bio</td>
#       <td id="T_5d97e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row1_col0" class="data row1 col0" >biopython.Seq</td>
#       <td id="T_5d97e_row1_col1" class="data row1 col1" >class</td>
#       <td id="T_5d97e_row1_col2" class="data row1 col2" >Bio</td>
#       <td id="T_5d97e_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row2_col0" class="data row2 col0" >biopython.SeqRecord</td>
#       <td id="T_5d97e_row2_col1" class="data row2 col1" >class</td>
#       <td id="T_5d97e_row2_col2" class="data row2 col2" >Bio</td>
#       <td id="T_5d97e_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row3_col0" class="data row3 col0" >cupy_ndarray</td>
#       <td id="T_5d97e_row3_col1" class="data row3 col1" >class</td>
#       <td id="T_5d97e_row3_col2" class="data row3 col2" >cupy</td>
#       <td id="T_5d97e_row3_col3" class="data row3 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row4_col0" class="data row4 col0" >MDAnalysis.AtomGroup</td>
#       <td id="T_5d97e_row4_col1" class="data row4 col1" >class</td>
#       <td id="T_5d97e_row4_col2" class="data row4 col2" >MDAnalysis</td>
#       <td id="T_5d97e_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row5_col0" class="data row5 col0" >MDAnalysis.Topology</td>
#       <td id="T_5d97e_row5_col1" class="data row5 col1" >class</td>
#       <td id="T_5d97e_row5_col2" class="data row5 col2" >MDAnalysis</td>
#       <td id="T_5d97e_row5_col3" class="data row5 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row6_col0" class="data row6 col0" >MDAnalysis.topology.PDBParser</td>
#       <td id="T_5d97e_row6_col1" class="data row6 col1" >class</td>
#       <td id="T_5d97e_row6_col2" class="data row6 col2" >MDAnalysis</td>
#       <td id="T_5d97e_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row7_col0" class="data row7 col0" >MDAnalysis.Universe</td>
#       <td id="T_5d97e_row7_col1" class="data row7 col1" >class</td>
#       <td id="T_5d97e_row7_col2" class="data row7 col2" >MDAnalysis</td>
#       <td id="T_5d97e_row7_col3" class="data row7 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row8_col0" class="data row8 col0" >mdtraj.AmberRestartFile</td>
#       <td id="T_5d97e_row8_col1" class="data row8 col1" >class</td>
#       <td id="T_5d97e_row8_col2" class="data row8 col2" >mdtraj</td>
#       <td id="T_5d97e_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_5d97e_row9_col0" class="data

# %% [markdown]
# ### Strings and Sequences
#
# String forms represent character strings including web database accessions (such as `'pdb:id'`, `'uniprot:id'`), raw record text (such as `'string:pdb_text'`), and sequence strings (such as `'string:amino_acids_1'`).

# %%
import molsysmt as msm
msm.supported.forms(form_type='string')
# Out:
# <style type="text/css">
# #T_93fb9 th {
#   text-align: left !important;
# }
# #T_93fb9 td {
#   text-align: left !important;
# }
# #T_93fb9_row0_col0, #T_93fb9_row0_col1, #T_93fb9_row0_col2, #T_93fb9_row0_col3, #T_93fb9_row1_col0, #T_93fb9_row1_col1, #T_93fb9_row1_col2, #T_93fb9_row1_col3, #T_93fb9_row2_col0, #T_93fb9_row2_col1, #T_93fb9_row2_col2, #T_93fb9_row2_col3, #T_93fb9_row3_col0, #T_93fb9_row3_col1, #T_93fb9_row3_col2, #T_93fb9_row3_col3, #T_93fb9_row4_col0, #T_93fb9_row4_col1, #T_93fb9_row4_col2, #T_93fb9_row4_col3, #T_93fb9_row5_col0, #T_93fb9_row5_col1, #T_93fb9_row5_col2, #T_93fb9_row5_col3, #T_93fb9_row6_col0, #T_93fb9_row6_col1, #T_93fb9_row6_col2, #T_93fb9_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_93fb9" class="table dataframe">
#   <thead>
#     <tr>
#       <th id="T_93fb9_level0_col0" class="col_heading level0 col0" >Form</th>
#       <th id="T_93fb9_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_93fb9_level0_col2" class="col_heading level0 col2" >Dependency</th>
#       <th id="T_93fb9_level0_col3" class="col_heading level0 col3" >Info</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93fb9_row0_col0" class="data row0 col0" >string:alphafold_id</td>
#       <td id="T_93fb9_row0_col1" class="data row0 col1" >string</td>
#       <td id="T_93fb9_row0_col2" class="data row0 col2" >Native</td>
#       <td id="T_93fb9_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row1_col0" class="data row1 col0" >string:amino_acids_1</td>
#       <td id="T_93fb9_row1_col1" class="data row1 col1" >string</td>
#       <td id="T_93fb9_row1_col2" class="data row1 col2" >Native</td>
#       <td id="T_93fb9_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row2_col0" class="data row2 col0" >string:amino_acids_3</td>
#       <td id="T_93fb9_row2_col1" class="data row2 col1" >string</td>
#       <td id="T_93fb9_row2_col2" class="data row2 col2" >Native</td>
#       <td id="T_93fb9_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row3_col0" class="data row3 col0" >string:pdb_id</td>
#       <td id="T_93fb9_row3_col1" class="data row3 col1" >string</td>
#       <td id="T_93fb9_row3_col2" class="data row3 col2" >Native</td>
#       <td id="T_93fb9_row3_col3" class="data row3 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row4_col0" class="data row4 col0" >string:pdb_text</td>
#       <td id="T_93fb9_row4_col1" class="data row4 col1" >string</td>
#       <td id="T_93fb9_row4_col2" class="data row4 col2" >Native</td>
#       <td id="T_93fb9_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.rcsb.org/pdb/static.do?p=file_formats/pdb/index.html">Protein Data Bank file format</a></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row5_col0" class="data row5 col0" >string:smiles</td>
#       <td id="T_93fb9_row5_col1" class="data row5 col1" >string</td>
#       <td id="T_93fb9_row5_col2" class="data row5 col2" >rdkit</td>
#       <td id="T_93fb9_row5_col3" class="data row5 col3" ><a target="_blank" href="https://en.wikipedia.org/wiki/Simplified_molecular-input_line-entry_system">SMILES (Simplified Molecular Input Line Entry System) string</a></td>
#     </tr>
#     <tr>
#       <td id="T_93fb9_row6_col0" class="data row6 col0" >string:uniprot_id</td>
#       <td id="T_93fb9_row6_col1" class="data row6 col1" >string</td>
#       <td id="T_93fb9_row6_col2" class="data row6 col2" >Native</td>
#       <td id="T_93fb9_row6_col3" class="data row6 col3" ><a target="_blank" href="https://www.uniprot.org/">UniProt accession number string</a></td>
#     </tr>
#   </tbody>
# </table>
