# %% [markdown]
# (user-foundations-entrance-demo-systems)=
# # Demo Systems Catalog
#
# MolSysMT includes a built-in collection of pre-packaged molecular systems accessible via `molsysmt.systems`. These datasets are bundled directly with the library to enable offline testing, hands-on tutorials, benchmarks, and reproducible recipes without relying on external network downloads.
#
# This page serves as the authoritative reference for all bundled demo systems referenced throughout the **User Guide**, **Cookbook**, **Showcase**, and **Master Course**.

# %% [markdown]
# ---
#
# ## How to Access Demo Systems
#
# All demo systems are stored in a nested dictionary structure inside `molsysmt.systems`, where top-level keys represent system names (such as `'Trp-Cage'`) and inner keys represent available file names (such as `'1l2y.h5msm'`).
#
# ### 1. Listing Available Systems
# You can list all bundled system keys in Python:
#
# ```python
# import molsysmt as msm
# print(list(msm.systems.keys()))
# ```
#
# ### 2. Accessing a System File Path
# To retrieve the absolute `Path` of a specific file:
#
# ```python
# file_path = msm.systems['Trp-Cage']['1l2y.h5msm']
# ```
#
# ### 3. Loading a System Directly into MolSysMT
# You can pass the dictionary item directly into `msm.convert()` or any other tool function:
#
# ```python
# molsys = msm.convert(msm.systems['Trp-Cage']['1l2y.h5msm'])
# ```

# %%
import molsysmt as msm

# Load a demo system into canonical 'molsys' variable and inspect basic attributes
molsys = msm.convert(msm.systems['Trp-Cage']['1l2y.h5msm'])
n_atoms, n_groups, n_structures = msm.get(molsys, n_atoms=True, n_groups=True, n_structures=True)

print(f"Trp-Cage loaded into molsys: {n_atoms} atoms, {n_groups} residues, {n_structures} structure(s).")
# Out:
# Trp-Cage loaded into molsys: 304 atoms, 20 residues, 38 structure(s).

# %% [markdown]
# ---
#
# ## Complete Catalog of Bundled Systems
#
# Below is the complete catalog of pre-packaged datasets organized by molecular category. Use the dictionary **Key** and any file from **Files Included** to access the corresponding dataset (e.g. `msm.systems['Trp-Cage']['1l2y.h5msm']`).

# %%
import pandas as pd
import molsysmt as msm
from IPython.display import HTML, display

for category_name, system_names in msm.systems.categories.items():
    rows = []
    for system_name in sorted(system_names):
        files = msm.systems[system_name]
        info = msm.systems.info.get(system_name, {})
        file_list = "<br>".join(f"<code>'{f}'</code>" for f in sorted(files.keys()))
        description = info.get('description', '')
        
        rows.append({
            "Key": f"<code>'{system_name}'</code>",
            "Description": description,
            "Files Included": file_list
        })
    
    df = pd.DataFrame(rows)
    display(HTML(f"<h3>{category_name}</h3>"))
    display(HTML(df.to_html(escape=False, index=False)))
    display(HTML("<br>"))
# Out:
# <h3>Dipeptides & Small Peptides</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'Met-enkephalin'</code></td>
#       <td>Pentapeptide neurotransmitter Met-enkephalin (PDB and H5MSM).</td>
#       <td><code>'met_enkephalin.h5msm'</code><br><code>'met_enkephalin.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'alanine dipeptide'</code></td>
#       <td>Alanine dipeptide (ACE-ALA-NME) benchmark system in H5MSM format.</td>
#       <td><code>'alanine_dipeptide.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'lysine dipeptide'</code></td>
#       <td>Lysine dipeptide in H5MSM format.</td>
#       <td><code>'lysine_dipeptide.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'pentalanine'</code></td>
#       <td>Pentalanine peptide in Amber prmtop/inpcrd and trajectory formats.</td>
#       <td><code>'pentalanine.inpcrd'</code><br><code>'pentalanine.prmtop'</code><br><code>'traj_pentalanine.h5'</code><br><code>'traj_pentalanine.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'proline dipeptide'</code></td>
#       <td>Proline dipeptide in H5MSM format.</td>
#       <td><code>'proline_dipeptide.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'valine dipeptide'</code></td>
#       <td>Valine dipeptide in H5MSM format.</td>
#       <td><code>'valine_dipeptide.h5msm'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>
# <h3>Small & Globular Proteins</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'Hexokinase 2'</code></td>
#       <td>Human Hexokinase 2 enzyme (PDB 2NZT).</td>
#       <td><code>'2nzt.bcif.gz'</code><br><code>'2nzt.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'T4 lysozyme L99A'</code></td>
#       <td>T4 Lysozyme L99A mutant cavity system (PDB 181L, 1L17).</td>
#       <td><code>'181l.bcif.gz'</code><br><code>'181l.h5msm'</code><br><code>'181l.pdb'</code><br><code>'1l17.h5msm'</code><br><code>'1l17.pdb'</code><br><code>'t4_lysozyme_L99A.h5msm'</code></td>
#     </tr>
#     <tr>
#       <td><code>'TcTIM'</code></td>
#       <td>Trypanosoma cruzi Triosephosphate Isomerase (PDB 1TCD).</td>
#       <td><code>'1tcd.bcif.gz'</code><br><code>'1tcd.h5msm'</code><br><code>'1tcd.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'Trp-Cage'</code></td>
#       <td>20-residue synthetic mini-protein Trp-Cage TC5b (PDB 1L2Y).</td>
#       <td><code>'1l2y.bcif.gz'</code><br><code>'1l2y.h5msm'</code><br><code>'1l2y.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'chicken villin HP35'</code></td>
#       <td>Villin headpiece subdomain HP35 (PDB 1VII), solvated structure and DCD trajectory.</td>
#       <td><code>'1vii.bcif'</code><br><code>'1vii.bcif.gz'</code><br><code>'1vii.pdb'</code><br><code>'chicken_villin_HP35.h5msm'</code><br><code>'chicken_villin_HP35_solvated.h5msm'</code><br><code>'traj_chicken_villin_HP35_solvated.dcd'</code><br><code>'traj_chicken_villin_HP35_solvated.h5'</code><br><code>'traj_chicken_villin_HP35_solvated.h5msm'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>
# <h3>Complexes & Assemblies</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'1ATP'</code></td>
#       <td>cAMP-dependent protein kinase catalytic subunit complex (PDB 1ATP).</td>
#       <td><code>'1atp.bcif.gz'</code><br><code>'1atp.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'1CEN'</code></td>
#       <td>Centromere protein B DNA-binding domain (PDB 1CEN).</td>
#       <td><code>'1cen.bcif.gz'</code><br><code>'1cen.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'1YCR'</code></td>
#       <td>MDM2 bound to p53 transactivation domain peptide (PDB 1YCR).</td>
#       <td><code>'1ycr.bcif.gz'</code><br><code>'1ycr.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'2HGR'</code></td>
#       <td>Ribosome structural benchmark dataset (PDB 2HGR).</td>
#       <td><code>'2hgr.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'4V4Z'</code></td>
#       <td>Thermus thermophilus 70S ribosome assembly (PDB 4V4Z, 149,640 atoms).</td>
#       <td><code>'4v4z.bcif.gz'</code><br><code>'4v4z_openmm.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'Barnase-Barstar'</code></td>
#       <td>Ribonuclease Barnase bound to inhibitor Barstar (PDB 1BRS).</td>
#       <td><code>'1brs.bcif'</code><br><code>'1brs.bcif.gz'</code><br><code>'1brs.h5msm'</code><br><code>'barnase_barstar.h5msm'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>
# <h3>Small Molecules & Ligands</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'benzamidine'</code></td>
#       <td>Benzamidine aromatic ligand (PDB format).</td>
#       <td><code>'benzamidine.pdb'</code></td>
#     </tr>
#     <tr>
#       <td><code>'caffeine'</code></td>
#       <td>Caffeine small molecule (MOL2 format).</td>
#       <td><code>'caffeine.mol2'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>
# <h3>Lipids & Membranes</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'POPC'</code></td>
#       <td>Single POPC lipid molecule (CHARMM PSF/CRD).</td>
#       <td><code>'popc.crd'</code><br><code>'popc.psf'</code></td>
#     </tr>
#     <tr>
#       <td><code>'POPC membrane'</code></td>
#       <td>Hydrated POPC lipid bilayer membrane simulation trajectory (CHARMM PSF and DCD).</td>
#       <td><code>'popc_membrane.dcd'</code><br><code>'popc_membrane.psf'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>
# <h3>Toy & Synthetic Models</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Key</th>
#       <th>Description</th>
#       <th>Files Included</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><code>'nglview'</code></td>
#       <td>Test files for NGLView and MDTraj integration (ala3, md_1u19 GRO/XTC/TRR).</td>
#       <td><code>'ala3.pdb'</code><br><code>'md_1u19.gro'</code><br><code>'md_1u19.pdb'</code><br><code>'md_1u19.traj'</code><br><code>'md_1u19.trr'</code><br><code>'md_1u19.xtc'</code></td>
#     </tr>
#     <tr>
#       <td><code>'particles 4'</code></td>
#       <td>4-particle spatial trajectory in XYZ NumPy format.</td>
#       <td><code>'traj_particles_4.xyznpy'</code></td>
#     </tr>
#     <tr>
#       <td><code>'two LJ particles'</code></td>
#       <td>Two Lennard-Jones particles toy trajectory.</td>
#       <td><code>'traj_two_lj_particles.trjpk'</code></td>
#     </tr>
#   </tbody>
# </table>
# <br>

# %% [markdown]
# ---
#
# :::{admonition} Offline Accessibility
# :class: tip
# All datasets in `molsysmt.systems` are pre-packaged with the library. You can run all tutorials and test suites completely offline without requiring internet access.
# :::
