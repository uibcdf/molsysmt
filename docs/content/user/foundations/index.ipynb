# %% [markdown]
# # User Guide Foundations
#
# Welcome to the **Foundations** of MolSysMT. This section defines the constitutional principles, the physical rules, and the high-performance engineering that power our framework.
#
# ---

# %% [markdown]
# ::::{grid} 1 2 4
# :gutter: 3
#
# :::{grid-item-card} 🚪 1. The Entrance
# :link: ./01_entrance/molsysmt_mission.ipynb
# :link-type: rel
#
# Mission, **MolSysSuite**, Installation, and **Demo Systems**.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} ⚛️ 2. The Molecular System
# :link: ./02_molecular_system/definition.ipynb
# :link-type: rel
#
# **The Trinity**, Hierarchy (Elements), and **Attributes**.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} ⚡ 3. The Native World
# :link: ./03_native_world/molsysmt_MolSys.ipynb
# :link-type: rel
#
# Native forms: **MolSys**, **H5MSM**, and optimized Dicts.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} 🗣️ 4. The Language
# :link: ./04_language/selection_grammar.ipynb
# :link-type: rel
#
# Master the **Selection Language** for human-to-atom communication.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} 🚀 5. Performance
# :link: ./05_performance/memory_management.ipynb
# :link-type: rel
#
# Scaling to Big Data: **Memory**, **Parallelization**, and **Lazy Loading**.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} ⚖️ 6. Governance
# :link: ./06_governance/quantities_and_units.ipynb
# :link-type: rel
#
# Rules: **Units**, **Precision**, **SMonitor**, and **Tests Coverage**.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} 🛠️ 7. Support & Coverage
# :link: ./07_support/supported_forms_and_libraries.ipynb
# :link-type: rel
#
# Agnostic Matrix: **Supported Forms**, Force Fields, and Atom Types.
# ^^^
# Explore →
# :::
#
# :::{grid-item-card} 🌍 8. The Ecosystem
# :link: ./08_ecosystem/viewers.ipynb
# :link-type: rel
#
# Diplomacy: **Third-party Bridges** and the **MolSysViewer** suite.
# ^^^
# Explore →
# :::
#
# ::::

# %% [markdown]
# ---
#
# ```{key-takeaway}
# Foundations are the difference between using a tool and mastering an ecosystem. Every API choice follows these 8 pillars.
# ```
