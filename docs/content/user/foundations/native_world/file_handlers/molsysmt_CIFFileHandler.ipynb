# %% [markdown]
# (Introduction_molsysmt_CIFFileHandler)=
# # molsysmt.CIFFileHandler
#
# The  form represents a native file handler for reading and writing Macromolecular Crystallographic Information Files (mmCIF).
