# %% [markdown]
# (Introduction_molsysmt_Structures)=
# # molsysmt.Structures
#
# The  form represents a native structures data container storing 3D atomic coordinates, periodic boxes, and trajectory frames.
