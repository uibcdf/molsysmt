# %% [markdown]
# (Introduction_molsysmt_MolSysBuilder)=
# # molsysmt.MolSysBuilder
#
# The  form represents an editable native container for incrementally constructing and modifying molecular models.
