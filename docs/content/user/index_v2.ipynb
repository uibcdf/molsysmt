# %% [markdown]
# # **User Guide**
#
# Welcome to the MolSysMT User Guide. This portal is designed to take you from first contact to structural modeling mastery. Explore our showcases, master our architectural foundations, browse the toolbox, or follow practical recipes.
#
# ---
#
# ## **Featured Pathway**
#
# ::::{grid} 1
# :gutter: 3
#
# :::{grid-item-card} 🚀 **Quickstart Guide & Showcases**
# :link: ../showcase/quickstart.ipynb
# :link-type: rel
#
# New to MolSysMT? Start here with a hands-on walk through the core capabilities, stunning 3D visualizations, and dynamic selections that make MolSysMT unique.
# ^^^
# Launch Quickstart →
# :::
#
# ::::
#
# ---
#
# ## **Core Sections**
#
# ::::{grid} 1 2 3
# :gutter: 3
#
# :::{grid-item-card} 🧱 **Foundations**
# :link: foundations/index.ipynb
# :link-type: rel
#
# Understand the agnostic philosophy, **The Trinity**, element levels, unit-safety, parallelization, and ecosystem bridges.
# ^^^
# Explore Foundations →
# :::
#
# :::{grid-item-card} 🧰 **Tools**
# :link: tools/index_v2.md
# :link-type: rel
#
# Browse the comprehensive, functional API toolbox grouped by feature area (basic, structure, topology, PBC, physchem, etc.).
# ^^^
# Open Toolbox →
# :::
#
# :::{grid-item-card} 🍳 **Cookbook**
# :link: cookbook/index.md
# :link-type: rel
#
# A collection of concrete, ready-to-run recipes for standard real-world structural biology and molecular modeling workflows.
# ^^^
# Browse Recipes →
# :::
#
# ::::
#
# ```{eval-rst}
# .. toctree::
#    :hidden:
#
#    foundations/index.ipynb
#    tools/index_v2.md
#    cookbook/index.md
# ```
#
# ---
#
# ## **Interactive Support**
#
# :::{tip}
# **💡 Looking for instant assistance?**
#
# Experimental AI chatbots specifically trained on MolSysMT's form-agnostic API and engineering rules are ready to assist you. Ask questions, troubleshoot code, and draft workflows: [AI Assistants](../ai_assistants.md).
# :::
