# %% [markdown]
# ```{eval-rst}
# :html_theme.sidebar_secondary.remove:
# ```

# %% [markdown]
# :::{figure} _static/logo.svg
# :width: 40%
# :align: center
#
# **One API. 60+ molecular formats and libraries.**
# **From PDB to simulation in a single workflow.**
#
# ```{image} https://img.shields.io/badge/release-v0.11.2-white.svg
# :target: https://github.com/uibcdf/molsysmt
# ```
# ```{image} https://img.shields.io/badge/license-MIT-white.svg
# :target: https://github.com/uibcdf/molsysmt/blob/master/LICENSE
# ```
# ```{image} https://img.shields.io/badge/install%20with-conda-white.svg
# :target: https://anaconda.org/uibcdf/molsysmt
# ```
# ```{image} https://img.shields.io/badge/python-3.11%20%7C%203.12%20%7C%203.13-white.svg
# :target: https://www.python.org/downloads/
# ```
# :::
#
# ---

# %% [markdown]
# ## Quick Start
#
# ```bash
# conda install -c uibcdf molsysmt
# ```
#
# ```python
# import molsysmt as msm
# system = msm.convert('181L', to_form='molsysmt.MolSys')
# msm.info(system)
# ```
#
# ---

# %% [markdown]
# ## Explore MolSysMT (Refactored _v2 Edition)
#
# ```{grid} 3
# :gutter: 3
# :class-container: sd-text-center
#
# :::{grid-item-card} SHOWCASE
# **Visual Gallery**
# ^^^
# Inspiration through high-end visualizations and success stories.
# +++
# [View Showcase](content/showcase/index.md)
# :::
#
# :::{grid-item-card} LEARNING PATH
# **The Master Course**
# ^^^
# A guided 50-module journey from basics to advanced engineering.
# +++
# [Start Learning](content/course/index.md)
# :::
#
# :::{grid-item-card} USER GUIDE
# **Philosophy & Functions**
# ^^^
# Understand the core concepts: Forms, Elements, and Attributes.
# +++
# [Read the Guide](content/user/index_v2.ipynb)
# :::
#
# :::{grid-item-card} ECOSYSTEM
# **Interoperability Matrix**
# ^^^
# Check compatibility with 60+ molecular formats and libraries.
# +++
# [See Supported](content/user/tools/Supported.ipynb)
# :::
#
# :::{grid-item-card} COOKBOOK
# **Ready-to-use Recipes**
# ^^^
# Practical snippets for common computational biology tasks.
# +++
# [Browse Recipes](content/user/cookbook/index.md)
# :::
#
# :::{grid-item-card} API REFERENCE
# **Technical Details**
# ^^^
# Low-level documentation of classes, objects, and internal logic.
# +++
# [Explore API](api/index_v2.md)
# :::
#
# :::{grid-item-card} AI ASSISTANT
# **Ask the Master**
# ^^^
# Instant support and code generation from our trained AI.
# +++
# [Ask AI](content/ai_assistant.md)
# :::
#
# :::{grid-item-card} DEVELOPER HUB
# **Contribute & Extend**
# ^^^
# Architecture rules, Golden Quartet, and contribution guidelines.
# +++
# [Join Team](content/developer/index.md)
# :::
#
# :::{grid-item-card} MOLSYS SUITE
# :class-card: sd-bg-light
# **The Keystone Universe**
# ^^^
# Explore our family of specialized structural biology tools.
# +++
# [See the Suite](https://www.uibcdf.org/)
# :::
# ```
#
# ---

# %% [markdown]
# ## Citation
#
# If you use MolSysMT in your research, please cite the software release:
#
# ````{tabs}
# ```{tab} Software
# Diego Prada-Gracia & Liliana M. Moreno-Vargas. (2023). uibcdf/MolSysMT: 0.9.1. Zenodo. https://doi.org/10.5281/zenodo.8092688
# ```
# ```{tab} Paper
# Coming soon...
# ```
# ````

# %% [markdown]
# ```{eval-rst}
#
# .. toctree::
#    :maxdepth: 1
#    :hidden:
#
#    About <content/about/index.md>
#    Showcase <content/showcase/index.md>
#    Learning Path <content/course/index.md>
#    User Guide <content/user/index_v2.ipynb>
#    API <api/index_v2.md>
#    Developer <content/developer/index.md>
#    AI Assistant <content/ai_assistant.md>
# ```
