# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # There we go!

# %%
import molsysmt as msm

# %%
#file = '/home/diego/Ixtlilton/hot_projects/hexii/AF-P52789-F1-model_v4.pdb'
file = '/home/diego/Ixtlilton/hot_projects/hexii/em.gro'

# %%
# %%time
molsys = msm.convert(file)
# Out:
# CPU times: user 49.3 s, sys: 476 ms, total: 49.8 s
# Wall time: 49.8 s

# %%
# %%time
molsys = msm.convert(file, 'molsysmt.Topology')
# Out:
# CPU times: user 50.1 s, sys: 464 ms, total: 50.5 s
# Wall time: 50.4 s

# %%
molsys = msm.convert(file, 'mdtraj.Topology')

# %%
bond.
# Out:
# 38113

# %%
for ii, bond in enumerate(molsys.bonds):
    print(ii, bond.index)
# Out:
# 0 <built-in method index of Bond object at 0x7f44f5147d80>
# 1 <built-in method index of Bond object at 0x7f44f5147dd0>
# 2 <built-in method index of Bond object at 0x7f44f5147e20>
# 3 <built-in method index of Bond object at 0x7f44f5147e70>
# 4 <built-in method index of Bond object at 0x7f44f5147ec0>
# 5 <built-in method index of Bond object at 0x7f44f5147f10>
# 6 <built-in method index of Bond object at 0x7f44f5147f60>
# 7 <built-in method index of Bond object at 0x7f44f5147fb0>
# 8 <built-in method index of Bond object at 0x7f44f515c040>
# 9 <built-in method index of Bond object at 0x7f44f515c090>
# 10 <built-in method index of Bond object at 0x7f44f515c0e0>
# 11 <built-in method index of Bond object at 0x7f44f515c130>
# 12 <built-in method index of Bond object at 0x7f44f515c180>
# 13 <built-in method index of Bond object at 0x7f44f515c1d0>
# 14 <built-in method index of Bond object at 0x7f44f515c220>
# 15 <built-in method index of Bond object at 0x7f44f515c270>
# 16 <built-in method index of Bond object at 0x7f44f515c2c0>
# 17 <built-in method index of Bond object at 0x7f44f515c310>
# 18 <built-in method index of Bond object at 0x7f44f515c360>
# 19 <built-in method index of Bond object at 0x7f44f515c3b0>
# 20 <built-in method index of Bond object at 0x7f44f515c400>
# 21 <built-in method index of Bond object at 0x7f44f515c450>
# 22 <built-in method index of Bond object at 0x7f44f515c4a0>
# 23 <built-in method index of Bond object at 0x7f44f515c4f0>
# 24 <built-in method index of Bond object at 0x7f44f515c540>
# 25 <built-in method index of Bond object at 0x7f44f515c590>
# 26 <built-in method index of Bond object at 0x7f44f515c5e0>
# 27 <built-in method index of Bond object at 0x7f44f515c630>
# 28 <built-in method index of Bond object at 0x7f44f515c680>
# 29 <built-in method index of Bond object at 0x7f44f515c6d0>
# 30 <built-in method index of Bond object at 0x7f44f515c720>
# 31 <built-in method index of Bond object at 0x7f44f515c770>
# 32 <built-in method index of Bond object at 0x7f44f515c7c0>
# 33 <built-in method index of Bond object at 0x7f44f515c810>
# 34 <built-in method index of Bond object at 0x7f44f515c860>
# 35 <built-in method index of Bond object at 0x7f44f515c8b0>
# 36 <built-in method index of Bond object at 0x7f44f515c900>
# 37 <built-in method index of Bond object at 0x7f44f515c950>
# 38 <built-in method index of Bond object at 0x7f44f515c9a0>
# 39 <built-in method index of Bond object at 0x7f44f515c9f0>
# 40 <built-in method index of Bond object at 0x7f44f515ca40>
# 41 <built-in method index of Bond object at 0x7f44f515ca90>
# 42 <built-in method index of Bond object at 0x7f44f515cae0>
# 43 <built-in method index of Bond object at 0x7f44f515cb30>
# 44 <built-in method index of Bond object at 0x7f44f515cb80>
# 45 <built-in method index of Bond object at 0x7f44f515cbd0>
# 46 <built-in method index of Bond object at 0x7f44f515cc20>
# 47 <built-in method index of Bond object at 0x7f44f515cc70>
# 48 <built-in method index of Bond object at 0x7f44f515ccc0>
# 49 <built-in method index of Bond object at 0x7f44f515cd10>
# 50 <built-in method index of Bond object at 0x7f44f515cd60>
# 51 <built-in method index of Bond object at 0x7f44f515cdb0>
# 52 <built-in method index of Bond object at 0x7f44f515ce00>
# 53 <built-in method index of Bond object at 0x7f44f515ce50>
# 54 <built-in method index of Bond object at 0x7f44f515cea0>
# 55 <built-in method index of Bond object at 0x7f44f515cef0>
# 56 <built-in method index of Bond object at 0x7f44f515cf40>
# 57 <built-in method index of Bond object at 0x7f44f515cf90>
# 58 <built-in method index of Bond object at 0x7f44f515cfe0>
# 59 <built-in method index of Bond object at 0x7f44f515d030>
# 60 <built-in method index of Bond object at 0x7f44f515d080>
# 61 <built-in method index of Bond object at 0x7f44f515d0d0>
# 62 <built-in method index of Bond object at 0x7f44f515d120>
# 63 <built-in method index of Bond object at 0x7f44f515d170>
# 64 <built-in method index of Bond object at 0x7f44f515d1c0>
# 65 <built-in method index of Bond object at 0x7f44f515d210>
# 66 <built-in method index of Bond object at 0x7f44f515d260>
# 67 <built-in method index of Bond object at 0x7f44f515d2b0>
# 68 <built-in method index of Bond object at 0x7f44f515d300>
# 69 <built-in method index of Bond object at 0x7f44f515d350>
# 70 <built-in method index of Bond object at 0x7f44f515d3a0>
# 71 <built-in method index of Bond object at 0x7f44f515d3f0>
# 72 <built-in method index of Bond object at 0x7f44f515d440>
# 73 <built-in method index of Bond object at 0x7f44f515d490>
# 74 <built-in method index of Bond object at 0x7f44f515d4e0>
# 75 <built-in method index of Bond object at 0x7f44f515d530>
# 76 <built-in method index of Bond object at 0x7f44f515d580>
# 77 <built-in method index of Bond object at 0x7f44f515d5d0>
# 78 <built-in method index of Bond object at 0x7f44f515d620>
# 79 <built-in method index of Bond object at 0x7f44f515d670>
# 80 <built-in method index of Bond object at 0x7f44f515d6c0>
# 81 <built-in method index of Bond object at 0x7f44f515d710>
# 82 <built-in method index of Bond object at 0x7f44f515d760>
# 83 <built-in method index of Bond object at 0x7f44f515d7b0>
# 84 <built-in method index of Bond object at 0x7f44f515d800>
# 85 <built-in method index of Bond object at 0x7f44f515d850>
# 86 <built-in method index of Bond object at 0x7f44f515d8a0>
# 87 <built-in method index of Bond object at 0x7f44f515d8f0>
# 88 <built-in method index of Bond object at 0x7f44f515d940>
# 89 <built-in method index of Bond object at 0x7f44f515d990>
# 90 <built-in method index of Bond object at 0x7f44f515d9e0>
# 91 <built-in method index of Bond object at 0x7f44f515da30>
# 92 <built-in method index of Bond object at 0x7f44f515da80>
# 93 <built-in method index of Bond object at 0x7f44f515dad0>
# 94 <built-in method index of Bond object at 0x7f44f515db20>
# 95 <built-in method index of Bond object at 0x7f44f515db70>
# 96 <built-in method index of Bond object at 0x7f44f515dbc0>
# 97 <built-in method index of Bond object at 0x7f44f515dc10>
# 98 <built-in method index of Bond object at 0x7f44f515dc60>
# 99 <built-in method index of Bond object at 0x7f44f515dcb0>
# 100 <built-in method index of Bond object at 0x7f44f515dd00>
# 101 <built-in method index of Bond object at 0x7f44f515dd50>
# 102 <built-in method index of Bond object at 0x7f44f515dda0>
# 103 <built-in method index of Bond object at 0x7f44f515ddf0>
# 104 <built-in method index of Bond object at 0x7f44f515de40>
# 105 <built-in method index of Bond object at 0x7f44f515de90>
# 106 <built-in method index of Bond object at 0x7f44f515dee0>
# 107 <built-in method index of Bond object at 0x7f44f515df30>
# 108 <built-in method index of Bond object at 0x7f44f515df80>
# 109 <built-in method index of Bond object at 0x7f44f515dfd0>
# 110 <built-in method index of Bond object at 0x7f44f515e020>
# 111 <built-in method index of Bond object at 0x7f44f515e070>
# 112 <built-in method index of Bond object at 0x7f44f515e0c0>
# 113 <built-in method index of Bond object at 0x7f44f515e110>
# 114 <built-in method index of Bond object at 0x7f44f515e160>
# 115 <built-in method index of Bond object at 0x7f44f515e1b0>
# 116 <built-in method index of Bond object at 0x7f44f515e200>
# 117 <built-in method index of Bond object at 0x7f44f515e250>
# 118 <built-in method index of Bond object at 0x7f44f515e2a0>
# 119 <built-in method index of Bond object at 0x7f44f515e2f0>
# 120 <built-in method index of Bond object at 0x7f44f515e340>
# 121 <built-in method index of Bond object at 0x7f44f515e390>
# 122 <built-in method index of Bond object at 0x7f44f515e3e0>
# 123 <built-in method index of Bond object at 0x7f44f515e430>
# 124 <built-in method index of Bond object at 0x7f44f515e480>
# 125 <built-in method index of Bond object at 0x7f44f515e4d0>
# 126 <built-in method index of Bond object at 0x7f44f515e520>
# 127 <built-in method index of Bond object at 0x7f44f515e570>
# 128 <built-in method index of Bond object at 0x7f44f515e5c0>
# 129 <built-in method index of Bond object at 0x7f44f515e610>
# 130 <built-in method index of Bond object at 0x7f44f515e660>
# 131 <built-in method index of Bond object at 0x7f44f515e6b0>
# 132 <built-in method index of Bond object at 0x7f44f515e700>
# 133 <built-in method index of Bond object at 0x7f44f515e750>
# 134 <built-in method index of Bond object at 0x7f44f515e7a0>
# 135 <built-in method index of Bond object at 0x7f44f515e7f0>
# 136 <built-in method index of Bond object at 0x7f44f515e840>
# 137 <built-in method index of Bond object at 0x7f44f515e890>
# 138 <built-in method index of Bond object at 0x7f44f515e8e0>
# 139 <built-in method index of Bond object at 0x7f44f515e930>
# 140 <built-in method index of Bond object at 0x7f44f515e980>
# 141 <built-in method index of Bond object at 0x7f44f515e9d0>
# 142 <built-in method index of Bond object at 0x7f44f515ea20>
# 143 <built-in method index of Bond object at 0x7f44f515ea70>
# 144 <built-in method index of Bond object at 0x7f44f515eac0>
# 145 <built-in method index of Bond object at 0x7f44f515eb10>
# 146 <built-in method index of Bond object at 0x7f44f515eb60>
# 147 <built-in method index of Bond object at 0x7f44f515ebb0>
# 148 <built-in method index of Bond object at 0x7f44f515ec00>
# 149 <built-in method index of Bond object at 0x7f44f515ec50>
# 150 <built-in method index of Bond object at 0x7f44f515eca0>
# 151 <built-in method index of Bond object at 0x7f44f515ecf0>
# 152 <built-in method index of Bond object at 0x7f44f515ed40>
# 153 <built-in method index of Bond object at 0x7f44f515ed90>
# 154 <built-in method index of Bond object at 0x7f44f515ede0>
# 155 <built-in method index of Bond object at 0x7f44f515ee30>
# 156 <built-in method index of Bond object at 0x7f44f515ee80>
# 157 <built-in method index of Bond object at 0x7f44f515eed0>
# 158 <built-in method index of Bond object at 0x7f44f515ef20>
# 159 <built-in method index of Bond object at 0x7f44f515ef70>
# 160 <built-in method index of Bond object at 0x7f44f515efc0>
# 161 <built-in method index of Bond object at 0x7f44f515f010>
# 162 <built-in method index of Bond object at 0x7f44f515f060>
# 163 <built-in method index of Bond object at 0x7f44f515f0b0>
# 164 <built-in method index of Bond object at 0x7f44f515f100>
# 165 <built-in method index of Bond object at 0x7f44f515f150>
# 166 <built-in method index of Bond object at 0x7f44f515f1a0>
# 167 <built-in method index of Bond object at 0x7f44f515f1f0>
# 168 <built-in method index of Bond object at 0x7f44f515f240>
# 169 <built-in method index of Bond object at 0x7f44f515f290>
# 170 <built-in method index of Bond object at 0x7f44f515f2e0>
# 171 <built-in method index of Bond object at 0x7f44f515f330>
# 172 <built-in method index of Bond object at 0x7f44f515f380>
# 173 <built-in method index of Bond object at 0x7f44f515f3d0>
# 174 <built-in method index of Bond object at 0x7f44f515f420>
# 175 <built-in method index of Bond object at 0x7f44f515f470>
# 176 <built-in method index of Bond object at 0x7f44f515f4c0>
# 177 <built-in method index of Bond object at 0x7f44f515f510>
# 178 <built-in method index of Bond object at 0x7f44f515f560>
# 179 <built-in method index of Bond object at 0x7f44f515f5b0>
# 180 <built-in method index of Bond object at 0x7f44f515f600>
# 181 <built-in method index of Bond object at 0x7f44f515f650>
# 182 <built-in method index of Bond object at 0x7f44f515f6a0>
# 183 <built-in method index of Bond object at 0x7f44f515f6f0>
# 184 <built-in method index of Bond object at 0x7f44f515f740>
# 185 <built-in method index of Bond object at 0x7f44f515f790>
# 186 <built-in method index of Bond object at 0x7f44f515f7e0>
# 187 <built-in method index of Bond object at 0x7f44f515f830>
# 188 <built-in method index of Bond object at 0x7f44f515f880>
# 189 <built-in method index of Bond object at 0x7f44f515f8d0>
# 190 <built-in method index of Bond object at 0x7f44f515f920>
# 191 <built-in method index of Bond object at 0x7f44f515f970>
# 192 <built-in method index of Bond object at 0x7f44f515f9c0>
# 193 <built-in method index of Bond object at 0x7f44f515fa10>
# 194 <built-in method index of Bond object at 0x7f44f515fa60>
# 195 <built-in method index of Bond object at 0x7f44f515fab0>
# 196 <built-in method index of Bond object at 0x7f44f515fb00>
# 197 <built-in method index of Bond object at 0x7f44f515fb50>
# 198 <built-in method index of Bond object at 0x7f44f515fba0>
# 199 <built-in method index of Bond object at 0x7f44f515fbf0>
# 200 <built-in method index of Bond object at 0x7f44f515fc40>
# 201 <built-in method index of Bond object at 0x7f44f515fc90>
# 202 <built-in method index of Bond object at 0x7f44f515fce0>
# 203 <built-in method index of Bond object at 0x7f44f515fd30>
# 204 <built-in method index of Bond object at 0x7f44f515fd80>
# 205 <built-in method index of Bond object at 0x7f44f515fdd0>
# 206 <built-in method index of Bond object at 0x7f44f515fe20>
# 207 <built-in method index of Bond object at 0x7f44f515fe70>
# 208 <built-in method index of Bond object at 0x7f44f515fec0>
# 209 <built-in method index of Bond object at 0x7f44f515ff10>
# 210 <built-in method index of Bond object at 0x7f44f515ff60>
# 211 <built-in method index of Bond object at 0x7f44f515ffb0>
# 212 <built-in method index of Bond object at 0x7f44f5168040>
# 213 <built-in method index of Bond object at 0x7f44f5168090>
# 214 <built-in method index of Bond object at 0x7f44f51680e0>
# 215 <built-in method index of Bond object at 0x7f44f5168130>
# 216 <built-in method index of Bond object at 0x7f44f5168180>
# 217 <built-in method index of Bond object at 0x7f44f51681d0>
# 218 <built-in method index of Bond object at 0x7f44f5168220>
# 219 <built-in method index of Bond object at 0x7f44f5168270>
# 220 <built-in method index of Bond object at 0x7f44f51682c0>
# 221 <built-in method index of Bond object at 0x7f44f5168310>
# 222 <built-in method index of Bond object at 0x7f44f5168360>
# 223 <built-in method index of Bond object at 0x7f44f51683b0>
# 224 <built-in method index of Bond object at 0x7f44f5168400>
# 225 <built-in method index of Bond object at 0x7f44f5168450>
# 226 <built-in method index of Bond object at 0x7f44f51684a0>
# 227 <built-in method index of Bond object at 0x7f44f51684f0>
# 228 <built-in method index of Bond object at 0x7f44f5168540>
# 229 <built-in method index of Bond object at 0x7f44f5168590>
# 230 <built-in method index of Bond object at 0x7f44f51685e0>
# 231 <built-in method index of Bond object at 0x7f44f5168630>
# 232 <built-in method index of Bond object at 0x7f44f5168680>
# 233 <built-in method index of Bond object at 0x7f44f51686d0>
# 234 <built-in method index of Bond object at 0x7f44f5168720>
# 235 <built-in method index of Bond object at 0x7f44f5168770>
# 236 <built-in method index of Bond object at 0x7f44f51687c0>
# 237 <built-in method index of Bond object at 0x7f44f5168810>
# 238 <built-in method index of Bond object at 0x7f44f5168860>
# 239 <built-in method index of Bond object at 0x7f44f51688b0>
# 240 <built-in method index of Bond object at 0x7f44f5168900>
# 241 <built-in method index of Bond object at 0x7f44f5168950>
# 242 <built-in method index of Bond object at 0x7f44f51689a0>
# 243 <built-in method index of Bond object at 0x7f44f51689f0>
# 244 <built-in method index of Bond object at 0x7f44f5168a40>
# 245 <built-in method index of Bond object at 0x7f44f5168a90>
# 246 <built-in method index of Bond object at 0x7f44f5168ae0>
# 247 <built-in method index of Bond object at 0x7f44f5168b30>
# 248 <built-in method index of Bond object at 0x7f44f5168b80>
# 249 <built-in method index of Bond object at 0x7f44f5168bd0>
# 250 <built-in method index of Bond object at 0x7f44f5168c20>
# 251 <built-in method index of Bond object at 0x7f44f5168c70>
# 252 <built-in method index of Bond object at 0x7f44f5168cc0>
# 253 <built-in method index of Bond object at 0x7f44f5168d10>
# 254 <built-in method index of Bond object at 0x7f44f5168d60>
# 255 <built-in method index of Bond object at 0x7f44f5168db0>
# 256 <built-in method index of Bond object at 0x7f44f5168e00>
# 257 <built-in method index of Bond object at 0x7f44f5168e50>
# 258 <built-in method index of Bond object at 0x7f44f5168ea0>
# 259 <built-in method index of Bond object at 0x7f44f5168ef0>
# 260 <built-in method index of Bond object at 0x7f44f5168f40>
# 261 <built-in method index of Bond object at 0x7f44f5168f90>
# 262 <built-in method index of Bond object at 0x7f44f5168fe0>
# 263 <built-in method index of Bond object at 0x7f44f5169030>
# 264 <built-in method index of Bond object at 0x7f44f5169080>
# 265 <built-in method index of Bond object at 0x7f44f51690d0>
# 266 <built-in method index of Bond object at 0x7f44f5169120>
# 267 <built-in method index of Bond object at 0x7f44f5169170>
# 268 <built-in method index of Bond object at 0x7f44f51691c0>
# 269 <built-in method index of Bond object at 0x7f44f5169210>
# 270 <built-in method index of Bond object at 0x7f44f5169260>
# 271 <built-in method index of Bond object at 0x7f44f51692b0>
# 272 <built-in method index of Bond object at 0x7f44f5169300>
# 273 <built-in method index of Bond object at 0x7f44f5169350>
# 274 <built-in method index of Bond object at 0x7f44f51693a0>
# 275 <built-in method index of Bond object at 0x7f44f51693f0>
# 276 <built-in method index of Bond object at 0x7f44f5169440>
# 277 <built-in method index of Bond object at 0x7f44f5169490>
# 278 <built-in method index of Bond object at 0x7f44f51694e0>
# 279 <built-in method index of Bond object at 0x7f44f5169530>
# 280 <built-in method index of Bond object at 0x7f44f5169580>
# 281 <built-in method index of Bond object at 0x7f44f51695d0>
# 282 <built-in method index of Bond object at 0x7f44f5169620>
# 283 <built-in method index of Bond object at 0x7f44f5169670>
# 284 <built-in method index of Bond object at 0x7f44f51696c0>
# 285 <built-in method index of Bond object at 0x7f44f5169710>
# 286 <built-in method index of Bond object at 0x7f44f5169760>
# 287 <built-in method index of Bond object at 0x7f44f51697b0>
# 288 <built-in method index of Bond object at 0x7f44f5169800>
# 289 <built-in method index of Bond object at 0x7f44f5169850>
# 290 <built-in method index of Bond object at 0x7f44f51698a0>
# 291 <built-in method index of Bond object at 0x7f44f51698f0>
# 292 <built-in method index of Bond object at 0x7f44f5169940>
# 293 <built-in method index of Bond object at 0x7f44f5169990>
# 294 <built-in method index of Bond object at 0x7f44f51699e0>
# 295 <built-in method index of Bond object at 0x7f44f5169a30>
# 296 <built-in method index of Bond object at 0x7f44f5169a80>
# 297 <built-in method index of Bond object at 0x7f44f5169ad0>
# 298 <built-in method index of Bond object at 0x7f44f5169b20>
# 299 <built-in method index of Bond object at 0x7f44f5169b70>
# 300 <built-in method index of Bond object at 0x7f44f5169bc0>
# 301 <built-in method index of Bond object at 0x7f44f5169c10>
# 302 <built-in method index of Bond object at 0x7f44f5169c60>
# 303 <built-in method index of Bond object at 0x7f44f5169cb0>
# 304 <built-in method index of Bond object at 0x7f44f5169d00>
# 305 <built-in method index of Bond object at 0x7f44f5169d50>
# 306 <built-in method index of Bond object at 0x7f44f5169da0>
# 307 <built-in method index of Bond object at 0x7f44f5169df0>
# 308 <built-in method index of Bond object at 0x7f44f5169e40>
# 309 <built-in method index of Bond object at 0x7f44f5169e90>
# 310 <built-in method index of Bond object at 0x7f44f5169ee0>
# 311 <built-in method index of Bond object at 0x7f44f5169f30>
# 312 <built-in method index of Bond object at 0x7f44f5169f80>
# 313 <built-in method index of Bond object at 0x7f44f5169fd0>
# 314 <built-in method index of Bond object at 0x7f44f516a020>
# 315 <built-in method index of Bond object at 0x7f44f516a070>
# 316 <built-in method index of Bond object at 0x7f44f516a0c0>
# 317 <built-in method index of Bond object at 0x7f44f516a110>
# 318 <built-in method index of Bond object at 0x7f44f516a160>
# 319 <built-in method index of Bond object at 0x7f44f516a1b0>
# 320 <built-in method index of Bond object at 0x7f44f516a200>
# 321 <built-in method index of Bond object at 0x7f44f516a250>
# 322 <built-in method index of Bond object at 0x7f44f516a2a0>
# 323 <built-in method index of Bond object at 0x7f44f516a2f0>
# 324 <built-in method index of Bond object at 0x7f44f516a340>
# 325 <built-in method index of Bond object at 0x7f44f516a390>
# 326 <built-in method index of Bond object at 0x7f44f516a3e0>
# 327 <built-in method index of Bond object at 0x7f44f516a430>
# 328 <built-in method index of Bond object at 0x7f44f516a480>
# 329 <built-in method index of Bond object at 0x7f44f516a4d0>
# 330 <built-in method index of Bond object at 0x7f44f516a520>
# 331 <built-in method index of Bond object at 0x7f44f516a570>
# 332 <built-in method index of Bond object at 0x7f44f516a5c0>
# 333 <built-in method index of Bond object at 0x7f44f516a610>
# 334 <built-in method index of Bond object at 0x7f44f516a660>
# 335 <built-in method index of Bond object at 0x7f44f516a6b0>
# 336 <built-in method index of Bond object at 0x7f44f516a700>
# 337 <built-in method index of Bond object at 0x7f44f516a750>
# 338 <built-in method index of Bond object at 0x7f44f516a7a0>
# 339 <built-in method index of Bond object at 0x7f44f516a7f0>
# 340 <built-in method index of Bond object at 0x7f44f516a840>
# 341 <built-in method index of Bond object at 0x7f44f516a890>
# 342 <built-in method index of Bond object at 0x7f44f516a8e0>
# 343 <built-in method index of Bond object at 0x7f44f516a930>
# 344 <built-in method index of Bond object at 0x7f44f516a980>
# 345 <built-in method index of Bond object at 0x7f44f516a9d0>
# 346 <built-in method index of Bond object at 0x7f44f516aa20>
# 347 <built-in method index of Bond object at 0x7f44f516aa70>
# 348 <built-in method index of Bond object at 0x7f44f516aac0>
# 349 <built-in method index of Bond object at 0x7f44f516ab10>
# 350 <built-in method index of Bond object at 0x7f44f516ab60>
# 351 <built-in method index of Bond object at 0x7f44f516abb0>
# 352 <built-in method index of Bond object at 0x7f44f516ac00>
# 353 <built-in method index of Bond object at 0x7f44f516ac50>
# 354 <built-in method index of Bond object at 0x7f44f516aca0>
# 355 <built-in method index of Bond object at 0x7f44f516acf0>
# 356 <built-in method index of Bond object at 0x7f44f516ad40>
# 357 <built-in method index of Bond object at 0x7f44f516ad90>
# 358 <built-in method index of Bond object at 0x7f44f516ade0>
# 359 <built-in method index of Bond object at 0x7f44f516ae30>
# 360 <built-in method index of Bond object at 0x7f44f516ae80>
# 361 <built-in method index of Bond object at 0x7f44f516aed0>
# 362 <built-in method index of Bond object at 0x7f44f516af20>
# 363 <built-in method index of Bond object at 0x7f44f516af70>
# 364 <built-in method index of Bond object at 0x7f44f516afc0>
# 365 <built-in method index of Bond object at 0x7f44f516b010>
# 366 <built-in method index of Bond object at 0x7f44f516b060>
# 367 <built-in method index of Bond object at 0x7f44f516b0b0>
# 368 <built-in method index of Bond object at 0x7f44f516b100>
# 369 <built-in method index of Bond object at 0x7f44f516b150>
# 370 <built-in method index of Bond object at 0x7f44f516b1a0>
# 371 <built-in method index of Bond object at 0x7f44f516b1f0>
# 372 <built-in method index of Bond object at 0x7f44f516b240>
# 373 <built-in method index of Bond object at 0x7f44f516b290>
# 374 <built-in method index of Bond object at 0x7f44f516b2e0>
# 375 <built-in method index of Bond object at 0x7f44f516b330>
# 376 <built-in method index of Bond object at 0x7f44f516b380>
# 377 <built-in method index of Bond object at 0x7f44f516b3d0>
# 378 <built-in method index of Bond object at 0x7f44f516b420>
# 379 <built-in method index of Bond object at 0x7f44f516b470>
# 380 <built-in method index of Bond object at 0x7f44f516b4c0>
# 381 <built-in method index of Bond object at 0x7f44f516b510>
# 382 <built-in method index of Bond object at 0x7f44f516b560>
# 383 <built-in method index of Bond object at 0x7f44f516b5b0>
# 384 <built-in method index of Bond object at 0x7f44f516b600>
# 385 <built-in method index of Bond object at 0x7f44f516b650>
# 386 <built-in method index of Bond object at 0x7f44f516b6a0>
# 387 <built-in method index of Bond object at 0x7f44f516b6f0>
# 388 <built-in method index of Bond object at 0x7f44f516b740>
# 389 <built-in method index of Bond object at 0x7f44f516b790>
# 390 <built-in method index of Bond object at 0x7f44f516b7e0>
# 391 <built-in method index of Bond object at 0x7f44f516b830>
# 392 <built-in method index of Bond object at 0x7f44f516b880>
# 393 <built-in method index of Bond object at 0x7f44f516b8d0>
# 394 <built-in method index of Bond object at 0x7f44f516b920>
# 395 <built-in method index of Bond object at 0x7f44f516b970>
# 396 <built-in method index of Bond object at 0x7f44f516b9c0>
# 397 <built-in method index of Bond object at 0x7f44f516ba10>
# 398 <built-in method index of Bond object at 0x7f44f516ba60>
# 399 <built-in method index of Bond object at 0x7f44f516bab0>
# 400 <built-in method index of Bond object at 0x7f44f516bb00>
# 401 <built-in method index of Bond object at 0x7f44f516bb50>
# 402 <built-in method index of Bond object at 0x7f44f516bba0>
# 403 <built-in method index of Bond object at 0x7f44f516bbf0>
# 404 <built-in method index of Bond object at 0x7f44f516bc40>
# 405 <built-in method index of Bond object at 0x7f44f516bc90>
# 406 <built-in method index of Bond object at 0x7f44f516bce0>
# 407 <built-in method index of Bond object at 0x7f44f516bd30>
# 408 <built-in method index of Bond object at 0x7f44f516bd80>
# 409 <built-in method index of Bond object at 0x7f44f516bdd0>
# 410 <built-in method index of Bond object at 0x7f44f516be20>
# 411 <built-in method index of Bond object at 0x7f44f516be70>
# 412 <built-in method index of Bond object at 0x7f44f516bec0>
# 413 <built-in method index of Bond object at 0x7f44f516bf10>
# 414 <built-in method index of Bond object at 0x7f44f516bf60>
# 415 <built-in method index of Bond object at 0x7f44f516bfb0>
# 416 <built-in method index of Bond object at 0x7f44f5170040>
# 417 <built-in method index of Bond object at 0x7f44f5170090>
# 418 <built-in method index of Bond object at 0x7f44f51700e0>
# 419 <built-in method index of Bond object at 0x7f44f5170130>
# 420 <built-in method index of Bond object at 0x7f44f5170180>
# 421 <built-in method index of Bond object at 0x7f44f51701d0>
# 422 <built-in method index of Bond object at 0x7f44f5170220>
# 423 <built-in method index of Bond object at 0x7f44f5170270>
# 424 <built-in method index of Bond object at 0x7f44f51702c0>
# 425 <built-in method index of Bond object at 0x7f44f5170310>
# 426 <built-in method index of Bond object at 0x7f44f5170360>
# 427 <built-in method index of Bond object at 0x7f44f51703b0>
# 428 <built-in method index of Bond object at 0x7f44f5170400>
# 429 <built-in method index of Bond object at 0x7f44f5170450>
# 430 <built-in method index of Bond object at 0x7f44f51704a0>
# 431 <built-in method index of Bond object at 0x7f44f51704f0>
# 432 <built-in method index of Bond object at 0x7f44f5170540>
# 433 <built-in method index of Bond object at 0x7f44f5170590>
# 434 <built-in method index of Bond object at 0x7f44f51705e0>
# 435 <built-in method index of Bond object at 0x7f44f5170630>
# 436 <built-in method index of Bond object at 0x7f44f5170680>
# 437 <built-in method index of Bond object at 0x7f44f51706d0>
# 438 <built-in method index of Bond object at 0x7f44f5170720>
# 439 <built-in method index of Bond object at 0x7f44f5170770>
# 440 <built-in method index of Bond object at 0x7f44f51707c0>
# 441 <built-in method index of Bond object at 0x7f44f5170810>
# 442 <built-in method index of Bond object at 0x7f44f5170860>
# 443 <built-in method index of Bond object at 0x7f44f51708b0>
# 444 <built-in method index of Bond object at 0x7f44f5170900>
# 445 <built-in method index of Bond object at 0x7f44f5170950>
# 446 <built-in method index of Bond object at 0x7f44f51709a0>
# 447 <built-in method index of Bond object at 0x7f44f51709f0>
# 448 <built-in method index of Bond object at 0x7f44f5170a40>
# 449 <built-in method index of Bond object at 0x7f44f5170a90>
# 450 <built-in method index of Bond object at 0x7f44f5170ae0>
# 451 <built-in method index of Bond object at 0x7f44f5170b30>
# 452 <built-in method index of Bond object at 0x7f44f5170b80>
# 453 <built-in method index of Bond object at 0x7f44f5170bd0>
# 454 <built-in method index of Bond object at 0x7f44f5170c20>
# 455 <built-in method index of Bond object at 0x7f44f5170c70>
# 456 <built-in method index of Bond object at 0x7f44f5170cc0>
# 457 <built-in method index of Bond object at 0x7f44f5170d10>
# 458 <built-in method index of Bond object at 0x7f44f5170d60>
# 459 <built-in method index of Bond object at 0x7f44f5170db0>
# 460 <built-in method index of Bond object at 0x7f44f5170e00>
# 461 <built-in method index of Bond object at 0x7f44f5170e50>
# 462 <built-in method index of Bond object at 0x7f44f5170ea0>
# 463 <built-in method index of Bond object at 0x7f44f5170ef0>
# 464 <built-in method index of Bond object at 0x7f44f5170f40>
# 465 <built-in method index of Bond object at 0x7f44f5170f90>
# 466 <built-in method index of Bond object at 0x7f44f5170fe0>
# 467 <built-in method index of Bond object at 0x7f44f5171030>
# 468 <built-in method index of Bond object at 0x7f44f5171080>
# 469 <built-in method index of Bond object at 0x7f44f51710d0>
# 470 <built-in method index of Bond object at 0x7f44f5171120>
# 471 <built-in method index of Bond object at 0x7f44f5171170>
# 472 <built-in method index of Bond object at 0x7f44f51711c0>
# 473 <built-in method index of Bond object at 0x7f44f5171210>
# 474 <built-in method index of Bond object at 0x7f44f5171260>
# 475 <built-in method index of Bond object at 0x7f44f51712b0>
# 476 <built-in method index of Bond object at 0x7f44f5171300>
# 477 <built-in method index of Bond object at 0x7f44f5171350>
# 478 <built-in method index of Bond object at 0x7f44f51713a0>
# 479 <built-in method index of Bond object at 0x7f44f51713f0>
# 480 <built-in method index of Bond object at 0x7f44f5171440>
# 481 <built-in method index of Bond object at 0x7f44f5171490>
# 482 <built-in method index of Bond object at 0x7f44f51714e0>
# 483 <built-in method index of Bond object at 0x7f44f5171530>
# 484 <built-in method index of Bond object at 0x7f44f5171580>
# 485 <built-in method index of Bond object at 0x7f44f51715d0>
# 486 <built-in method index of Bond object at 0x7f44f5171620>
# 487 <built-in method index of Bond object at 0x7f44f5171670>
# 488 <built-in method index of Bond object at 0x7f44f51716c0>
# 489 <built-in method index of Bond object at 0x7f44f5171710>
# 490 <built-in method index of Bond object at 0x7f44f5171760>
# 491 <built-in method index of Bond object at 0x7f44f51717b0>
# 492 <built-in method index of Bond object at 0x7f44f5171800>
# 493 <built-in method index of Bond object at 0x7f44f5171850>
# 494 <built-in method index of Bond object at 0x7f44f51718a0>
# 495 <built-in method index of Bond object at 0x7f44f51718f0>
# 496 <built-in method index of Bond object at 0x7f44f5171940>
# 497 <built-in method index of Bond object at 0x7f44f5171990>
# 498 <built-in method index of Bond object at 0x7f44f51719e0>
# 499 <built-in method index of Bond object at 0x7f44f5171a30>
# 500 <built-in method index of Bond object at 0x7f44f5171a80>
# 501 <built-in method index of Bond object at 0x7f44f5171ad0>
# 502 <built-in method index of Bond object at 0x7f44f5171b20>
# 503 <built-in method index of Bond object at 0x7f44f5171b70>
# 504 <built-in method index of Bond object at 0x7f44f5171bc0>
# 505 <built-in method index of Bond object at 0x7f44f5171c10>
# 506 <built-in method index of Bond object at 0x7f44f5171c60>
# 507 <built-in method index of Bond object at 0x7f44f5171cb0>
# 508 <built-in method index of Bond object at 0x7f44f5171d00>
# 509 <built-in method index of Bond object at 0x7f44f5171d50>
# 510 <built-in method index of Bond object at 0x7f44f5171da0>
# 511 <built-in method index of Bond object at 0x7f44f5171df0>
# 512 <built-in method index of Bond object at 0x7f44f5171e40>
# 513 <built-in method index of Bond object at 0x7f44f5171e90>
# 514 <built-in method index of Bond object at 0x7f44f5171ee0>
# 515 <built-in method index of Bond object at 0x7f44f5171f30>
# 516 <built-in method index of Bond object at 0x7f44f5171f80>
# 517 <built-in method index of Bond object at 0x7f44f5171fd0>
# 518 <built-in method index of Bond object at 0x7f44f5172020>
# 519 <built-in method index of Bond object at 0x7f44f5172070>
# 520 <built-in method index of Bond object at 0x7f44f51720c0>
# 521 <built-in method index of Bond object at 0x7f44f5172110>
# 522 <built-in method index of Bond object at 0x7f44f5172160>
# 523 <built-in method index of Bond object at 0x7f44f51721b0>
# 524 <built-in method index of Bond object at 0x7f44f5172200>
# 525 <built-in method index of Bond object at 0x7f44f5172250>
# 526 <built-in method index of Bond object at 0x7f44f51722a0>
# 527 <built-in method index of Bond object at 0x7f44f51722f0>
# 528 <built-in method index of Bond object at 0x7f44f5172340>
# 529 <built-in method index of Bond object at 0x7f44f5172390>
# 530 <built-in method index of Bond object at 0x7f44f51723e0>
# 531 <built-in method index of Bond object at 0x7f44f5172430>
# 532 <built-in method index of Bond object at 0x7f44f5172480>
# 533 <built-in method index of Bond object at 0x7f44f51724d0>
# 534 <built-in method index of Bond object at 0x7f44f5172520>
# 535 <built-in method index of Bond object at 0x7f44f5172570>
# 536 <built-in method index of Bond object at 0x7f44f51725c0>
# 537 <built-in method index of Bond object at 0x7f44f5172610>
# 538 <built-in method index of Bond object at 0x7f44f5172660>
# 539 <built-in method index of Bond object at 0x7f44f51726b0>
# 540 <built-in method index of Bond object at 0x7f44f5172700>
# 541 <built-in method index of Bond object at 0x7f44f5172750>
# 542 <built-in method index of Bond object at 0x7f44f51727a0>
# 543 <built-in method index of Bond object at 0x7f44f51727f0>
# 544 <built-in method index of Bond object at 0x7f44f5172840>
# 545 <built-in method index of Bond object at 0x7f44f5172890>
# 546 <built-in method index of Bond object at 0x7f44f51728e0>
# 547 <built-in method index of Bond object at 0x7f44f5172930>
# 548 <built-in method index of Bond object at 0x7f44f5172980>
# 549 <built-in method index of Bond object at 0x7f44f51729d0>
# 550 <built-in method index of Bond object at 0x7f44f5172a20>
# 551 <built-in method index of Bond object at 0x7f44f5172a70>
# 552 <built-in method index of Bond object at 0x7f44f5172ac0>
# 553 <built-in method index of Bond object at 0x7f44f5172b10>
# 554 <built-in method index of Bond object at 0x7f44f5172b60>
# 555 <built-in method index of Bond object at 0x7f44f5172bb0>
# 556 <built-in method index of Bond object at 0x7f44f5172c00>
# 557 <built-in method index of Bond object at 0x7f44f5172c50>
# 558 <built-in method index of Bond object at 0x7f44f5172ca0>
# 559 <built-in method index of Bond object at 0x7f44f5172cf0>
# 560 <built-in method index of Bond object at 0x7f44f5172d40>
# 561 <built-in method index of Bond object at 0x7f44f5172d90>
# 562 <built-in method index of Bond object at 0x7f44f5172de0>
# 563 <built-in method index of Bond object at 0x7f44f5172e30>
# 564 <built-in method index of Bond object at 0x7f44f5172e80>
# 565 <built-in method index of Bond object at 0x7f44f5172ed0>
# 566 <built-in method index of Bond object at 0x7f44f5172f20>
# 567 <built-in method index of Bond object at 0x7f44f5172f70>
# 568 <built-in method index of Bond object at 0x7f44f5172fc0>
# 569 <built-in method index of Bond object at 0x7f44f5173010>
# 570 <built-in method index of Bond object at 0x7f44f5173060>
# 571 <built-in method index of Bond object at 0x7f44f51730b0>
# 572 <built-in method index of Bond object at 0x7f44f5173100>
# 573 <built-in method index of Bond object at 0x7f44f5173150>
# 574 <built-in method index of Bond object at 0x7f44f51731a0>
# 575 <built-in method index of Bond object at 0x7f44f51731f0>
# 576 <built-in method index of Bond object at 0x7f44f5173240>
# 577 <built-in method index of Bond object at 0x7f44f5173290>
# 578 <built-in method index of Bond object at 0x7f44f51732e0>
# 579 <built-in method index of Bond object at 0x7f44f5173330>
# 580 <built-in method index of Bond object at 0x7f44f5173380>
# 581 <built-in method index of Bond object at 0x7f44f51733d0>
# 582 <built-in method index of Bond object at 0x7f44f5173420>
# 583 <built-in method index of Bond object at 0x7f44f5173470>
# 584 <built-in method index of Bond object at 0x7f44f51734c0>
# 585 <built-in method index of Bond object at 0x7f44f5173510>
# 586 <built-in method index of Bond object at 0x7f44f5173560>
# 587 <built-in method index of Bond object at 0x7f44f51735b0>
# 588 <built-in method index of Bond object at 0x7f44f5173600>
# 589 <built-in method index of Bond object at 0x7f44f5173650>
# 590 <built-in method index of Bond object at 0x7f44f51736a0>
# 591 <built-in method index of Bond object at 0x7f44f51736f0>
# 592 <built-in method index of Bond object at 0x7f44f5173740>
# 593 <built-in method index of Bond object at 0x7f44f5173790>
# 594 <built-in method index of Bond object at 0x7f44f51737e0>
# 595 <built-in method index of Bond object at 0x7f44f5173830>
# 596 <built-in method index of Bond object at 0x7f44f5173880>
# 597 <built-in method index of Bond object at 0x7f44f51738d0>
# 598 <built-in method index of Bond object at 0x7f44f5173920>
# 599 <built-in method index of Bond object at 0x7f44f5173970>
# 600 <built-in method index of Bond object at 0x7f44f51739c0>
# 601 <built-in method index of Bond object at 0x7f44f5173a10>
# 602 <built-in method index of Bond object at 0x7f44f5173a60>
# 603 <built-in method index of Bond object at 0x7f44f5173ab0>
# 604 <built-in method index of Bond object at 0x7f44f5173b00>
# 605 <built-in method index of Bond object at 0x7f44f5173b50>
# 606 <built-in method index of Bond object at 0x7f44f5173ba0>
# 607 <built-in method index of Bond object at 0x7f44f5173bf0>
# 608 <built-in method index of Bond object at 0x7f44f5173c40>
# 609 <built-in method index of Bond object at 0x7f44f5173c90>
# 610 <built-in method index of Bond object at 0x7f44f5173ce0>
# 611 <built-in method index of Bond object at 0x7f44f5173d30>
# 612 <built-in method index of Bond object at 0x7f44f5173d80>
# 613 <built-in method index of Bond object at 0x7f44f5173dd0>
# 614 <built-in method index of Bond object at 0x7f44f5173e20>
# 615 <built-in method index of Bond object at 0x7f44f5173e70>
# 616 <built-in method index of Bond object at 0x7f44f5173ec0>
# 617 <built-in method index of Bond object at 0x7f44f5173f10>
# 618 <built-in method index of Bond object at 0x7f44f5173f60>
# 619 <built-in method index of Bond object at 0x7f44f5173fb0>
# 620 <built-in method index of Bond object at 0x7f44f5178040>
# 621 <built-in method index of Bond object at 0x7f44f5178090>
# 622 <built-in method index of Bond object at 0x7f44f51780e0>
# 623 <built-in method index of Bond object at 0x7f44f5178130>
# 624 <built-in method index of Bond object at 0x7f44f5178180>
# 625 <built-in method index of Bond object at 0x7f44f51781d0>
# 626 <built-in method index of Bond object at 0x7f44f5178220>
# 627 <built-in method index of Bond object at 0x7f44f5178270>
# 628 <built-in method index of Bond object at 0x7f44f51782c0>
# 629 <built-in method index of Bond object at 0x7f44f5178310>
# 630 <built-in method index of Bond object at 0x7f44f5178360>
# 631 <built-in method index of Bond object at 0x7f44f51783b0>
# 632 <built-in method index of Bond object at 0x7f44f5178400>
# 633 <built-in method index of Bond object at 0x7f44f5178450>
# 634 <built-in method index of Bond object at 0x7f44f51784a0>
# 635 <built-in method index of Bond object at 0x7f44f51784f0>
# 636 <built-in method index of Bond object at 0x7f44f5178540>
# 637 <built-in method index of Bond object at 0x7f44f5178590>
# 638 <built-in method index of Bond object at 0x7f44f51785e0>
# 639 <built-in method index of Bond object at 0x7f44f5178630>
# 640 <built-in method index of Bond object at 0x7f44f5178680>
# 641 <built-in method index of Bond object at 0x7f44f51786d0>
# 642 <built-in method index of Bond object at 0x7f44f5178720>
# 643 <built-in method index of Bond object at 0x7f44f5178770>
# 644 <built-in method index of Bond object at 0x7f44f51787c0>
# 645 <built-in method index of Bond object at 0x7f44f5178810>
# 646 <built-in method index of Bond object at 0x7f44f5178860>
# 647 <built-in method index of Bond object at 0x7f44f51788b0>
# 648 <built-in method index of Bond object at 0x7f44f5178900>
# 649 <built-in method index of Bond object at 0x7f44f5178950>
# 650 <built-in method index of Bond object at 0x7f44f51789a0>
# 651 <built-in method index of Bond object at 0x7f44f51789f0>
# 652 <built-in method index of Bond object at 0x7f44f5178a40>
# 653 <built-in method index of Bond object at 0x7f44f5178a90>
# 654 <built-in method index of Bond object at 0x7f44f5178ae0>
# 655 <built-in method index of Bond object at 0x7f44f5178b30>
# 656 <built-in method index of Bond object at 0x7f44f5178b80>
# 657 <built-in method index of Bond object at 0x7f44f5178bd0>
# 658 <built-in method index of Bond object at 0x7f44f5178c20>
# 659 <built-in method index of Bond object at 0x7f44f5178c70>
# 660 <built-in method index of Bond object at 0x7f44f5178cc0>
# 661 <built-in method index of Bond object at 0x7f44f5178d10>
# 662 <built-in method index of Bond object at 0x7f44f5178d60>
# 663 <built-in method index of Bond object at 0x7f44f5178db0>
# 664 <built-in method index of Bond object at 0x7f44f5178e00>
# 665 <built-in method index of Bond object at 0x7f44f5178e50>
# 666 <built-in method index of Bond object at 0x7f44f5178ea0>
# 667 <built-in method index of Bond object at 0x7f44f5178ef0>
# 668 <built-in method index of Bond object at 0x7f44f5178f40>
# 669 <built-in method index of Bond object at 0x7f44f5178f90>
# 670 <built-in method index of Bond object at 0x7f44f5178fe0>
# 671 <built-in method index of Bond object at 0x7f44f5179030>
# 672 <built-in method index of Bond object at 0x7f44f5179080>
# 673 <built-in method index of Bond object at 0x7f44f51790d0>
# 674 <built-in method index of Bond object at 0x7f44f5179120>
# 675 <built-in method index of Bond object at 0x7f44f5179170>
# 676 <built-in method index of Bond object at 0x7f44f51791c0>
# 677 <built-in method index of Bond object at 0x7f44f5179210>
# 678 <built-in method index of Bond object at 0x7f44f5179260>
# 679 <built-in method index of Bond object at 0x7f44f51792b0>
# 680 <built-in method index of Bond object at 0x7f44f5179300>
# 681 <built-in method index of Bond object at 0x7f44f5179350>
# 682 <built-in method index of Bond object at 0x7f44f51793a0>
# 683 <built-in method index of Bond object at 0x7f44f51793f0>
# 684 <built-in method index of Bond object at 0x7f44f5179440>
# 685 <built-in method index of Bond object at 0x7f44f5179490>
# 686 <built-in method index of Bond object at 0x7f44f51794e0>
# 687 <built-in method index of Bond object at 0x7f44f5179530>
# 688 <built-in method index of Bond object at 0x7f44f5179580>
# 689 <built-in method index of Bond object at 0x7f44f51795d0>
# 690 <built-in method index of Bond object at 0x7f44f5179620>
# 691 <built-in method index of Bond object at 0x7f44f5179670>
# 692 <built-in method index of Bond object at 0x7f44f51796c0>
# 693 <built-in method index of Bond object at 0x7f44f5179710>
# 694 <built-in method index of Bond object at 0x7f44f5179760>
# 695 <built-in method index of Bond object at 0x7f44f51797b0>
# 696 <built-in method index of Bond object at 0x7f44f5179800>
# 697 <built-in method index of Bond object at 0x7f44f5179850>
# 698 <built-in method index of Bond object at 0x7f44f51798a0>
# 699 <built-in method index of Bond object at 0x7f44f51798f0>
# 700 <built-in method index of Bond object at 0x7f44f5179940>
# 701 <built-in method index of Bond object at 0x7f44f5179990>
# 702 <built-in method index of Bond object at 0x7f44f51799e0>
# 703 <built-in method index of Bond object at 0x7f44f5179a30>
# 704 <built-in method index of Bond object at 0x7f44f5179a80>
# 705 <built-in method index of Bond object at 0x7f44f5179ad0>
# 706 <built-in method index of Bond object at 0x7f44f5179b20>
# 707 <built-in method index of Bond object at 0x7f44f5179b70>
# 708 <built-in method index of Bond object at 0x7f44f5179bc0>
# 709 <built-in method index of Bond object at 0x7f44f5179c10>
# 710 <built-in method index of Bond object at 0x7f44f5179c60>
# 711 <built-in method index of Bond object at 0x7f44f5179cb0>
# 712 <built-in method index of Bond object at 0x7f44f5179d00>
# 713 <built-in method index of Bond object at 0x7f44f5179d50>
# 714 <built-in method index of Bond object at 0x7f44f5179da0>
# 715 <built-in method index of Bond object at 0x7f44f5179df0>
# 716 <built-in method index of Bond object at 0x7f44f5179e40>
# 717 <built-in method index of Bond object at 0x7f44f5179e90>
# 718 <built-in method index of Bond object at 0x7f44f5179ee0>
# 719 <built-in method index of Bond object at 0x7f44f5179f30>
# 720 <built-in method index of Bond object at 0x7f44f5179f80>
# 721 <built-in method index of Bond object at 0x7f44f5179fd0>
# 722 <built-in method index of Bond object at 0x7f44f517a020>
# 723 <built-in method index of Bond object at 0x7f44f517a070>
# 724 <built-in method index of Bond object at 0x7f44f517a0c0>
# 725 <built-in method index of Bond object at 0x7f44f517a110>
# 726 <built-in method index of Bond object at 0x7f44f517a160>
# 727 <built-in method index of Bond object at 0x7f44f517a1b0>
# 728 <built-in method index of Bond object at 0x7f44f517a200>
# 729 <built-in method index of Bond object at 0x7f44f517a250>
# 730 <built-in method index of Bond object at 0x7f44f517a2a0>
# 731 <built-in method index of Bond object at 0x7f44f517a2f0>
# 732 <built-in method index of Bond object at 0x7f44f517a340>
# 733 <built-in method index of Bond object at 0x7f44f517a390>
# 734 <built-in method index of Bond object at 0x7f44f517a3e0>
# 735 <built-in method index of Bond object at 0x7f44f517a430>
# 736 <built-in method index of Bond object at 0x7f44f517a480>
# 737 <built-in method index of Bond object at 0x7f44f517a4d0>
# 738 <built-in method index of Bond object at 0x7f44f517a520>
# 739 <built-in method index of Bond object at 0x7f44f517a570>
# 740 <built-in method index of Bond object at 0x7f44f517a5c0>
# 741 <built-in method index of Bond object at 0x7f44f517a610>
# 742 <built-in method index of Bond object at 0x7f44f517a660>
# 743 <built-in method index of Bond object at 0x7f44f517a6b0>
# 744 <built-in method index of Bond object at 0x7f44f517a700>
# 745 <built-in method index of Bond object at 0x7f44f517a750>
# 746 <built-in method index of Bond object at 0x7f44f517a7a0>
# 747 <built-in method index of Bond object at 0x7f44f517a7f0>
# 748 <built-in method index of Bond object at 0x7f44f517a840>
# 749 <built-in method index of Bond object at 0x7f44f517a890>
# 750 <built-in method index of Bond object at 0x7f44f517a8e0>
# 751 <built-in method index of Bond object at 0x7f44f517a930>
# 752 <built-in method index of Bond object at 0x7f44f517a980>
# 753 <built-in method index of Bond object at 0x7f44f517a9d0>
# 754 <built-in method index of Bond object at 0x7f44f517aa20>
# 755 <built-in method index of Bond object at 0x7f44f517aa70>
# 756 <built-in method index of Bond object at 0x7f44f517aac0>
# 757 <built-in method index of Bond object at 0x7f44f517ab10>
# 758 <built-in method index of Bond object at 0x7f44f517ab60>
# 759 <built-in method index of Bond object at 0x7f44f517abb0>
# 760 <built-in method index of Bond object at 0x7f44f517ac00>
# 761 <built-in method index of Bond object at 0x7f44f517ac50>
# 762 <built-in method index of Bond object at 0x7f44f517aca0>
# 763 <built-in method index of Bond object at 0x7f44f517acf0>
# 764 <built-in method index of Bond object at 0x7f44f517ad40>
# 765 <built-in method index of Bond object at 0x7f44f517ad90>
# 766 <built-in method index of Bond object at 0x7f44f517ade0>
# 767 <built-in method index of Bond object at 0x7f44f517ae30>
# 768 <built-in method index of Bond object at 0x7f44f517ae80>
# 769 <built-in method index of Bond object at 0x7f44f517aed0>
# 770 <built-in method index of Bond object at 0x7f44f517af20>
# 771 <built-in method index of Bond object at 0x7f44f517af70>
# 772 <built-in method index of Bond object at 0x7f44f517afc0>
# 773 <built-in method index of Bond object at 0x7f44f517b010>
# 774 <built-in method index of Bond object at 0x7f44f517b060>
# 775 <built-in method index of Bond object at 0x7f44f517b0b0>
# 776 <built-in method index of Bond object at 0x7f44f517b100>
# 777 <built-in method index of Bond object at 0x7f44f517b150>
# 778 <built-in method index of Bond object at 0x7f44f517b1a0>
# 779 <built-in method index of Bond object at 0x7f44f517b1f0>
# 780 <built-in method index of Bond object at 0x7f44f517b240>
# 781 <built-in method index of Bond object at 0x7f44f517b290>
# 782 <built-in method index of Bond object at 0x7f44f517b2e0>
# 783 <built-in method index of Bond object at 0x7f44f517b330>
# 784 <built-in method index of Bond object at 0x7f44f517b380>
# 785 <built-in method index of Bond object at 0x7f44f517b3d0>
# 786 <built-in method index of Bond object at 0x7f44f517b420>
# 787 <built-in method index of Bond object at 0x7f44f517b470>
# ...
# 273501 <built-in method index of Bond object at 0x7f44eeea2930>
# 273502 <built-in method index of Bond object at 0x7f44eeea2980>
# 273503 <built-in method index of Bond object at 0x7f44eeea29d0>
# 273504 <built-in method index of Bond object at 0x7f44eeea2a20>
# 273505 <built-in method index of Bond object at 0x7f44eeea2a70>
# 273506 <built-in method index of Bond object at 0x7f44eeea2ac0>
# 273507 <built-in method index of Bond object at 0x7f44eeea2b10>
# 273508 <built-in method index of Bond object at 0x7f44eeea2b60>
# 273509 <built-in method index of Bond object at 0x7f44eeea2bb0>
# 273510 <built-in method index of Bond object at 0x7f44eeea2c00>
# 273511 <built-in method index of Bond object at 0x7f44eeea2c50>
# 273512 <built-in method index of Bond object at 0x7f44eeea2ca0>
# 273513 <built-in method index of Bond object at 0x7f44eeea2cf0>
# 273514 <built-in method index of Bond object at 0x7f44eeea2d40>
# 273515 <built-in method index of Bond object at 0x7f44eeea2d90>
# 273516 <built-in method index of Bond object at 0x7f44eeea2de0>
# 273517 <built-in method index of Bond object at 0x7f44eeea2e30>
# 273518 <built-in method index of Bond object at 0x7f44eeea2e80>
# 273519 <built-in method index of Bond object at 0x7f44eeea2ed0>
# 273520 <built-in method index of Bond object at 0x7f44eeea2f20>
# 273521 <built-in method index of Bond object at 0x7f44eeea2f70>
# 273522 <built-in method index of Bond object at 0x7f44eeea2fc0>
# 273523 <built-in method index of Bond object at 0x7f44eeea3010>
# 273524 <built-in method index of Bond object at 0x7f44eeea3060>
# 273525 <built-in method index of Bond object at 0x7f44eeea30b0>
# 273526 <built-in method index of Bond object at 0x7f44eeea3100>
# 273527 <built-in method index of Bond object at 0x7f44eeea3150>
# 273528 <built-in method index of Bond object at 0x7f44eeea31a0>
# 273529 <built-in method index of Bond object at 0x7f44eeea31f0>
# 273530 <built-in method index of Bond object at 0x7f44eeea3240>
# 273531 <built-in method index of Bond object at 0x7f44eeea3290>
# 273532 <built-in method index of Bond object at 0x7f44eeea32e0>
# 273533 <built-in method index of Bond object at 0x7f44eeea3330>
# 273534 <built-in method index of Bond object at 0x7f44eeea3380>
# 273535 <built-in method index of Bond object at 0x7f44eeea33d0>
# 273536 <built-in method index of Bond object at 0x7f44eeea3420>
# 273537 <built-in method index of Bond object at 0x7f44eeea3470>
# 273538 <built-in method index of Bond object at 0x7f44eeea34c0>
# 273539 <built-in method index of Bond object at 0x7f44eeea3510>
# 273540 <built-in method index of Bond object at 0x7f44eeea3560>
# 273541 <built-in method index of Bond object at 0x7f44eeea35b0>
# 273542 <built-in method index of Bond object at 0x7f44eeea3600>
# 273543 <built-in method index of Bond object at 0x7f44eeea3650>
# 273544 <built-in method index of Bond object at 0x7f44eeea36a0>
# 273545 <built-in method index of Bond object at 0x7f44eeea36f0>
# 273546 <built-in method index of Bond object at 0x7f44eeea3740>
# 273547 <built-in method index of Bond object at 0x7f44eeea3790>
# 273548 <built-in method index of Bond object at 0x7f44eeea37e0>
# 273549 <built-in method index of Bond object at 0x7f44eeea3830>
# 273550 <built-in method index of Bond object at 0x7f44eeea3880>
# 273551 <built-in method index of Bond object at 0x7f44eeea38d0>
# 273552 <built-in method index of Bond object at 0x7f44eeea3920>
# 273553 <built-in method index of Bond object at 0x7f44eeea3970>
# 273554 <built-in method index of Bond object at 0x7f44eeea39c0>
# 273555 <built-in method index of Bond object at 0x7f44eeea3a10>
# 273556 <built-in method index of Bond object at 0x7f44eeea3a60>
# 273557 <built-in method index of Bond object at 0x7f44eeea3ab0>
# 273558 <built-in method index of Bond object at 0x7f44eeea3b00>
# 273559 <built-in method index of Bond object at 0x7f44eeea3b50>
# 273560 <built-in method index of Bond object at 0x7f44eeea3ba0>
# 273561 <built-in method index of Bond object at 0x7f44eeea3bf0>
# 273562 <built-in method index of Bond object at 0x7f44eeea3c40>
# 273563 <built-in method index of Bond object at 0x7f44eeea3c90>
# 273564 <built-in method index of Bond object at 0x7f44eeea3ce0>
# 273565 <built-in method index of Bond object at 0x7f44eeea3d30>
# 273566 <built-in method index of Bond object at 0x7f44eeea3d80>
# 273567 <built-in method index of Bond object at 0x7f44eeea3dd0>
# 273568 <built-in method index of Bond object at 0x7f44eeea3e20>
# 273569 <built-in method index of Bond object at 0x7f44eeea3e70>
# 273570 <built-in method index of Bond object at 0x7f44eeea3ec0>
# 273571 <built-in method index of Bond object at 0x7f44eeea3f10>
# 273572 <built-in method index of Bond object at 0x7f44eeea3f60>
# 273573 <built-in method index of Bond object at 0x7f44eeea3fb0>
# 273574 <built-in method index of Bond object at 0x7f44eeeac040>
# 273575 <built-in method index of Bond object at 0x7f44eeeac090>
# 273576 <built-in method index of Bond object at 0x7f44eeeac0e0>
# 273577 <built-in method index of Bond object at 0x7f44eeeac130>
# 273578 <built-in method index of Bond object at 0x7f44eeeac180>
# 273579 <built-in method index of Bond object at 0x7f44eeeac1d0>
# 273580 <built-in method index of Bond object at 0x7f44eeeac220>
# 273581 <built-in method index of Bond object at 0x7f44eeeac270>
# 273582 <built-in method index of Bond object at 0x7f44eeeac2c0>
# 273583 <built-in method index of Bond object at 0x7f44eeeac310>
# 273584 <built-in method index of Bond object at 0x7f44eeeac360>
# 273585 <built-in method index of Bond object at 0x7f44eeeac3b0>
# 273586 <built-in method index of Bond object at 0x7f44eeeac400>
# 273587 <built-in method index of Bond object at 0x7f44eeeac450>
# 273588 <built-in method index of Bond object at 0x7f44eeeac4a0>
# 273589 <built-in method index of Bond object at 0x7f44eeeac4f0>
# 273590 <built-in method index of Bond object at 0x7f44eeeac540>
# 273591 <built-in method index of Bond object at 0x7f44eeeac590>
# 273592 <built-in method index of Bond object at 0x7f44eeeac5e0>
# 273593 <built-in method index of Bond object at 0x7f44eeeac630>
# 273594 <built-in method index of Bond object at 0x7f44eeeac680>
# 273595 <built-in method index of Bond object at 0x7f44eeeac6d0>
# 273596 <built-in method index of Bond object at 0x7f44eeeac720>
# 273597 <built-in method index of Bond object at 0x7f44eeeac770>
# 273598 <built-in method index of Bond object at 0x7f44eeeac7c0>
# 273599 <built-in method index of Bond object at 0x7f44eeeac810>
# 273600 <built-in method index of Bond object at 0x7f44eeeac860>
# 273601 <built-in method index of Bond object at 0x7f44eeeac8b0>
# 273602 <built-in method index of Bond object at 0x7f44eeeac900>
# 273603 <built-in method index of Bond object at 0x7f44eeeac950>
# 273604 <built-in method index of Bond object at 0x7f44eeeac9a0>
# 273605 <built-in method index of Bond object at 0x7f44eeeac9f0>
# 273606 <built-in method index of Bond object at 0x7f44eeeaca40>
# 273607 <built-in method index of Bond object at 0x7f44eeeaca90>
# 273608 <built-in method index of Bond object at 0x7f44eeeacae0>
# 273609 <built-in method index of Bond object at 0x7f44eeeacb30>
# 273610 <built-in method index of Bond object at 0x7f44eeeacb80>
# 273611 <built-in method index of Bond object at 0x7f44eeeacbd0>
# 273612 <built-in method index of Bond object at 0x7f44eeeacc20>
# 273613 <built-in method index of Bond object at 0x7f44eeeacc70>
# 273614 <built-in method index of Bond object at 0x7f44eeeaccc0>
# 273615 <built-in method index of Bond object at 0x7f44eeeacd10>
# 273616 <built-in method index of Bond object at 0x7f44eeeacd60>
# 273617 <built-in method index of Bond object at 0x7f44eeeacdb0>
# 273618 <built-in method index of Bond object at 0x7f44eeeace00>
# 273619 <built-in method index of Bond object at 0x7f44eeeace50>
# 273620 <built-in method index of Bond object at 0x7f44eeeacea0>
# 273621 <built-in method index of Bond object at 0x7f44eeeacef0>
# 273622 <built-in method index of Bond object at 0x7f44eeeacf40>
# 273623 <built-in method index of Bond object at 0x7f44eeeacf90>
# 273624 <built-in method index of Bond object at 0x7f44eeeacfe0>
# 273625 <built-in method index of Bond object at 0x7f44eeead030>
# 273626 <built-in method index of Bond object at 0x7f44eeead080>
# 273627 <built-in method index of Bond object at 0x7f44eeead0d0>
# 273628 <built-in method index of Bond object at 0x7f44eeead120>
# 273629 <built-in method index of Bond object at 0x7f44eeead170>
# 273630 <built-in method index of Bond object at 0x7f44eeead1c0>
# 273631 <built-in method index of Bond object at 0x7f44eeead210>
# 273632 <built-in method index of Bond object at 0x7f44eeead260>
# 273633 <built-in method index of Bond object at 0x7f44eeead2b0>
# 273634 <built-in method index of Bond object at 0x7f44eeead300>
# 273635 <built-in method index of Bond object at 0x7f44eeead350>
# 273636 <built-in method index of Bond object at 0x7f44eeead3a0>
# 273637 <built-in method index of Bond object at 0x7f44eeead3f0>
# 273638 <built-in method index of Bond object at 0x7f44eeead440>
# 273639 <built-in method index of Bond object at 0x7f44eeead490>
# 273640 <built-in method index of Bond object at 0x7f44eeead4e0>
# 273641 <built-in method index of Bond object at 0x7f44eeead530>
# 273642 <built-in method index of Bond object at 0x7f44eeead580>
# 273643 <built-in method index of Bond object at 0x7f44eeead5d0>
# 273644 <built-in method index of Bond object at 0x7f44eeead620>
# 273645 <built-in method index of Bond object at 0x7f44eeead670>
# 273646 <built-in method index of Bond object at 0x7f44eeead6c0>
# 273647 <built-in method index of Bond object at 0x7f44eeead710>
# 273648 <built-in method index of Bond object at 0x7f44eeead760>
# 273649 <built-in method index of Bond object at 0x7f44eeead7b0>
# 273650 <built-in method index of Bond object at 0x7f44eeead800>
# 273651 <built-in method index of Bond object at 0x7f44eeead850>
# 273652 <built-in method index of Bond object at 0x7f44eeead8a0>
# 273653 <built-in method index of Bond object at 0x7f44eeead8f0>
# 273654 <built-in method index of Bond object at 0x7f44eeead940>
# 273655 <built-in method index of Bond object at 0x7f44eeead990>
# 273656 <built-in method index of Bond object at 0x7f44eeead9e0>
# 273657 <built-in method index of Bond object at 0x7f44eeeada30>
# 273658 <built-in method index of Bond object at 0x7f44eeeada80>
# 273659 <built-in method index of Bond object at 0x7f44eeeadad0>
# 273660 <built-in method index of Bond object at 0x7f44eeeadb20>
# 273661 <built-in method index of Bond object at 0x7f44eeeadb70>
# 273662 <built-in method index of Bond object at 0x7f44eeeadbc0>
# 273663 <built-in method index of Bond object at 0x7f44eeeadc10>
# 273664 <built-in method index of Bond object at 0x7f44eeeadc60>
# 273665 <built-in method index of Bond object at 0x7f44eeeadcb0>
# 273666 <built-in method index of Bond object at 0x7f44eeeadd00>
# 273667 <built-in method index of Bond object at 0x7f44eeeadd50>
# 273668 <built-in method index of Bond object at 0x7f44eeeadda0>
# 273669 <built-in method index of Bond object at 0x7f44eeeaddf0>
# 273670 <built-in method index of Bond object at 0x7f44eeeade40>
# 273671 <built-in method index of Bond object at 0x7f44eeeade90>
# 273672 <built-in method index of Bond object at 0x7f44eeeadee0>
# 273673 <built-in method index of Bond object at 0x7f44eeeadf30>
# 273674 <built-in method index of Bond object at 0x7f44eeeadf80>
# 273675 <built-in method index of Bond object at 0x7f44eeeadfd0>
# 273676 <built-in method index of Bond object at 0x7f44eeeae020>
# 273677 <built-in method index of Bond object at 0x7f44eeeae070>
# 273678 <built-in method index of Bond object at 0x7f44eeeae0c0>
# 273679 <built-in method index of Bond object at 0x7f44eeeae110>
# 273680 <built-in method index of Bond object at 0x7f44eeeae160>
# 273681 <built-in method index of Bond object at 0x7f44eeeae1b0>
# 273682 <built-in method index of Bond object at 0x7f44eeeae200>
# 273683 <built-in method index of Bond object at 0x7f44eeeae250>
# 273684 <built-in method index of Bond object at 0x7f44eeeae2a0>
# 273685 <built-in method index of Bond object at 0x7f44eeeae2f0>
# 273686 <built-in method index of Bond object at 0x7f44eeeae340>
# 273687 <built-in method index of Bond object at 0x7f44eeeae390>
# 273688 <built-in method index of Bond object at 0x7f44eeeae3e0>
# 273689 <built-in method index of Bond object at 0x7f44eeeae430>
# 273690 <built-in method index of Bond object at 0x7f44eeeae480>
# 273691 <built-in method index of Bond object at 0x7f44eeeae4d0>
# 273692 <built-in method index of Bond object at 0x7f44eeeae520>
# 273693 <built-in method index of Bond object at 0x7f44eeeae570>
# 273694 <built-in method index of Bond object at 0x7f44eeeae5c0>
# 273695 <built-in method index of Bond object at 0x7f44eeeae610>
# 273696 <built-in method index of Bond object at 0x7f44eeeae660>
# 273697 <built-in method index of Bond object at 0x7f44eeeae6b0>
# 273698 <built-in method index of Bond object at 0x7f44eeeae700>
# 273699 <built-in method index of Bond object at 0x7f44eeeae750>
# 273700 <built-in method index of Bond object at 0x7f44eeeae7a0>
# 273701 <built-in method index of Bond object at 0x7f44eeeae7f0>
# 273702 <built-in method index of Bond object at 0x7f44eeeae840>
# 273703 <built-in method index of Bond object at 0x7f44eeeae890>
# 273704 <built-in method index of Bond object at 0x7f44eeeae8e0>
# 273705 <built-in method index of Bond object at 0x7f44eeeae930>
# 273706 <built-in method index of Bond object at 0x7f44eeeae980>
# 273707 <built-in method index of Bond object at 0x7f44eeeae9d0>
# 273708 <built-in method index of Bond object at 0x7f44eeeaea20>
# 273709 <built-in method index of Bond object at 0x7f44eeeaea70>
# 273710 <built-in method index of Bond object at 0x7f44eeeaeac0>
# 273711 <built-in method index of Bond object at 0x7f44eeeaeb10>
# 273712 <built-in method index of Bond object at 0x7f44eeeaeb60>
# 273713 <built-in method index of Bond object at 0x7f44eeeaebb0>
# 273714 <built-in method index of Bond object at 0x7f44eeeaec00>
# 273715 <built-in method index of Bond object at 0x7f44eeeaec50>
# 273716 <built-in method index of Bond object at 0x7f44eeeaeca0>
# 273717 <built-in method index of Bond object at 0x7f44eeeaecf0>
# 273718 <built-in method index of Bond object at 0x7f44eeeaed40>
# 273719 <built-in method index of Bond object at 0x7f44eeeaed90>
# 273720 <built-in method index of Bond object at 0x7f44eeeaede0>
# 273721 <built-in method index of Bond object at 0x7f44eeeaee30>
# 273722 <built-in method index of Bond object at 0x7f44eeeaee80>
# 273723 <built-in method index of Bond object at 0x7f44eeeaeed0>
# 273724 <built-in method index of Bond object at 0x7f44eeeaef20>
# 273725 <built-in method index of Bond object at 0x7f44eeeaef70>
# 273726 <built-in method index of Bond object at 0x7f44eeeaefc0>
# 273727 <built-in method index of Bond object at 0x7f44eeeaf010>
# 273728 <built-in method index of Bond object at 0x7f44eeeaf060>
# 273729 <built-in method index of Bond object at 0x7f44eeeaf0b0>
# 273730 <built-in method index of Bond object at 0x7f44eeeaf100>
# 273731 <built-in method index of Bond object at 0x7f44eeeaf150>
# 273732 <built-in method index of Bond object at 0x7f44eeeaf1a0>
# 273733 <built-in method index of Bond object at 0x7f44eeeaf1f0>
# 273734 <built-in method index of Bond object at 0x7f44eeeaf240>
# 273735 <built-in method index of Bond object at 0x7f44eeeaf290>
# 273736 <built-in method index of Bond object at 0x7f44eeeaf2e0>
# 273737 <built-in method index of Bond object at 0x7f44eeeaf330>
# 273738 <built-in method index of Bond object at 0x7f44eeeaf380>
# 273739 <built-in method index of Bond object at 0x7f44eeeaf3d0>
# 273740 <built-in method index of Bond object at 0x7f44eeeaf420>
# 273741 <built-in method index of Bond object at 0x7f44eeeaf470>
# 273742 <built-in method index of Bond object at 0x7f44eeeaf4c0>
# 273743 <built-in method index of Bond object at 0x7f44eeeaf510>
# 273744 <built-in method index of Bond object at 0x7f44eeeaf560>
# 273745 <built-in method index of Bond object at 0x7f44eeeaf5b0>
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
chain.
