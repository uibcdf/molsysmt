# %%
import molsysmt as msm

# %%
molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')

# %%
msm.info(molecular_system)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15a1c">
#   <thead>
#     <tr>
#       <th id="T_15a1c_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_15a1c_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_15a1c_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_15a1c_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_15a1c_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_15a1c_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_15a1c_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_15a1c_level0_col7" class="col_heading level0 col7" >n_proteins</th>
#       <th id="T_15a1c_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15a1c_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_15a1c_row0_col1" class="data row0 col1" >4638</td>
#       <td id="T_15a1c_row0_col2" class="data row0 col2" >588</td>
#       <td id="T_15a1c_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_15a1c_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_15a1c_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_15a1c_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_15a1c_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_15a1c_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
msm.view(molecular_system, selection='molecule_index==0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 msm.view(molecular_system, selection='molecule_index==0')
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/view.py:95, in view(molecular_system, selection, structure_indices, viewer, syntax, skip_digestion)
#      90 if viewer not in _dict_view:
#      91     raise ModuleNotFoundError(
#      92         f"Viewer backend '{viewer}' is not available. Install the optional dependency if required."
#      93     )
# ---> 95 return _dict_view[viewer](
#      96     molecular_system=molecular_system,
#      97     selection=selection,
#      98     structure_indices=structure_indices,
#      99     syntax=syntax,
#     100     skip_digestion=True,
#     101 )
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/viewer/molsysviewer.py:6, in view(molecular_system, selection, structure_indices, syntax, skip_digestion)
#       1 def view(molecular_system=None, selection='all', structure_indices='all', syntax='MolSysMT',
#       2          skip_digestion=False):
#       4     from molsysviewer import new_view
# ----> 6     return new_view(
#       7         molecular_system=molecular_system,
#       8         selection=selection,
#       9         structure_indices=structure_indices,
#      10         syntax=syntax,
#      11         skip_digestion=skip_digestion,
#      12     )
#
# TypeError: new_view() got an unexpected keyword argument 'syntax'
