# %%
import molsysmt as msm
from molsysmt import systems
# Out:
# MOLSYSMT WARNING [py.warnings] | UserWarning [nglview] (__init__.py:12): pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
topology = msm.convert(systems['TcTIM']['1tcd.h5msm'], to_form='molsysmt.Topology')

# %%
topology.groups['group_id']
# Out:
# 0        4
# 1        5
# 2        6
# 3        7
# 4        8
#       ...
# 657    339
# 658    340
# 659    341
# 660    342
# 661    343
# Name: group_id, Length: 662, dtype: object
