# %%
import molsysmt as msm
from molsysmt import systems

# %%
molsys = msm.convert(systems['chicken villin HP35']['chicken_villin_HP35_solvated.h5msm'], to_form='molsysmt.MolSys')

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_38b99">
#   <thead>
#     <tr>
#       <th id="T_38b99_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_38b99_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_38b99_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_38b99_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_38b99_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_38b99_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_38b99_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_38b99_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_38b99_level0_col8" class="col_heading level0 col8" >n_ions</th>
#       <th id="T_38b99_level0_col9" class="col_heading level0 col9" >n_peptides</th>
#       <th id="T_38b99_level0_col10" class="col_heading level0 col10" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38b99_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_38b99_row0_col1" class="data row0 col1" >4369</td>
#       <td id="T_38b99_row0_col2" class="data row0 col2" >1294</td>
#       <td id="T_38b99_row0_col3" class="data row0 col3" >1257</td>
#       <td id="T_38b99_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_38b99_row0_col5" class="data row0 col5" >1257</td>
#       <td id="T_38b99_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_38b99_row0_col7" class="data row0 col7" >1254</td>
#       <td id="T_38b99_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_38b99_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_38b99_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#   </tbody>
# </table>
