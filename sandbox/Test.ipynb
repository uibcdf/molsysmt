# %%
import molsysmt as msm

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_n_proteins_from_molecule(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_n_proteins_from_molecule(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_n_proteins_from_molecule(molsys_Hk2.topology, [4,5,6], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_n_proteins_from_molecule(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
all_Hk2

# %%
all_BB

# %%
list_Hk2

# %%
list_BB

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[15:25]

# %%
all_Hk2[105:115]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[3:13]

# %%
all_BB[486:492]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2[0][50:60]

# %%
list_Hk2

# %%
list_BB

# %%
len(list_Hk2[0])

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[15:25]

# %%
all_Hk2[105:115]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[3:13]

# %%
all_BB[5:8]

# %%
all_BB[486:492]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_Hk2[1:]

# %%
list_BB

# %%
len(3)

# %%
type(sorted(set([3,2,1])))
