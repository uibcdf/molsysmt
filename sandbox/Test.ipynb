# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from molsysmt import systems
import numpy as np
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
molsys_bcif = msm.convert('2CCY', to_form='bcifreader.PdbxContainers.DataContainer')

# %%
molsys = msm.convert(molsys_bcif)
# Out:
# /home/diego/repos@uibcdf/molsysmt/molsysmt/_private/warnings/check_struct_conn_new_covalent_bonds.py:34: UserWarning: [MolSysMT Warning] 4 covalent bond(s) reported by the 'struct_conn' table between atoms belonging to different chains were added.
# Verify whether these cross-chain bonds are expected in your system.
#   - SG 847 in CYS118 with atom_index 842  <-->  CAB 1889 in HEC129 with atom_index 1880
#   - SG 867 in CYS121 with atom_index 862  <-->  CAC 1897 in HEC129 with atom_index 1888
#   - SG 1780 in CYS118 with atom_index 1771  <-->  CAB 1932 in HEC129 with atom_index 1923
#   - SG 1800 in CYS121 with atom_index 1791  <-->  CAC 1940 in HEC129 with atom_index 1931
#
#   warnings.warn(msg, UserWarning)

# %%
msm.info(molsys, element='molecule')

# %%
sorted([[6,5],[3,5]])

# %%
aa = molsys_bcif.getObjCatalog()

# %%
aa['atom_site']

# %%
for ii in aa['atom_site'].data:
    if ii[3]=='CAB':
        print(ii)

# %%
aa['atom_site'].getAttributeList()

# %%
msm.info(molsys, element='atom', selection='atom_type=="CA"')

# %%
msm.info(molsys, element='molecule')

# %%
aa['entity_poly']

# %%
aa['chem_comp']

# %%
aa['pdbx_entity_nonpoly']

# %%
aa['entity']

# %%
aa['pdbx_branch_scheme']

# %%
aa['struct_conn']

# %%
for ii in aa['struct_conn'].data:
    if ii[1]=='covale':
        print(ii)

# %%
msm.element.group.get_group_type_from_group_name('ATP')

# %%
aa['chem_comp_bond']

# %%
aa['entity_poly']

# %%
msm.info(molsys, element='chain')

# %%
aa = 'p'

# %%
'g'+aa[1:]

# %%
ord('A')
