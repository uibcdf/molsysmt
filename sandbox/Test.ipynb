# %%
import molsysmt as msm
# Out:
# /conda/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
#%%timeit -n 50 -r 25
all_Hk2 = msm.form.molsysmt_Topology.get_component_type_from_chain(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_component_type_from_chain(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_component_type_from_chain(molsys_Hk2.topology, [3,4,5], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_component_type_from_chain(molsys_BB.topology, [3,4], skip_digestion=True)

# %%
len(all_Hk2)
# Out:
# 40

# %%
len(all_BB)
# Out:
# 12

# %%
all_Hk2[0]
# Out:
# ['protein', 'protein', 'peptide', 'peptide', 'protein', 'protein']

# %%
all_Hk2[2:6]
# Out:
# [['polysaccharide'],
#  ['polysaccharide'],
#  ['polysaccharide'],
#  ['polysaccharide']]

# %%
all_Hk2[30]
# Out:
# ['ion']

# %%
all_BB[:6]
# Out:
# [['protein'],
#  ['protein'],
#  ['protein'],
#  ['protein', 'peptide'],
#  ['protein', 'peptide'],
#  ['protein']]

# %%
list_Hk2
# Out:
# [['polysaccharide'], ['polysaccharide'], ['polysaccharide']]

# %%
list_BB
# Out:
# [['protein', 'peptide'], ['protein', 'peptide']]
