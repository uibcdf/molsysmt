# %%
import molsysmt as msm
# Out:
# MOLSYSMT WARNING | UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
topology = msm.convert(msm.systems['TcTIM']['1tcd.h5msm'], to_form='molsysmt.Topology')

# %%
topology.get_atom_indices(atom_id=43, group_name='ALA')
# Out:
# [42]

# %%
msm.info(topology, element='atom', selection=[42])
# Out:
# <style type="text/css">
# </style>
# <table id="T_963df">
#   <thead>
#     <tr>
#       <th id="T_963df_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_963df_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_963df_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_963df_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_963df_level0_col4" class="col_heading level0 col4" >group index</th>
#       <th id="T_963df_level0_col5" class="col_heading level0 col5" >group id</th>
#       <th id="T_963df_level0_col6" class="col_heading level0 col6" >group name</th>
#       <th id="T_963df_level0_col7" class="col_heading level0 col7" >group type</th>
#       <th id="T_963df_level0_col8" class="col_heading level0 col8" >component index</th>
#       <th id="T_963df_level0_col9" class="col_heading level0 col9" >chain index</th>
# ...

# %%
[0,3,4]==[0,3,4]
