# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
import pandas as pd
import numpy as np
# Out:
# /conda/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
msm.info(msm.systems['POPC membrane']['popc_membrane'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c37d">
#   <thead>
#     <tr>
#       <th id="T_3c37d_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_3c37d_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_3c37d_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_3c37d_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_3c37d_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_3c37d_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_3c37d_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_3c37d_level0_col7" class="col_heading level0 col7" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c37d_row0_col0" class="data row0 col0" >file:msmpk</td>
#       <td id="T_3c37d_row0_col1" class="data row0 col1" >None</td>
# ...
