# %%
import molsysmt as msm
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_entity_id_from_molecule(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_entity_id_from_molecule(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_entity_id_from_molecule(molsys_Hk2.topology, [1,2,3], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_entity_id_from_molecule(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
len(all_Hk2)
# Out:
# 135

# %%
len(all_BB)
# Out:
# 519

# %%
all_Hk2[15:25]
# Out:
# [4, 4, 4, 2, 3, 2, 3, 4, 4, 4]

# %%
all_Hk2[105:115]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[3:13]

# %%
all_BB[5:8]

# %%
all_BB[486:492]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_Hk2[1:]

# %%
list_BB
