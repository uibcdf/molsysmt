# %%
import molsysmt as msm
# Out:
# /conda/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_n_molecules_from_group(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_n_molecules_from_group(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_n_molecules_from_group(molsys_Hk2.topology, [4,5,6], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_n_molecules_from_group(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
list_Hk2
# Out:
# 1

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[344:347]

# %%
all_Hk2[1750:1755]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[385:388]

# %%
all_BB[586:592]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_BB
