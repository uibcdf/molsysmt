# %%
import molsysmt as msm

# %%
molsys = msm.convert([msm.systems['nglview']['md_1u19.gro'], msm.systems['nglview']['md_1u19.xtc']],
                         to_form='molsysmt.MolSys')
# Out:
# WARNING: 'molsysmt.GROFileHandler' is a best-effort supported form (Tier 2). Results are supported but not contractually guaranteed for all workflows. (Hint: For production workflows, prefer Tier 1 forms where possible. See the support-tier documentation at https://www.uibcdf.org/MolSysMT)

# %%
view = msm.convert(molsys, to_form='nglview.NGLWidget')

# %%
check_comparison = msm.compare(molsys, view, attribute_type='topological', rule='equal',
                               redefine_indices=True, output_type='dictionary',
                               n_bonds=False, bonded_atom_pairs=False, bond_index=False,
                               bond_type=False, bond_order=False,
                               n_inner_bonds=False, inner_bonded_atom_pairs=False,
                               inner_bond_index=False)

# %%
check_comparison
