# %%
import molsysmt as msm
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
# %%timeit -n 50 -r 25
all_Hk2 = msm.form.molsysmt_Topology.get_n_peptides_from_group(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_n_peptides_from_group(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_n_peptides_from_group(molsys_Hk2.topology, [1,2,3], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_n_peptides_from_group(molsys_BB.topology, [1,2], skip_digestion=True)
# Out:
# 447 μs ± 87.9 μs per loop (mean ± std. dev. of 25 runs, 50 loops each)

# %%
msm.form.molsysmt_Topology.get_n_groups_from_system(molsys_BB.topology)

# %%
list_BB

# %%
1.47 ms ± 122 μs per loop (mean ± std. dev. of 100 runs, 200 loops each)

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_group_name_from_entity(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_group_name_from_entity(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_group_name_from_entity(molsys_Hk2.topology, [1,2,3], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_group_name_from_entity(molsys_BB.topology, [1,2], skip_digestion=True)

# %%
all_Hk2

# %%
all_BB

# %%
list_Hk2

# %%
list_BB

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[0][100:110]

# %%
all_Hk2[1]

# %%
all_Hk2[2]

# %%
all_Hk2[-1][10:20]

# %%
all_BB[0][200:210]

# %%
all_BB[1][105:115]

# %%
all_BB[2][105:115]

# %%
all_BB[-1]

# %%
list_Hk2[0][50:60]

# %%
list_Hk2[0]

# %%
list_BB[1][60:70]

# %%
import numpy as np

# %%
aa = np.zeros(10)

# %%
aa[[2,3,4]]

# %%
len(list_Hk2[0])

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[15:25]

# %%
all_Hk2[105:115]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[3:13]

# %%
all_BB[5:8]

# %%
all_BB[486:492]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_Hk2[1:]

# %%
list_BB

# %%
len(3)

# %%
type(sorted(set([3,2,1])))
