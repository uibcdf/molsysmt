# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from molsysmt import systems
import numpy as np
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
molsys_bcif = msm.convert('1LTS', to_form='bcifreader.PdbxContainers.DataContainer')

# %%
molsys = msm.convert(molsys_bcif)
# Out:
# ['HEAT-LABILE ENTEROTOXIN, SUBUNIT B' 'HEAT-LABILE ENTEROTOXIN, SUBUNIT A'
#  'HEAT-LABILE ENTEROTOXIN, SUBUNIT A' 'water']
# ['protein' 'protein' 'peptide' 'peptide']
# 0 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT B
# 0 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT B
# 0 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT B
# 0 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT B
# 0 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT B
# 1 protein HEAT-LABILE ENTEROTOXIN, SUBUNIT A
# 2 peptide HEAT-LABILE ENTEROTOXIN, SUBUNIT A
# 3 peptide water
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 molsys = msm.convert(molsys_bcif)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# ...

# %%
msm.view(molsys)

# %%
aa = molsys.getObjCatalog()

# %%
aa.keys()

# %%
aa['entity_poly']

# %%
aa['entity_poly']

# %%
att_list = aa['atom_site'].getAttributeList()
atom_0 = aa['atom_site'].data[-5]

# %%
for ii,jj in zip(att_list, atom_0):
    print(ii,jj)

# %%
aa['chem_comp']

# %%
aa['pdbx_entity_nonpoly']

# %%
aa['entity']
