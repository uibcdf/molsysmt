# %%
import molsysmt as msm
from molsysmt import systems

# %%
from molsysmt.form.file_h5msm import get_topological_attributes as aux

# %%
molsys_Hk2 = msm.systems['Hexokinase 2']['2nzt.h5msm']
molsys_BB = msm.systems['Barnase-Barstar']['1brs.h5msm']

# %%
all_atom_id_BB = aux.get_atom_id_from_component(molsys_BB, skip_digestion=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File h5py/_proxy.pyx:366, in h5py._proxy.needs_bkg_buffer()
#
# KeyError: 'Conversion function not found (no appropriate function for conversion path)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 all_atom_id_BB = aux.get_atom_id_from_component(molsys_BB, skip_digestion=True)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/file_h5msm/get_topological_attributes.py:3505, in get_atom_id_from_component(item, indices, skip_digestion)
#    3502 from ..molsysmt_H5MSMFileHandler import get_atom_id_from_component as aux_get
#    3504 tmp_item = to_molsysmt_H5MSMFileHandler(item, skip_digestion=True)
# -> 3505 output = aux_get(tmp_item, indices=indices, skip_digestion=True)
#    3506 tmp_item.close()
#    3508 return output
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/molsysmt_H5MSMFileHandler/get_topological_attributes.py:4724, in get_atom_id_from_component(item, indices, skip_digestion)
#    4722     aux_dict = defaultdict(list)
#    4723     for atom_index, component_index in enumerate(component_index_from_atom):
# -> 4724         aux_dict[component_index].append(atom_id_from_atom[atom_index])
#    4726     output = list(aux_dict.values())
#    4728 else:
#
# File ~/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/python3.12/site-packages/h5py/_hl/dataset.py:266, in AsTypeView.__getitem__(self, idx)
#     265 def __getitem__(self, idx):
# --> 266     return self._dset.__getitem__(idx, new_dtype=self._dtype)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/python3.12/site-packages/h5py/_hl/dataset.py:923, in Dataset.__getitem__(self, args, new_dtype)
#     921 mspace = h5s.create_simple(selection.mshape)
#     922 fspace = selection.id
# --> 923 self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     925 # Patch up the output for NumPy
#     926 if arr.shape == ():
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:260, in h5py.h5d.DatasetID.read()
#
# File h5py/_proxy.pyx:139, in h5py._proxy.dset_rw()
#
# File h5py/_proxy.pyx:368, in h5py._proxy.needs_bkg_buffer()
#
# TypeError: Operation not defined for data type class (operation not defined for data type class)
