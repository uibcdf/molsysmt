# %%
import molsysmt as msm

# %%
molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:518, in convert(molecular_system, to_form, selection, structure_indices, syntax, skip_digestion, **kwargs)
#     516 # If one to one
#     517 if not isinstance(from_form, (list, tuple)):
# --> 518     output = _convert_one_to_one(molecular_system, from_form, to_form=to_form, selection=selection, structure_indices=structure_indices,
#     519             syntax=syntax, skip_digestion=True, **kwargs)
#     521 # If multiple to one
#     522
#     523 else:
#     524
#     525     # conversions in private shortcuts
#     526     if tuple(sorted(from_form)) in _multiple_conversion_shortcuts:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:94, in _convert_one_to_one(molecular_system, from_form, to_form, selection, structure_indices, syntax, **kwargs)
#      91         if len(missing_arguments)>0:
#      92             raise NotCompatibleConversionError(from_form, to_form, missing_arguments)
# ---> 94     output = function(molecular_system, **conversion_arguments, **kwargs)
#      96 elif ('molsysmt.MolSys' in _dict_modules[from_form]._convert_to) and (to_form in _dict_modules['molsysmt.MolSys']._convert_to):
#      98     output = _convert_one_to_one(molecular_system, from_form, to_form='molsysmt.MolSys', selection=selection,
#      99             structure_indices=structure_indices, syntax=syntax, **kwargs)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/string_pdb_id/to_molsysmt_MolSys.py:10, in to_molsysmt_MolSys(item, atom_indices, structure_indices, skip_digestion)
#       7 from ..mmcif_PdbxContainers_DataContainer import to_molsysmt_MolSys as mmcif_PdbxContainers_DataContainer_to_molsysmt_MolSys
#       9 tmp_item = to_mmcif_PdbxContainers_DataContainer(item, skip_digestion=True)
# ---> 10 tmp_item = mmcif_PdbxContainers_DataContainer_to_molsysmt_MolSys(tmp_item, atom_indices=atom_indices,
#      11                                                           structure_indices=structure_indices, skip_digestion=True)
#      13 return tmp_item
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/mmcif_PdbxContainers_DataContainer/to_molsysmt_MolSys.py:829, in to_molsysmt_MolSys(item, atom_indices, structure_indices, skip_digestion)
#     825     warn(CrossChainCovalentBondsWarning(tmp_item, atom_pairs_bonded_by_struct_conn))
#     827 # Extract
# --> 829 tmp_item = tmp_item.extract(atom_indices=atom_indices, structure_indices=structure_indices,
#     830                             copy_if_all=False, skip_digestion=True)
#     832 return tmp_item
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/native/molsys.py:37, in MolSys.extract(self, atom_indices, structure_indices, copy_if_all, skip_digestion)
#      34 else:
#      36     tmp_item = MolSys()
# ---> 37     tmp_item.topology = self.topology.extract(atom_indices=atom_indices, copy_if_all=True, skip_digestion=True)
#      38     tmp_item.structures = self.structures.extract(atom_indices=atom_indices,
#      39                                                   structure_indices=structure_indices, copy_if_all=True,
#      40                                                   skip_digestion=True)
#      41     tmp_item.molecular_mechanics = self.molecular_mechanics.copy()
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:52, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#      48 @functools.wraps(func)
#      49 def wrapper(*args, **kwargs):
#      51     if kwargs.get('skip_digestion', False):
# ---> 52         return func(*args, **kwargs)
#      54     # Define caller
#      56     caller = func.__module__+'.'+func.__name__
#
# File ~/repos@uibcdf/molsysmt/molsysmt/native/topology.py:333, in Topology.extract(self, atom_indices, copy_if_all, skip_digestion)
#     330 tmp_item.chains.reset_index(drop=True, inplace=True)
#     331 del old_chain_indices
# --> 333 tmp_item.atoms['group_index'] = occurrence_order(tmp_item.atoms['group_index'].to_numpy(dtype=int))
#     334 tmp_item.groups['molecule_index'] = occurrence_order(tmp_item.groups['molecule_index'].to_numpy(dtype=int))
#     335 tmp_item.molecules['entity_index'] = occurrence_order(tmp_item.molecules['entity_index'].to_numpy(dtype=int))
#
# File /conda/miniconda3/envs/molsysmt@uibcdf_3.12/lib/python3.12/site-packages/numba/core/dispatcher.py:659, in _DispatcherBase._explain_matching_error(self, *args, **kws)
#     656 args = [self.typeof_pyval(a) for a in args]
#     657 msg = ("No matching definition for argument type(s) %s"
#     658        % ', '.join(map(str, args)))
# --> 659 raise TypeError(msg)
#
# TypeError: No matching definition for argument type(s) readonly array(int64, 1d, C)

# %%
msm.info(molecular_system)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e4a2">
#   <thead>
#     <tr>
#       <th id="T_9e4a2_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_9e4a2_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_9e4a2_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_9e4a2_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_9e4a2_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_9e4a2_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_9e4a2_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_9e4a2_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_9e4a2_level0_col8" class="col_heading level0 col8" >n_proteins</th>
#       <th id="T_9e4a2_level0_col9" class="col_heading level0 col9" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e4a2_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_9e4a2_row0_col1" class="data row0 col1" >5151</td>
#       <td id="T_9e4a2_row0_col2" class="data row0 col2" >1101</td>
#       <td id="T_9e4a2_row0_col3" class="data row0 col3" >521</td>
#       <td id="T_9e4a2_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_9e4a2_row0_col5" class="data row0 col5" >519</td>
#       <td id="T_9e4a2_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_9e4a2_row0_col7" class="data row0 col7" >513</td>
#       <td id="T_9e4a2_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_9e4a2_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
import molsysviewer as viewer

# %%
molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')

msm.info(molecular_system, element='molecule')

# %%
aa = viewer.new_view('1BRS')

# %%
aa.show()

# %%
molsys = msm.convert('1BRS', selection='molecule_type=="protein"')

# %%
msm.view(molecular_system, selection='molecule_index==0')
