# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from molsysmt import systems
import numpy as np
# Out:
# MOLSYSMT WARNING | UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
molsys_bcif = msm.convert('1ATN', to_form='bcifreader.PdbxContainers.DataContainer')

# %%
molsys = msm.convert('pdb_00001tcd')

# %%
msm.info(molsys, element='molecule')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2970">
#   <thead>
#     <tr>
#       <th id="T_a2970_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a2970_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_a2970_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_a2970_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_a2970_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_a2970_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_a2970_level0_col6" class="col_heading level0 col6" >chain index</th>
#       <th id="T_a2970_level0_col7" class="col_heading level0 col7" >entity index</th>
#       <th id="T_a2970_level0_col8" class="col_heading level0 col8" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2970_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a2970_row0_col1" class="data row0 col1" >TRIOSEPHOSPHATE ISOMERASE</td>
#       <td id="T_a2970_row0_col2" class="data row0 col2" >protein</td>
#       <td id="T_a2970_row0_col3" class="data row0 col3" >1906</td>
#       <td id="T_a2970_row0_col4" class="data row0 col4" >248</td>
#       <td id="T_a2970_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_a2970_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a2970_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_a2970_row0_col8" class="data row0 col8" >TRIOSEPHOSPHATE ISOMERASE</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a2970_row1_col1" class="data row1 col1" >TRIOSEPHOSPHATE ISOMERASE</td>
#       <td id="T_a2970_row1_col2" class="data row1 col2" >protein</td>
#       <td id="T_a2970_row1_col3" class="data row1 col3" >1912</td>
#       <td id="T_a2970_row1_col4" class="data row1 col4" >249</td>
#       <td id="T_a2970_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_a2970_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_a2970_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_a2970_row1_col8" class="data row1 col8" >TRIOSEPHOSPHATE ISOMERASE</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_a2970_row2_col1" class="data row2 col1" >water</td>
#       <td id="T_a2970_row2_col2" class="data row2 col2" >water</td>
#       <td id="T_a2970_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_a2970_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_a2970_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_a2970_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_a2970_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_a2970_row2_col8" class="data row2 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_a2970_row3_col1" class="data row3 col1" >water</td>
#       <td id="T_a2970_row3_col2" class="data row3 col2" >water</td>
#       <td id="T_a2970_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_a2970_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_a2970_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_a2970_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_a2970_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_a2970_row3_col8" class="data row3 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_a2970_row4_col1" class="data row4 col1" >water</td>
#       <td id="T_a2970_row4_col2" class="data row4 col2" >water</td>
#       <td id="T_a2970_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_a2970_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_a2970_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_a2970_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_a2970_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_a2970_row4_col8" class="data row4 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_a2970_row5_col1" class="data row5 col1" >water</td>
#       <td id="T_a2970_row5_col2" class="data row5 col2" >water</td>
#       <td id="T_a2970_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_a2970_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_a2970_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_a2970_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_a2970_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_a2970_row5_col8" class="data row5 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_a2970_row6_col1" class="data row6 col1" >water</td>
#       <td id="T_a2970_row6_col2" class="data row6 col2" >water</td>
#       <td id="T_a2970_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_a2970_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_a2970_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_a2970_row6_col6" class="data row6 col6" >2</td>
#       <td id="T_a2970_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_a2970_row6_col8" class="data row6 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_a2970_row7_col1" class="data row7 col1" >water</td>
#       <td id="T_a2970_row7_col2" class="data row7 col2" >water</td>
#       <td id="T_a2970_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_a2970_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_a2970_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_a2970_row7_col6" class="data row7 col6" >2</td>
#       <td id="T_a2970_row7_col7" class="data row7 col7" >1</td>
#       <td id="T_a2970_row7_col8" class="data row7 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_a2970_row8_col1" class="data row8 col1" >water</td>
#       <td id="T_a2970_row8_col2" class="data row8 col2" >water</td>
#       <td id="T_a2970_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_a2970_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_a2970_row8_col5" class="data row8 col5" >1</td>
#       <td id="T_a2970_row8_col6" class="data row8 col6" >2</td>
#       <td id="T_a2970_row8_col7" class="data row8 col7" >1</td>
#       <td id="T_a2970_row8_col8" class="data row8 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_a2970_row9_col1" class="data row9 col1" >water</td>
#       <td id="T_a2970_row9_col2" class="data row9 col2" >water</td>
#       <td id="T_a2970_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_a2970_row9_col4" class="data row9 col4" >1</td>
#       <td id="T_a2970_row9_col5" class="data row9 col5" >1</td>
#       <td id="T_a2970_row9_col6" class="data row9 col6" >2</td>
#       <td id="T_a2970_row9_col7" class="data row9 col7" >1</td>
#       <td id="T_a2970_row9_col8" class="data row9 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_a2970_row10_col1" class="data row10 col1" >water</td>
#       <td id="T_a2970_row10_col2" class="data row10 col2" >water</td>
#       <td id="T_a2970_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_a2970_row10_col4" class="data row10 col4" >1</td>
#       <td id="T_a2970_row10_col5" class="data row10 col5" >1</td>
#       <td id="T_a2970_row10_col6" class="data row10 col6" >2</td>
#       <td id="T_a2970_row10_col7" class="data row10 col7" >1</td>
#       <td id="T_a2970_row10_col8" class="data row10 col8" >water</td>
#     </tr>
#     <tr>
#       <td id="T_a2970_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_a2970_row11_col1" class="data row11 col1" >water</td>
#       <td id="T_a2970_row11_col2" class="data row11 col2" >water</td>
#       <td id="T_a2970_row11_col3" class="data row11 col3" >1</td>
#       <td id="T_a2970_row11_col4" class="data row11 col4" >1</td>
#       <td id="T_a2

# %%
sorted([[6,5],[3,5]])

# %%
aa = molsys_bcif.getObjCatalog()

# %%
aa['atom_site']

# %%
for ii in aa['atom_site'].data:
    if ii[3]=='CAB':
        print(ii)

# %%
aa['atom_site'].getAttributeList()

# %%
msm.info(molsys, element='atom', selection='atom_type=="CA"')

# %%
msm.info(molsys, element='molecule')

# %%
aa['entity_poly']

# %%
aa['chem_comp']

# %%
aa['pdbx_entity_nonpoly']

# %%
aa['entity']

# %%
aa['pdbx_branch_scheme']

# %%
aa['struct_conn']

# %%
for ii in aa['struct_conn'].data:
    if ii[1]=='covale':
        print(ii)

# %%
msm.element.group.get_group_type_from_group_name('ATP')

# %%
aa['chem_comp_bond']

# %%
aa['entity_poly']

# %%
msm.info(molsys, element='chain')

# %%
aa = 'p'

# %%
'g'+aa[1:]

# %%
ord('A')

# %%
aa = [0,1,2]

# %%
for ii in aa[:-1]:
    print(ii)

# %%
for ii in aa[-1:]:
    print(ii)
