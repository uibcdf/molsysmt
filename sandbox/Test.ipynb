# %%
import molsysmt as msm
# Out:
# DEBUG: Registering pipeline kind='std' name='to_bool' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='to_list' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='to_tuple' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='strip' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='lower' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='upper' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='is_positive' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='is_non_negative' in <class 'argdigest.core.registry.Registry'>
# DEBUG: Registering pipeline kind='std' name='is_file' in <class 'argdigest.core.registry.Registry'>
# ...

# %%
molecular_system = msm.convert('1BRS')

# %%
molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')

# %%
msm.info(molecular_system)

# %%
msm.view(molecular_system)

# %%
from mmcif.io.BinaryCifReader import BinaryCifReader
binary_cif_reader = BinaryCifReader()
containers = binary_cif_reader.deserialize('/tmp/tmpqxsyybxe.bcif.gz')

# %%
from mmcif.io.BinaryCifReader import BinaryCifReader
binary_cif_reader = BinaryCifReader()
containers = binary_cif_reader.deserialize('/tmp/tmpzt4jemdt.bcif.gz')
