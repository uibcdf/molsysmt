# %%
import molsysmt as msm
# Out:
# /conda/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
aaa = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'], to_form='mmcif.PdbxContainers.DataContainer')

# %%
aaa.getObj('entity')

# %%
aaa.getObj('chem_comp')

# %%
aaa.getObjNameList()

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_entity_type_from_atom(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_entity_type_from_atom(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_entity_type_from_atom(molsys_Hk2.topology, [4,5,6], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_entity_type_from_atom(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
all_Hk2[2685:2688]
# Out:
# ['protein', 'protein', 'protein']

# %%
all_Hk2[13374:13380]
# Out:
# ['unknown', 'unknown', 'unknown', 'saccharide', 'saccharide', 'saccharide']

# %%
all_Hk2[0]
# Out:
# 'protein'

# %%
all_Hk2[-1]
# Out:
# 'water'

# %%
all_BB[2685:2688]
# Out:
# ['protein', 'protein', 'protein']

# %%
all_BB[-515:-510]
# Out:
# ['protein', 'protein', 'water', 'water', 'water']

# %%
all_BB[0]
# Out:
# 'protein'

# %%
all_BB[-1]
# Out:
# 'water'

# %%
list_Hk2
# Out:
# ['protein', 'protein', 'protein']

# %%
list_BB
# Out:
# ['protein', 'protein', 'protein', 'protein']
