# %%
import molsysmt as msm
# Out:
# /conda/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_bond_index_from_group(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_bond_index_from_group(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_bond_index_from_group(molsys_Hk2.topology, [4,5,6], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_bond_index_from_group(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
all_Hk2
# Out:
# [[0, 1, 2, 3, 4, 5, 6, 7],
#  [4, 8, 9, 10, 11, 12, 13, 14, 15, 16],
#  [12, 17, 18, 19, 20, 21, 22, 23],
#  [21, 24, 25, 26, 27, 28, 29, 30, 31, 32],
#  [28, 33, 34, 35, 36, 37, 38, 39, 40, 41],
#  [37, 42, 43, 44, 45, 46, 47, 48],
#  [46, 49, 50, 51, 52, 53, 54, 55, 56],
#  [53, 57, 58, 59, 60, 61, 62, 63, 64, 65],
#  [61, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78],
#  [70, 79, 80, 81, 82, 83, 84, 85, 86],
#  [83, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99],
#  [91, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
#  [104, 111, 112, 113, 114, 115, 116, 117, 118],
#  [115, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129],
#  [123, 130, 131, 132, 133, 134, 135, 136, 137],
#  [134, 138, 139, 140, 141, 142, 143],
#  [142, 144, 145, 146, 147, 148, 149, 150, 151],
#  [148, 152, 153, 154, 155, 156, 157, 158, 159, 160],
#  [156, 161, 162, 163, 164, 165, 166, 167],
#  [165, 168, 169, 170, 171, 172, 173, 174, 175],
# ...

# %%
all_BB

# %%
list_Hk2

# %%
list_BB

# %%
aa = [[1,2,3], [2,2,2], [3,4,5]]

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[2685:2688]

# %%
all_Hk2[13374:13380]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[2685:2688]

# %%
all_BB[-515:-510]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_BB

# %%
list_Hk2

# %%
len(all_Hk2)

# %%
len(all_BB)

# %%
all_Hk2[15:25]

# %%
all_Hk2[105:115]

# %%
all_Hk2[0]

# %%
all_Hk2[-1]

# %%
all_BB[3:13]

# %%
all_BB[5:8]

# %%
all_BB[486:492]

# %%
all_BB[0]

# %%
all_BB[-1]

# %%
list_Hk2

# %%
list_Hk2[1:]

# %%
list_BB

# %%
len(3)
