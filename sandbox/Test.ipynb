# %%
import molsysmt as msm
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
#aaa = msm.convert('2NZT', 'mmcif.PdbxContainers.DataContainer')

# %%
aaa = msm.convert('1BRS', 'mmcif.PdbxContainers.DataContainer')

# %%
molsys = msm.convert('2NZT')
# Out:
# >> 135
# 5 5 135
# 5 135
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 molsys = msm.convert('2NZT')
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:508, in convert(molecular_system, to_form, selection, structure_indices, syntax, skip_digestion, **kwargs)
#     506 # If one to one
#     507 if not isinstance(from_form, (list, tuple)):
# --> 508     output = _convert_one_to_one(molecular_system, from_form, to_form=to_form, selection=selection, structure_indices=structure_indices,
#     509             syntax=syntax, skip_digestion=True, **kwargs)
#     511 # If multiple to one
# ...

# %%
#aaa = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'], 'mmcif.PdbxContainers.DataContainer')
