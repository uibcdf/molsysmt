# %%
import molsysmt as msm

# %%
molecular_system = msm.convert('1BRS')
# Out:
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'BRS' is not defined in the unit registry
# ERROR: 'molsysmt' is not defined in the unit registry
# ERROR: 'molsysmt' is not defined in the unit registry
# ERROR: 'molsysmt' is not defined in the unit registry
# ERROR: 'molsysmt' is not defined in the unit registry
# ERROR: 'molsysmt' is not defined in the unit registry
# WARNING:
# ERROR: 'networkx' is not defined in the unit registry
# ERROR: 'networkx' is not defined in the unit registry
# ERROR: 'networkx' is not defined in the unit registry
# ERROR: 'networkx' is not defined in the unit registry
# ERROR: 'networkx' is not defined in the unit registry
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ERROR: got an unexpected keyword argument 'kwargs'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 molecular_system = msm.convert('1BRS')
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:244, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     241     eff_rules = cfg_pipe.get("rules")
#     242     bound[argname] = Registry.run(eff_kind, eff_rules, bound[argname], ctx)
# --> 244 return fn_to_wrap(**bound)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:525, in convert(molecular_system, to_form, selection, structure_indices, syntax, skip_digestion, **kwargs)
#     523 # If one to one
#     524 if not isinstance(from_form, (list, tuple)):
# --> 525     output = _convert_one_to_one(molecular_system, from_form, to_form=to_form, selection=selection, structure_indices=structure_indices,
#     526             syntax=syntax, skip_digestion=True, **kwargs)
#     528 # If multiple to one
#     529
#     530 else:
#     531
#     532     # conversions in private shortcuts
#     533     if tuple(sorted(from_form)) in _multiple_conversion_shortcuts:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:94, in _convert_one_to_one(molecular_system, from_form, to_form, selection, structure_indices, syntax, **kwargs)
#      91         if len(missing_arguments)>0:
#      92             raise NotCompatibleConversionError(from_form, to_form, missing_arguments)
# ---> 94     output = function(molecular_system, **conversion_arguments, **kwargs)
#      96 elif ('molsysmt.MolSys' in _dict_modules[from_form]._convert_to) and (to_form in _dict_modules['molsysmt.MolSys']._convert_to):
#      98     output = _convert_one_to_one(molecular_system, from_form, to_form='molsysmt.MolSys', selection=selection,
#      99             structure_indices=structure_indices, syntax=syntax, **kwargs)
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:166, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     164 bound = bind_arguments(fn, *args, **kwargs)
#     165 if bound.get(plan.skip_param, False):
# --> 166     return fn_to_wrap(**bound)
#     168 caller = f"{fn.__module__}.{fn.__name__}"
#     169 if plan.var_keyword_name and plan.var_keyword_name in bound:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/string_pdb_id/to_molsysmt_MolSys.py:10, in to_molsysmt_MolSys(item, atom_indices, structure_indices, skip_digestion)
#       7 from ..mmcif_PdbxContainers_DataContainer import to_molsysmt_MolSys as mmcif_PdbxContainers_DataContainer_to_molsysmt_MolSys
#       9 tmp_item = to_mmcif_PdbxContainers_DataContainer(item, skip_digestion=True)
# ---> 10 tmp_item = mmcif_PdbxContainers_DataContainer_to_molsysmt_MolSys(tmp_item, atom_indices=atom_indices,
#      11                                                           structure_indices=structure_indices, skip_digestion=True)
#      13 return tmp_item
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:166, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     164 bound = bind_arguments(fn, *args, **kwargs)
#     165 if bound.get(plan.skip_param, False):
# --> 166     return fn_to_wrap(**bound)
#     168 caller = f"{fn.__module__}.{fn.__name__}"
#     169 if plan.var_keyword_name and plan.var_keyword_name in bound:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/form/mmcif_PdbxContainers_DataContainer/to_molsysmt_MolSys.py:765, in to_molsysmt_MolSys(item, atom_indices, structure_indices, skip_digestion)
#     761 tmp_item.topology.bonds._sort_bonds()
#     763 # Rebuild components
# --> 765 tmp_item.topology.rebuild_components(redefine_indices=True, redefine_ids=True,
#     766                                      redefine_names=True, redefine_types=True)
#     768 # Rebuild chains
#     770 tmp_item.topology.rebuild_chains(redefine_indices=False, redefine_ids=False,
#     771                                  redefine_types=True, redefine_names=False)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/native/topology.py:564, in Topology.rebuild_components(self, redefine_indices, redefine_ids, redefine_names, redefine_types)
#     560 from molsysmt.element.component import get_component_index, get_component_id, get_component_name, get_component_type
#     562 if redefine_indices:
# --> 564     component_index_of_atoms = get_component_index(self, element='atom', selection='all',
#     565                                                    redefine_indices=True, skip_digestion=True)
#     566     self.atoms['component_index'] = np.array(component_index_of_atoms, dtype=int)
#     567     n_components = component_index_of_atoms[-1]+1
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:166, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     164 bound = bind_arguments(fn, *args, **kwargs)
#     165 if bound.get(plan.skip_param, False):
# --> 166     return fn_to_wrap(**bound)
#     168 caller = f"{fn.__module__}.{fn.__name__}"
#     169 if plan.var_keyword_name and plan.var_keyword_name in bound:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/element/component/get_component_index.py:17, in get_component_index(molecular_system, element, selection, redefine_indices, syntax, skip_digestion)
#      13 from molsysmt import convert, get
#      15 component_index_of_atoms = None
# ---> 17 g = convert(molecular_system, to_form='networkx.Graph', skip_digestion=True)
#      19 components = list(nx.connected_components(g))
#      21 aux_n_components = len(components)
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:166, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     164 bound = bind_arguments(fn, *args, **kwargs)
#     165 if bound.get(plan.skip_param, False):
# --> 166     return fn_to_wrap(**bound)
#     168 caller = f"{fn.__module__}.{fn.__name__}"
#     169 if plan.var_keyword_name and plan.var_keyword_name in bound:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:525, in convert(molecular_system, to_form, selection, structure_indices, syntax, skip_digestion, **kwargs)
#     523 # If one to one
#     524 if not isinstance(from_form, (list, tuple)):
# --> 525     output = _convert_one_to_one(molecular_system, from_form, to_form=to_form, selection=selection, structure_indices=structure_indices,
#     526             syntax=syntax, skip_digestion=True, **kwargs)
#     528 # If multiple to one
#     529
#     530 else:
#     531
#     532     # conversions in private shortcuts
#     533     if tuple(sorted(from_form)) in _multiple_conversion_shortcuts:
#
# File ~/repos@uibcdf/molsysmt/molsysmt/basic/convert.py:94, in _convert_one_to_one(molecular_system, from_form, to_form, selection, structure_indices, syntax, **kwargs)
#      91         if len(missing_arguments)>0:
#      92             raise NotCompatibleConversionError(from_form, to_form, missing_arguments)
# ---> 94     output = function(molecular_system, **conversion_arguments, **kwargs)
#      96 elif ('molsysmt.MolSys' in _dict_modules[from_form]._convert_to) and (to_form in _dict_modules['molsysmt.MolSys']._convert_to):
#      98     output = _convert_one_to_one(molecular_system, from_form, to_form='molsysmt.MolSys', selection=selection,
#      99             structure_indices=structure_indices, syntax=syntax, **kwargs)
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:42, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      40 push_frame(frame)
#      41 try:
# ---> 42     return fn(*args, **kwargs)
#      43 except Exception as exc:
#      44     manager.emit(
#      45         "ERROR",
#      46         str(exc),
#      47         source=fn.__module__,
#      48         exception_type=exc.__class__.__name__,
#      49     )
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:249, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     247     from ..contrib.pyunitwizard_support import context as puw_ctx_manager
#     248     with puw_ctx_manager(**effective_puw_context): return _run_digestion()
# --> 249 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:164, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     163 def _run_digestion():
# --> 164     bound = bind_arguments(fn, *args, **kwargs)
#     165     if bound.get(plan.skip_param, False):
#     166         return fn_to_wrap(**bound)
#
# File ~/repos@uibcdf/argdigest/argdigest/core/utils.py:8, in bind_arguments(fn, *args, **kwargs)
#       6 def bind_arguments(fn: Callable[..., Any], *args: Any, **kwargs: Any) -> dict[str, Any]:
#       7     sig = signature(fn)
# ----> 8     bound = sig.bind_partial(*args, **kwargs)
#       9     bound.apply_defaults()
#      10     return dict(bound.arguments)
#
# File ~/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/python3.12/inspect.py:3287, in Signature.bind_partial(self, *args, **kwargs)
#    3282 def bind_partial(self, /, *args, **kwargs):
#    3283     """Get a BoundArguments object, that partially maps the
#    3284     passed `args` and `kwargs` to the function's signature.
#    3285     Raises `TypeError` if the passed arguments can not be bound.
#    3286     """
# -> 3287     return self._bind(args, kwargs, partial=True)
#
# File ~/Myopt/miniconda3/envs/molsysmt@uibcdf_3.12/lib/python3.12/inspect.py:3269, in Signature._bind(self, args, kwargs, partial)
#    3259         raise TypeError(
#    3260             'got some positional-only arguments passed as '
#    3261             'keyword arguments: {arg!r}'.format(
#    (...)   3266             ),
#    3267         )
#    3268     else:
# -> 3269         raise TypeError(
#    3270             'got an unexpected keyword argument {arg!r}'.format(
#    3271                 arg=next(iter(kwargs))))
#    3273 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'kwargs'

# %%
molecular_system = msm.convert('1BRS', selection='molecule_type=="protein"')

# %%
msm.info(molecular_system)

# %%
msm.view(molecular_system)

# %%
from mmcif.io.BinaryCifReader import BinaryCifReader
binary_cif_reader = BinaryCifReader()
containers = binary_cif_reader.deserialize('/tmp/tmpqxsyybxe.bcif.gz')

# %%
from mmcif.io.BinaryCifReader import BinaryCifReader
binary_cif_reader = BinaryCifReader()
containers = binary_cif_reader.deserialize('/tmp/tmpzt4jemdt.bcif.gz')
