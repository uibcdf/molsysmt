# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from molsysmt import systems
import numpy as np
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
molsys_bcif = msm.convert('2CCY', to_form='bcifreader.PdbxContainers.DataContainer')

# %%
molsys = msm.convert(molsys_bcif)
# Out:
# SG 118 A CAB 129 C
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/repos@uibcdf/molsysmt/molsysmt/form/bcifreader_PdbxContainers_DataContainer/to_molsysmt_MolSys.py:499, in to_molsysmt_MolSys(item, atom_indices, structure_indices, skip_digestion)
#     498 if len(atom_index_2)!=1:
# --> 499     raise Exception
#     500 atom_index_2 = atom_index_2[0]
#
# Exception:
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedMethodError                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 molsys = msm.convert(molsys_bcif)
#
# File ~/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# ...

# %%
msm.info(molsys, element='molecule')

# %%
sorted([[6,5],[3,5]])

# %%
aa = molsys_bcif.getObjCatalog()

# %%
aa['atom_site']

# %%
for ii in aa['atom_site'].data:
    if ii[2]=='CA':
        print(ii)

# %%
aa['atom_site'].getAttributeList()

# %%
msm.info(molsys, element='atom', selection='atom_type=="CA"')

# %%
msm.info(molsys, element='molecule')

# %%
aa['entity_poly']

# %%
aa['chem_comp']

# %%
aa['pdbx_entity_nonpoly']

# %%
aa['entity']

# %%
aa['pdbx_branch_scheme']

# %%
aa['struct_conn']
# Out:
# DataCategory(name:'struct_conn'
# attrbuteList: ['id', 'conn_type_id', 'pdbx_leaving_atom_flag', 'pdbx_PDB_id', 'ptnr1_label_asym_id', 'ptnr1_label_comp_id', 'ptnr1_label_seq_id', 'ptnr1_label_atom_id', 'pdbx_ptnr1_label_alt_id', 'pdbx_ptnr1_PDB_ins_code', 'pdbx_ptnr1_standard_comp_id', 'ptnr1_symmetry', 'ptnr2_label_asym_id', 'ptnr2_label_comp_id', 'ptnr2_label_seq_id', 'ptnr2_label_atom_id', 'pdbx_ptnr2_label_alt_id', 'pdbx_ptnr2_PDB_ins_code', 'ptnr1_auth_asym_id', 'ptnr1_auth_comp_id', 'ptnr1_auth_seq_id', 'ptnr2_auth_asym_id', 'ptnr2_auth_comp_id', 'ptnr2_auth_seq_id', 'ptnr2_symmetry', 'pdbx_ptnr3_label_atom_id', 'pdbx_ptnr3_label_seq_id', 'pdbx_ptnr3_label_comp_id', 'pdbx_ptnr3_label_asym_id', 'pdbx_ptnr3_label_alt_id', 'pdbx_ptnr3_PDB_ins_code', 'details', 'pdbx_dist_value', 'pdbx_value_order', 'pdbx_role']
# ...

# %%
for ii in aa['struct_conn'].data:
    if ii[1]=='covale':
        for aa,bb in zip(aa['struct_conn'].getAttributeList(), ii):
            print(aa,bb)
        print (' ')

# %%
msm.element.group.get_group_type_from_group_name('ATP')

# %%
aa['chem_comp_bond']

# %%
aa['entity_poly']

# %%
msm.info(molsys, element='chain')

# %%
aa = 'p'

# %%
'g'+aa[1:]

# %%
ord('A')
