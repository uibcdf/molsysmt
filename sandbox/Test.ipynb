# %%
import molsysmt as msm
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.12/lib/python3.12/site-packages/nglview/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
import pandas as pd
import numpy as np

# %%
molsys_Hk2 = msm.convert(msm.systems['Hexokinase 2']['2nzt.bcif.gz'])

# %%
molsys_BB = msm.convert(msm.systems['Barnase-Barstar']['1brs.bcif.gz'])

# %%
all_Hk2 = msm.form.molsysmt_Topology.get_atom_name_from_molecule(molsys_Hk2.topology, skip_digestion=True)
all_BB = msm.form.molsysmt_Topology.get_atom_name_from_molecule(molsys_BB.topology, skip_digestion=True)
list_Hk2 = msm.form.molsysmt_Topology.get_atom_name_from_molecule(molsys_Hk2.topology, [1,2,3], skip_digestion=True)
list_BB = msm.form.molsysmt_Topology.get_atom_name_from_molecule(molsys_BB.topology, [10,11,12,13], skip_digestion=True)

# %%
len(all_Hk2)
# Out:
# 135

# %%
len(all_BB)
# Out:
# 519

# %%
all_Hk2[4:10]
# Out:
# [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6'],
#  ['C1',
#   'C2',
#   'O1',
#   'O5',
#   'C3',
#   'O2',
#   'C4',
#   'O3',
#   'C5',
#   'O4',
#   'C6',
#   'O6',
#   'P',
#   'O1P',
#   'O2P',
#   'O3P'],
#  ['UNK'],
#  ['UNK'],
#  ['UNK'],
#  ['UNK']]

# %%
all_Hk2[90:96]
# Out:
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O']]

# %%
all_Hk2[0][110:120]
# Out:
# ['C', 'O', 'CB', 'CG', 'SD', 'CE', 'N', 'CA', 'C', 'O']

# %%
all_Hk2[-1]
# Out:
# ['O']

# %%
all_BB[5:8][0][200:210]
# Out:
# ['CD1', 'CD2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'N']

# %%
all_BB[5:8][1:]
# Out:
# [['O'], ['O']]

# %%
all_BB[486:492]
# Out:
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O']]

# %%
all_BB[0][60:70]
# Out:
# ['N', 'CA', 'C', 'O', 'CB', 'N', 'CA', 'C', 'O', 'CB']

# %%
all_BB[-1]
# Out:
# ['O']

# %%
list_Hk2[0][160:170]
# Out:
# ['OG1', 'CG2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD1', 'CD2']

# %%
list_Hk2[1:]
# Out:
# [['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6'],
#  ['C1',
#   'C2',
#   'O1',
#   'O5',
#   'C3',
#   'O2',
#   'C4',
#   'O3',
#   'C5',
#   'O4',
#   'C6',
#   'O6',
#   'P',
#   'O1P',
#   'O2P',
#   'O3P']]

# %%
list_BB
# Out:
# [['O'], ['O'], ['O'], ['O']]
